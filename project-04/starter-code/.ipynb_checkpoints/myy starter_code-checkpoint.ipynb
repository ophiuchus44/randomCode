# %% [markdown]
# # Web Scraping for Indeed.com & Predicting Salaries

# %% [markdown]
# In this project, we will practice two major skills: collecting data by scraping a website and then building a binary predictor with Logistic Regression.
#
# We are going to collect salary information on data science jobs in a variety of markets. Then using the location, title and summary of the job we will attempt to predict the salary of the job. For job posting sites, this would be extraordinarily useful. While most listings DO NOT come with salary information (as you will see in this exercise), being to able extrapolate or predict the expected salaries from other listings can help guide negotiations.
#
# Normally, we could use regression for this task; however, we will convert this problem into classification and use Logistic Regression.
#
# - Question: Why would we want this to be a classification problem?
# - Answer: While more precision may be better, there is a fair amount of natural variance in job salaries - predicting a range be may be useful.
#
# Therefore, the first part of the assignment will be focused on scraping Indeed.com. In the second, we'll focus on using listings with salary information to build a model and predict additional salaries.

# %% [markdown]
# ### Scraping job listings from Indeed.com

# %% [markdown]
# We will be scraping job listings from Indeed.com using BeautifulSoup. Luckily, Indeed.com is a simple text page where we can easily find relevant entries.
#
# First, look at the source of an Indeed.com page: (http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10")
#
# Notice, each job listing is underneath a `div` tag with a class name of `result`. We can use BeautifulSoup to extract those.

# %% [markdown]
# #### Setup a request (using `requests`) to the URL below. Use BeautifulSoup to parse the page and extract all results (HINT: Look for div tags with class name result)

# %%
URL = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"

# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
r = requests.get(URL)
soup = BeautifulSoup(r.content, "lxml")
#print soup.prettify

# %%
soup.select('a')
# Out:
# [<a class="selected" href="/" id="jobsLink" title="Jobs">Find Jobs</a>,
#  <a href="/resumes?isid=find-resumes&amp;ikw=SERPtop&amp;co=US&amp;hl=en" id="rezLink">Find Resumes</a>,
#  <a href="/hire?hl=en&amp;cc=US" id="empLink" onclick="if ( this.href.match('&amp;isid=employerlink-US-control&amp;ikw=SERPtop') == null ) { this.href += '&amp;isid=employerlink-US-control&amp;ikw=SERPtop' };">Employers / Post Job</a>,
#  <a href="/promo/resume" onclick="window.location=this.href + '?from=nav&amp;subfrom=rezprmstd&amp;trk.origin=jobsearch&amp;trk.variant=rezprmstd&amp;trk.tk=1ameem70abs5gblu'; return false;">Upload your resume</a>,
#  <a href="http://www.indeed.com/account/login?dest=%2Fjobs%3Fq%3Ddata%2Bscientist%2B%2420%2C000%26l%3DNew%2BYork%26start%3D10" id="userOptionsLabel" rel="nofollow">Sign in</a>,
#  <a href="/" id="branding" onmousedown="ptk('logo');"><img alt="one search. all jobs. Indeed" class="indeedLogo" src="..." style="margin-bottom:6px;display:block;" title="one search. all jobs. Indeed"/></a>,
#  <a class="sl" href="/advanced_search?q=data+scientist+%2420%2C000&amp;l=New+York">Advanced Job Search</a>,
#  <a href="/jobs?q=data+scientist+%2420%2C000&amp;l=New+York&amp;sort=date" rel="nofollow">date</a>,
#  <a class="undo" href="/q-data-scientist-l-New-York-jobs.html" onmousedown="rbptk('rbundo', 'salest');" rel="nofollow">undo</a>,
#  <a class="se_label" href="http://support.indeed.com/hc/en-us/articles/204489020-What-is-a-Salary-Estimate-" onclick="showInPopup( '/jsp/about_salary_estimate.jsp' ); return false;">Salaries estimated if unavailable</a>,
#  <a href="/jobs?q=data+scientist+$20,000&amp;l=New+York&amp;jt=fulltime" rel="nofollow" title="Full-time (2075)">Full-time</a>,
#  <a href="/jobs?q=data+scientist+$20,000&amp;l=New+York&amp
itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[6],true,0);" onmousedown="return rclk(this,jobmap[6],0);" rel="nofollow" target="_blank" title="Developer Programs Engineer, Machine Learning">Developer Programs Engineer, Machine Learning</a>,
#  <a href="/cmp/Google?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=90283f5714b2f111&amp;jcid=a5b4499d9e91a5c6" target="_blank">\n    Google</a>,
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Google/reviews?jcid=a5b4499d9e91a5c6" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Developer+Programs+Engineer%2C+Machine+Learning&amp;fromjk=90283f5714b2f111');" target="_blank" title="Google reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 52.800003px;"><!-- --></span></span><span class="slNoUnderline">1,128 reviews</span></a>,
#  <a class="sl resultLink save-job-link" href="#" id="sj_90283f5714b2f111" onclick="changeJobState('90283f5714b2f111', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a>,
#  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('90283f5714b2f111', 6, false); return false;">email</a>,
#  <a class="sl resultLink more-link " href="#" id="tog_6" onclick="toggleMoreLinks('90283f5714b2f111'); return false;">more...</a>,
#  <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('90283f5714b2f111'); return false;" title="Close"></a>,
#  <a href="/q-Google-l-New-York,-NY-jobs.html" rel="nofollow">Google jobs in New York, NY</a>,
#  <a href="/l-New-York,-NY-jobs.html">New York jobs</a>,
#  <a href="/salary?q1=Developer+Program+Engineer&amp;l1=New+York%2C+NY">Developer Program Engineer salaries in New York, NY</a>,
#  <a href="/cmp/Google?fromjk=90283f5714b2f111&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=a5b4499d9e91a5c6">Google</a>,
#  <a href="/forum/loc/New-York-New-York.html">New York, New York</a>,
#  <a href="/forum/cmp/Google.html">Google</a>,
#  <a class="turnstileLink" data-tn-element="jobTitle" href="/cmp/ShopKeep/jobs/Data-Scientist-6ca932c2af4750af?r=1&amp;fccid=11811b52a7138086" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[7],true,0);" onmousedown="return rclk(this,jobmap[7],0);" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>,
#  <a href="/cmp/Shopkeep?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=6ca932c2af4750af&amp;jcid=11811b52a7138086" target="_blank">\n    ShopKeep</a>,
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Shopkeep/reviews?jcid=11811b52a7138086" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=6ca932c2af4750af');" target="_blank" title="Shopkeep reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 43.8px;"><!-- --></span></span><span class="slNoUnderline">4 reviews</span></a>,
#  <a class="sl resultLink save-job-link" href="#" id="sj_6ca932c2af4750af" onclick="changeJobState('6ca932c2af4750af', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a>,
#  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('6ca932c2af4750af', 7, false); return false;">email</a>,
#  <a class="sl resultLink more-link " href="#" id="tog_7" onclick="toggleMoreLinks('6ca932c2af4750af'); return false;">more...</a>,
#  <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('6ca932c2af4750af'); return false;" title="Close"></a>,
#  <a href="/q-Shopkeep-l-New-York,-NY-jobs.html" rel="nofollow">ShopKeep jobs in New York, NY</a>,
#  <a href="/l-New-York,-NY-jobs.html">New York jobs</a>,
#  <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">Data Scientist salaries in New York, NY</a>,
#  <a href="/cmp/Shopkeep?fromjk=6ca932c2af4750af&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=11811b52a7138086">Shopkeep</a>,
#  <a href="/forum/loc/New-York-New-York.html">New York, New York</a>,
#  <a href="/forum/cmp/Shopkeep.html">ShopKeep</a>,
#  <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=d3e3cf3e21ee173a&amp;fccid=d887c830351bb4f7" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[8],true,0);" onmousedown="return rclk(this,jobmap[8],0);" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>,
#  <a href="/cmp/Factset-Research-Systems?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=d3e3cf3e21ee173a&amp;jcid=7ca19d158e5b580d" target="_blank">\n    FactSet</a>,
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Factset-Research-Systems/reviews?jcid=7ca19d158e5b580d" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=d3e3cf3e21ee173a');" target="_blank" title="Factset reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 43.8px;"><!-- --></span></span><span class="slNoUnderline">37 reviews</span></a>,
#  <a class="sl resultLink save-job-link" href="#" id="sj_d3e3cf3e21ee173a" onclick="changeJobState('d3e3cf3e21ee173a', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a>,
#  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('d3e3cf3e21ee173a', 8, false); return false;">email</a>,
#  <a class="sl resultLink more-link " href="#" id="tog_8" onclick="toggleMoreLinks('d3e3cf3e21ee173a'); return false;">more...</a>,
#  <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('d3e3cf3e21ee173a'); return false;" title="Close"></a>,
#  <a href="/q-Factset-l-New-York,-NY-jobs.html" rel="nofollow">FactSet jobs in New York, NY</a>,
#  <a href="/l-New-York,-NY-jobs.html">New York jobs</a>,
#  <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">Data Scientist salaries in New York, NY</a>,
#  <a href="/cmp/Factset-Research-Systems?fromjk=d3e3cf3e21ee173a&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=7ca19d158e5b580d">Factset</a>,
#  <a href="/forum/loc/New-York-New-York.html">New York, New York</a>,
#  <a href="/forum/cmp/Factset-Research-Systems.html">FactSet Research Systems</a>,
#  <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=b79bcf74be22b4ba&amp;fccid=567a0cc944322669" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[9],true,0);" onmousedown="return rclk(this,jobmap[9],0);" rel="nofollow" target="_blank" title="Quantitative Research Associate">Quantitative Research Associate</a>,
#  <a class="sl resultLink save-job-link" href="#" id="sj
0); convCtr('SJ', pingUrlsForGA)" onmousedown="sjomd('sja5'); clk('sja5');" rel="nofollow" target="_blank" title="Data Scientist - Monitoring &amp; Anomaly Detection Platform"><b>Data</b> <b>Scientist</b> - Monitoring &amp; Anomaly Detection Platform</a>,
#  <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Uber?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=2ccb5eca0c079ac2&amp;jcid=f766f8bfbc3effb7" target="_blank">\n    Uber</a>,
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Uber/reviews?jcid=f766f8bfbc3effb7" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist+-+Monitoring+%26+Anomaly+Detection+Platform&amp;fromjk=2ccb5eca0c079ac2');" target="_blank" title="Uber reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 51.6px;"><!-- --></span></span><span class="slNoUnderline">155 reviews</span></a>,
#  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('2ccb5eca0c079ac2', 14, true); return false;">email</a>,
#  <a href="/jobs?q=data+scientist+%2420%2C000&amp;l=New+York"><span class="pn"><span class="np">\xab\xa0Previous</span></span></a>,
#  <a href="/jobs?q=data+scientist+%2420%2C000&amp;l=New+York"><span class="pn">1</span></a>,
#  <a href="/jobs?q=data+scientist+%2420%2C000&amp;l=New+York&amp;start=20"><span class="pn">3</span></a>,
#  <a href="/jobs?q=data+scientist+%2420%2C000&amp;l=New+York&amp;start=30"><span class="pn">4</span></a>,
#  <a href="/jobs?q=data+scientist+%2420%2C000&amp;l=New+York&amp;start=40"><span class="pn">5</span></a>,
#  <a href="/jobs?q=data+scientist+%2420%2C000&amp;l=New+York&amp;start=50"><span class="pn">6</span></a>,
#  <a href="/jobs?q=data+scientist+%2420%2C000&amp;l=New+York&amp;start=20&amp;pp="><span class="pn"><span class="np">Next\xa0\xbb</span></span></a>,
#  <a href="/cmp/Abilto,-Inc?tk=1ameem70abs5gblu" onmousedown="this.href = appendParamsOnce(this.href, '&amp;campaignid=femp&amp;from=femp');" target="_blank"><img alt="AbilTo, Inc" src="https://d2q79iu7y748jz.cloudfront.net/s/_logo/48213d067918757750f3927f170522b9" width="120"/></a>,
#  <a class="femp_cmp_link" href="/cmp/Abilto,-Inc?tk=1ameem70abs5gblu" onmousedown="this.href = appendParamsOnce(this.href, '&amp;campaignid=femp&amp;from=femp');" target="_blank">AbilTo, Inc</a>,
#  <a href="/jobs?q=company%3A%22AbilTo%2C+Inc%22&amp;l=New+York" onmousedown="this.href = appendParamsOnce(this.href, '&amp;from=femp');">Jobs (9)</a>,
#  <a class="popover-close-link">No, thanks</a>,
#  <a class="sl" href="/promo/gotajob" onmousedown="this.href = appendParamsOnce( this.href, '?trk.origin=jobsearch&amp;trk.tk=1ameem70abs5gblu')">Over 2.8 million stories shared</a>,
#  <a href="/" id="jobs_product_link" title="Jobs">Jobs</a>,
#  <a href="/Best-Places-to-Work" id="companies_product_link" title="Browse Companies">Browse Companies</a>,
#  <a href="/salary" id="salaries_product_link" title="Salary Search">Salaries</a>,
#  <a href="/jobtrends" id="trends_product_link" title="Career Trends">Trends</a>,
#  <a href="/forum" id="forums_product_link" title="Employment Forums">Forums</a>,
#  <a href="/find-jobs.jsp">Browse Jobs</a>,
#  <a href="/tools/jobseeker/">Tools</a>,
#  <a href="http://www.indeed.jobs">Work at Indeed</a>,
#  <a href="/publisher">API</a>,
#  <a href="/intl/en/about.html"><nobr>About</nobr></a>,
#  <a href="https://indeed.zendesk.com/hc/en-us">Help Center</a>,
#  <a href="/legal">Cookies, Privacy and Terms</a>]

# %%
soup.select('span.')
# Out:
# []

# %%
soup.select('h1')
# Out:
# [<h1><font size="+1">data scientist $20,000 jobs in New York State</font></h1>]

# %%
soup.select('h2')
# Out:
# [<h2 class="jobtitle" id="jl_5b8a65b6982893bf">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=5b8a65b6982893bf&amp;fccid=6ae0e4a8a0a337cd" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[0],true,0);" onmousedown="return rclk(this,jobmap[0],0);" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>\n</h2>,
#  <h2 class="jobtitle" id="jl_90283f5714b2f111">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=90283f5714b2f111&amp;fccid=a5b4499d9e91a5c6" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[1],true,0);" onmousedown="return rclk(this,jobmap[1],0);" rel="nofollow" target="_blank" title="Developer Programs Engineer, Machine Learning">Developer Programs Engineer, Machine Learning</a>\n</h2>,
#  <h2 class="jobtitle" id="jl_0bffc15fa50ec9a4">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=0bffc15fa50ec9a4&amp;fccid=302ac6eda058f71c" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[2],true,0);" onmousedown="return rclk(this,jobmap[2],0);" rel="nofollow" target="_blank" title="Internship: Sales &amp; Marketing Data Analysis">Internship: Sales &amp; Marketing <b>Data</b> Analysis</a>\n</h2>,
#  <h2 class="jobtitle" id="jl_cd0799dfdf821b2c">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=cd0799dfdf821b2c&amp;fccid=25b5166547bbf543" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[3],true,0);" onmousedown="return rclk(this,jobmap[3],0);" rel="nofollow" target="_blank" title="Senior Inventive Scientist (Labs Big Data Research)">Senior Inventive <b>Scientist</b> (Labs Big <b>Data</b> Research)</a>\n</h2>,
#  <h2 class="jobtitle" id="jl_3ecaa294064ce9f0">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=3ecaa294064ce9f0&amp;fccid=fe2d21eef233e94a" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[4],true,0);" onmousedown="return rclk(this,jobmap[4],0);" rel="nofollow" target="_blank" title="Data Scientist - NYC"><b>Data</b> <b>Scientist</b> - NYC</a>\n</h2>,
#  <h2 class="jobtitle" id="jl_235f3afdc8453fc0">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=235f3afdc8453fc0&amp;fccid=f7029f63fe5c906e" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[5],true,0);" onmousedown="return rclk(this,jobmap[5],0);" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>\n</h2>,
#  <h2 class="jobtitle" id="jl_cabdf8ddc92e8eca">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=cabdf8ddc92e8eca&amp;fccid=21c72fd5fe6c8641" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[6],true,0);" onmousedown="return rclk(this,jobmap[6],0);" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>\n</h2>,
#  <h2 class="jobtitle" id="jl_0e486be090f66c4e">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=0e486be090f66c4e&amp;fccid=9044e8bd254c73d6" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[7],true,0);" onmousedown="return rclk(this,jobmap[7],0);" rel="nofollow" target="_blank" title="Security Data Scientist">Security <b>Data</b> <b>Scientist</b></a>\n</h2>,
#  <h2 class="jobtitle" id="jl_39466464fb7cb366">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=39466464fb7cb366&amp;fccid=fe404d18bb9eef1e" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[8],true,0);" onmousedown="return rclk(this,jobmap[8],0);" rel="nofollow" target="_blank" title="Research Lead / Data Scientist">Research Lead / <b>Data</b> <b>Scientist</b></a>\n</h2>,
#  <h2 class="jobtitle" id="jl_ae363dac9dd3b750">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=ae363dac9dd3b750&amp;fccid=a259fc86b1470609" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[9],true,0);" onmousedown="return rclk(this,jobmap[9],0);" rel="nofollow" target="_blank" title="Research Data Associate">Research <b>Data</b> Associate</a>\n</h2>]

# %%
soup.select('a')
# Out:
# [<a class="selected" href="/" id="jobsLink" title="Jobs">Find Jobs</a>,
#  <a href="/resumes?isid=find-resumes&amp;ikw=SERPtop&amp;co=US&amp;hl=en" id="rezLink">Find Resumes</a>,
#  <a href="/hire?hl=en&amp;cc=US" id="empLink" onclick="if ( this.href.match('&amp;isid=employerlink-US-control&amp;ikw=SERPtop') == null ) { this.href += '&amp;isid=employerlink-US-control&amp;ikw=SERPtop' };">Employers / Post Job</a>,
obs in New York, NY</a>,
#  <a href="/l-New-York,-NY-jobs.html">New York jobs</a>,
#  <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">Data Scientist salaries in New York, NY</a>,
#  <a href="/cmp/Placeiq?fromjk=5b8a65b6982893bf&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=6ae0e4a8a0a337cd">Placeiq</a>,
#  <a href="/forum/loc/New-York-New-York.html">New York, New York</a>,
#  <a href="/forum/cmp/Placeiq.html">PlaceIQ</a>,
#  <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=90283f5714b2f111&amp;fccid=a5b4499d9e91a5c6" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[1],true,0);" onmousedown="return rclk(this,jobmap[1],0);" rel="nofollow" target="_blank" title="Developer Programs Engineer, Machine Learning">Developer Programs Engineer, Machine Learning</a>,
#  <a href="/cmp/Google?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=90283f5714b2f111&amp;jcid=a5b4499d9e91a5c6" target="_blank">\n    Google</a>,
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Google/reviews?jcid=a5b4499d9e91a5c6" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Developer+Programs+Engineer%2C+Machine+Learning&amp;fromjk=90283f5714b2f111');" target="_blank" title="Google reviews">\n<span class="ratings"><span class="rating" style="width:47.300003px;"><!-- --></span></span><span class="slNoUnderline">1,127 reviews</span></a>,
#  <a class="sl resultLink save-job-link" href="#" id="sj_90283f5714b2f111" onclick="changeJobState('90283f5714b2f111', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a>,
#  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('90283f5714b2f111', 1, false); return false;">email</a>,
#  <a class="sl resultLink more-link " href="#" id="tog_1" onclick="toggleMoreLinks('90283f5714b2f111'); return false;">more...</a>,
#  <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('90283f5714b2f111'); return false;" title="Close"></a>,
#  <a href="/q-Google-l-New-York,-NY-jobs.html" rel="nofollow">Google jobs in New York, NY</a>,
#  <a href="/l-New-York,-NY-jobs.html">New York jobs</a>,
#  <a href="/salary?q1=Developer+Program+Engineer&amp;l1=New+York%2C+NY">Developer Program Engineer salaries in New York, NY</a>,
#  <a href="/cmp/Google?fromjk=90283f5714b2f111&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=a5b4499d9e91a5c6">Google</a>,
#  <a href="/forum/loc/New-York-New-York.html">New York, New York</a>,
#  <a href="/forum/cmp/Google.html">Google</a>,
#  <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=0bffc15fa50ec9a4&amp;fccid=302ac6eda058f71c" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[2],true,0);" onmousedown="return rclk(this,jobmap[2],0);" rel="nofollow" target="_blank" title="Internship: Sales &amp; Marketing Data Analysis">Internship: Sales &amp; Marketing <b>Data</b> Analysis</a>,
#  <a class="sl resultLink save-job-link" href="#" id="sj_0bffc15fa50ec9a4" onclick="changeJobState('0bffc15fa50ec9a4', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a>,
#  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('0bffc15fa50ec9a4', 2, false); return false;">email</a>,
#  <a class="sl resultLink more-link " href="#" id="tog_2" onclick="toggleMoreLinks('0bffc15fa50ec9a4'); return false;">more...</a>,
#  <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('0bffc15fa50ec9a4'); return false;" title="Close"></a>,
#  <a href="/q-Jw-Player-l-New-York,-NY-jobs.html" rel="nofollow">JW Player jobs in New York, NY</a>,
#  <a href="/l-New-York,-NY-jobs.html">New York jobs</a>,
#  <a href="/salary?q1=Internship&amp;l1=New+York%2C+NY">Internship salaries in New York, NY</a>,
#  <a href="/cmp/Jw-Player?fromjk=0bffc15fa50ec9a4&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=4539715bb20eb005">Jw Player</a>,
#  <a href="/forum/cmp/Jw-Player.html">JW Player</a>,
#  <a href="/forum/loc/New-York-New-York.html">New York, New York</a>,
#  <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=cd0799dfdf821b2c&amp;fccid=25b5166547bbf543" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[3],true,0);" onmousedown="return rclk(this,jobmap[3],0);" rel="nofollow" target="_blank" title="Senior Inventive Scientist (Labs Big Data Research)">Senior Inventive <b>Scientist</b> (Labs Big <b>Data</b> Research)</a>,
#  <a href="/cmp/AT&amp;T?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=cd0799dfdf821b2c&amp;jcid=25b5166547bbf543" target="_blank">\n    AT&amp;T</a>,
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/AT&amp;T/reviews?jcid=25b5166547bbf543" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Senior+Inventive+Scientist+%28Labs+Big+Data+Research%29&amp;fromjk=cd0799dfdf821b2c');" target="_blank" title="AT&amp;T reviews">\n<span class="ratings"><span class="rating" style="width:42.9px;"><!-- --></span></span><span class="slNoUnderline">13,437 reviews</span></a>,
#  <a class="sl resultLink save-job-link" href="#" id="sj_cd0799dfdf821b2c" onclick="changeJobState('cd0799dfdf821b2c', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a>,
#  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('cd0799dfdf821b2c', 3, false); return false;">email</a>,
#  <a class="sl resultLink more-link " href="#" id="tog
>,
#  <a href="/jobs?q=data+scientist+%2420%2C000&amp;l=New+York&amp;start=50"><span class="pn">6</span></a>,
#  <a href="/jobs?q=data+scientist+%2420%2C000&amp;l=New+York&amp;start=20&amp;pp="><span class="pn"><span class="np">Next\xa0\xbb</span></span></a>,
#  <a href="/cmp/Abilto,-Inc?tk=1amcdcvjb1fba704" onmousedown="this.href = appendParamsOnce(this.href, '&amp;campaignid=femp&amp;from=femp');" target="_blank"><img alt="AbilTo, Inc" src="https://d2q79iu7y748jz.cloudfront.net/s/_logo/48213d067918757750f3927f170522b9" width="120"/></a>,
#  <a class="femp_cmp_link" href="/cmp/Abilto,-Inc?tk=1amcdcvjb1fba704" onmousedown="this.href = appendParamsOnce(this.href, '&amp;campaignid=femp&amp;from=femp');" target="_blank">AbilTo, Inc</a>,
#  <a href="/jobs?q=company%3A%22AbilTo%2C+Inc%22&amp;l=New+York" onmousedown="this.href = appendParamsOnce(this.href, '&amp;from=femp');">Jobs (9)</a>,
#  <a class="popover-close-link">No, thanks</a>,
#  <a class="sl" href="/promo/gotajob" onmousedown="this.href = appendParamsOnce( this.href, '?trk.origin=jobsearch&amp;trk.tk=1amcdcvjb1fba704')">Over 2.8 million stories shared</a>,
#  <a href="/" id="jobs_product_link" title="Jobs">Jobs</a>,
#  <a href="/salary" id="salaries_product_link" title="Salary Search">Salaries</a>,
#  <a href="/jobtrends" id="trends_product_link" title="Career Trends">Trends</a>,
#  <a href="/forum" id="forums_product_link" title="Employment Forums">Forums</a>,
#  <a href="/find-jobs.jsp">Browse Jobs</a>,
#  <a href="/tools/jobseeker/">Tools</a>,
#  <a href="http://www.indeed.jobs">Work at Indeed</a>,
#  <a href="/publisher">API</a>,
#  <a href="/intl/en/about.html"><nobr>About</nobr></a>,
#  <a href="https://indeed.zendesk.com/hc/en-us">Help Center</a>,
#  <a href="/legal">Cookies, Privacy and Terms</a>]

# %%
soup.prettify
# Out:
# <bound method BeautifulSoup.prettify of <!DOCTYPE html>\n<html lang="en">\n<head>\n<meta content="text/html;charset=unicode-escape" http-equiv="content-type"/>\n<!-- pll --><script src="/s/4a89ac5/en_US.js" type="text/javascript"></script>\n<link href="/s/a6a334e/jobsearch_all.css" rel="stylesheet" type="text/css"/>\n<link href="http://rss.indeed.com/rss?q=data+scientist+%2420%2C000&amp;l=New+York" rel="alternate" title="Data Scientist $20,000 Jobs, Employment in New York State" type="application/rss+xml"/>\n<link href="/m/jobs?q=data+scientist+%2420%2C000&amp;l=New+York" media="handheld" rel="alternate"/>\n<script type="text/javascript">\n    \n    window['closureReadyCallbacks'] = [];\n\n    function call_when_jsall_loaded(cb) {\n        if (window['closureReady']) {\n            cb();\n        } else {\n            window['closureReadyCallbacks'].push(cb);\n        }\n    }\n</script>\n<script src="/s/40c36c1/jobsearch-all-compiled.js" type="text/javascript"></script>\n<script type="text/javascript">\nvar pingUrlsForGA = [];\n\nvar searchUID = '1amcdcvjb1fba704';\nvar tk = '1amcdcvjb1fba704';\n\nvar loggedIn = false;\nvar myindeed = true;\nvar userEmail = '';\nvar tellFriendEmail = '';\nvar globalLoginURL = 'http:\\/\\/www.indeed.com\\/account\\/login?dest=%2Fjobs%3Fq%3Ddata%2Bscientist%2B%2420%2C000%26l%3DNew%2BYork%26start%3D10';\nvar globalRegisterURL = 'http:\\/\\/www.indeed.com\\/account\\/register?dest=%2Fjobs%3Fq%3Ddata%2Bscientist%2B%2420%2C000%26l%3DNew%2BYork%26start%3D10';\nvar searchKey = '60e10e972da47133';\nvar searchState = 'q=data+scientist+%2420%2C000&amp;l=New+York&amp;start=10';\nvar searchQS = 'q=data+scientist+$20,000&l=New+York&start=10';\nvar eventType = 'jobsearch';\nvar locale = 'en_US';\nfunction clk(id) { var a = document.getElementById(id); var hr = a.href; var si = a.href.indexOf('&jsa='); if (si > 0) return; var jsh = hr + '&tk=1amcdcvjb1fba704&jsa=1835'; a.href = jsh; }\nfunction sjomd(id) { var a = document.getElementById(id); var hr = a.href; var ocs = hr.indexOf('&oc=1'); if (ocs < 0) return; var oce = ocs + 5; a.href = hr.substring(0, ocs) + hr.substring(oce); }\nfunction sjoc(id, sal) { var a = document.getElementById(id); a.href = a.href + '&oc=1&sal='+sal; }\nfunction ptk(st,p) {document.cookie = 'PTK="tk=1amcdcvjb1fba704&type=jobsearch&subtype='+st+(p?'&'+p:'')+'"; path=/';}\nfunction rbptk(st, c, p) { ptk(st, 'cat='+c+(p?'&p='+p:''));}\n</script>\n<script type="text/javascript">\nfunction loadJSAsync( ) {\nfor ( var i = 0; i < arguments.length; i++ ) {\nvar url = arguments[i];\n(function() {\nvar s = document.createElement("script"), el = document.getElementsByTagName("script")[0];\ns.async = true;\ns.src = url;\nel.parentNode.insertBefore(s, el);\n})();\n}\n}\n</script>\n<meta content="2,272  Data Scientist $20,000 Jobs available in New York State on Indeed.com.  one search.  all jobs." name="description"/>\n<meta content="Data Scientist $20,000 Jobs, Employment in New York State, New York State careers, New York State employment, New York State job listings, New York State job search, New York State search engine, work in New York State" name="keywords"/>\n<link href="/jobs?q=Data+Scientist+$20,000&amp;l=New+York+State&amp;start=10" rel="canonical"/><link href="/jobs?q=data+scientist+%2420%2C000&amp;l=New+York" rel="prev"/>\n<link href="/jobs?q=data+scientist+%2420%2C000&amp;l=New+York&amp;start=20" rel="next"/><style type="text/css">\n#recPromoDisplay { margin-bottom: 3em;margin-left: 0.5em; }\n#recPromoDisplayPageLast { font-size: 16px; margin: 1.5em 0; }\n</style>\n<script type="text/javascript">\nvar indeedCsrfToken = 'XSGF7zFRHYEfYj6tvV4606gIeXmIwRyp';\nvar hashedCsrfToken = '571763c6e244f263ab3845d506ec08d3';\n</script>\n<style type="text/css">\n.jasxcustomfonttst-useCustomHostedFontFullPage *{font-family:"Open Sans", sans-serif !important}.jasxcustomfonttst-useLato *{font-family:"Lato", sans-serif !important}.jasxcustomfonttst-useFira *{font-family:"Fira Sans", sans-serif !im ...

# %%
results = soup.findAll('div',{"class" : "result"})
results
# Out:
# [<div class="row result" data-jk="134f86fee2270420" id="pj_134f86fee2270420">\n<a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0DDxuA8Y4K3JnPiGV4kjt8LJAX0ZelysMhEJeNM_3_rWTILiycg7ZYjKlLAIX95lqQtFmoChREKQ4Z2OUnmNbxKLJ0FrgRoikq887B5dba7jkD4BGEpDFzxdQceHfi8GnvEp16jFQVU5BQ3K9m3fQfOIj9oZ4yopVng23hDM7DkyygyeXOgAXUrbzRuYuV6crN8FDJQBVzs_g9MLDCL5yNuJ-MKGUBzmK0z17wn63A2YFj-xoDMNX20OTY2X3mH8uSAMEk0EcrAtraDmsSe_Ayry3Nw5WUhdH4yXhGRE3qlzKf-ps5o6XcdQNbsOXHa_eAoJqqSA1klkSVSHTsvdHmDxcxc4U9Qr-VjMjQldA8-JC4vMcaK5GDXLabFaEyy6KOL3byn--b9yNqoljldLPpvlp0bkBxM44R2JElC70roQ6F-Fws_DeDXJfpmFtZLvLfcVNI6gNpT0IymG0MMBXTG&amp;p=1&amp;sk=&amp;fvj=0" id="sja1" onclick="setRefineByCookie(['salest']); sjoc('sja1',0); convCtr('SJ', pingUrlsForGA)" onmousedown="sjomd('sja1'); clk('sja1');" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>\n<br/>\n<div class="sjcl">\n<span class="company">\n    AbilTo, Inc</span>\n\n - <span class="location">New York, NY</span>\n</div>\n<table border="0" cellpadding="0" cellspacing="0"><tr><td class="snip">\n<span class="summary"><b>Data</b> &amp; Analytics Team. <b>Data</b> &amp; Analytics team culture:. As a <b>Data</b> <b>Scientist</b> at AbilTo, you will work in a uniquely cross-functional capacity, helping teams...</span>\n</td></tr></table>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">30+ days ago</span> <span class="tt_set" id="tt_set_10">  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('134f86fee2270420', 10, true); return false;">email</a></span><div class="edit_note_content" id="editsaved2_134f86fee2270420" style="display:none;"></div><script>window['sj_result_134f86fee2270420'] = {"showSource": false, "source": "AbilTo, Inc", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "30+ days ago","jobKey": "134f86fee2270420", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": false, "resultNumber": 10, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": false, "currentPage" : "serp", "sponsored" : true,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="tellafriend-container result-tab email_job_content"></div>\n</div>\n<span class="sdn">Sponsored</span>\n</div>,
#  <div class="row sjlast result" data-jk="60daa4cc2519aa23" id="pj_60daa4cc2519aa23">\n<a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0DfhRlNgWF6CSat27t3uUi_uTzycdnOM4gGCFKEHa9SmXbTZxwdwN-Xr1YZZ7rTQ29DWD4p0drATvvKw9qjUbbs1X-MJAJFxKe9IMVD7V3l079MW8Zj0dSrfWinGc9HtO4IkKwQKY8KX_ji1S71_vElWz_MmhtUVXoOB0VwAoR5HmHbnQBqWc9KZypU-bBjjTF1fUx8fEuAMO5Lis6_M1THguu4sIqDz51xof-03i4zm9vSLexx_MiMHqHkrDyel2ru17c5zhyW_4wghR3h2oZXPL3iUfveMWXu14ncHBsf1-BaRX6Ymg4gy2cbwyuiVTlGB-952bZTeOl511boxvmOTNwLe_tj9lETuErKZOFDa03O9T2v6NvM7wym1QtgEeZ9wrHGLBtv-2EIVnD4jOeKWH8izqPKQKe_KAbw2cwTRMXs-cPDh8DeQ-ZiF4Or3uT15_u-HWNofjPc3gE3ASea&amp;p=2&amp;sk=&amp;fvj=1" id="sja2" onclick="setRefineByCookie(['salest']); sjoc('sja2',0); convCtr('SJ', pingUrlsForGA)" onmousedown="sjomd('sja2'); clk('sja2');" rel="nofollow" target="_blank" title="Data Scientist &amp; Analytics Developer"><b>Data</b> <b>Scientist</b> &amp; Analytics Developer</a>\n<br/>\n<div class="sjcl">\n<span class="company">\n    Lancer Insurance Company</span>\n\n - <span class="location">Long Beach, NY</span>\n</div>\n<table border="0" cellpadding="0" cellspacing="0"><tr><td class="snip">\n<span class="summary">Lancer Insurance Company is looking for a talented and motivated <b>data</b> <b>scientist</b> and analytics developer to help provide business insight from our <b>data</b> assets...</span>\n</td></tr></table>\n<div class="iaP">\n<span class="iaLabel"> Easily apply</span>\n</div><div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">13 days ago</span> <span class="tt_set" id="tt_set_11">  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('60daa4cc2519aa23', 11, true); return false;">email</a></span><div class="edit_note_content" id="editsaved2_60daa4cc2519aa23" style="display:none;"></div><script>window['sj_result_60daa4cc2519aa23'] = {"showSource": false, "source": "Indeed", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "13 days ago","jobKey": "60daa4cc2519aa23", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": false, "resultNumber": 11, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": false, "currentPage" : "serp", "sponsored" : true,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="tellafriend-container result-tab email_job_content"></div>\n</div>\n<span class="sdn">Sponsored</span>\n</div>,
#  <div class=" row result" data-jk="5b8a65b6982893bf" data-tn-component="organicJob" id="p_5b8a65b6982893bf" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_5b8a65b6982893bf">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=5b8a65b6982893bf&amp;fccid=6ae0e4a8a0a337cd" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[0],true,0);" onmousedown="return rclk(this,jobmap[0],0);" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Placeiq?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=5b8a65b6982893bf&amp;jcid=6ae0e4a8a0a337cd" target="_blank">\n    PlaceIQ</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Placeiq/reviews?jcid=6ae0e4a8a0a337cd" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=5b8a65b6982893bf');" target="_blank" title="Placeiq reviews">\n<span class="ratings"><span class="rating" style="width:51.699997px;"><!-- --></span></span><span class="slNoUnderline">3 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\n<b>Data</b> <b>Scientists</b> analyze PlaceIQ hyperlocal <b>data</b> sources to develop accurate predictions of audience and behavior....</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">11 days ago</span> <span class="tt_set" id="tt_set_0"> - <span class="savelink2" id="savelink2_5b8a65b6982893bf"><a class="sl resultLink save-job-link" href="#" id="sj_5b8a65b6982893bf" onclick="changeJobState('5b8a65b6982893bf', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('5b8a65b6982893bf', 0, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_0" onclick="toggleMoreLinks('5b8a65b6982893bf'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_5b8a65b6982893bf" style="display:none;"></div><script>window['result_5b8a65b6982893bf'] = {"showSource": false, "source": "PlaceIQ", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "11 days ago","jobKey": "5b8a65b6982893bf", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 0, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_0" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('5b8a65b6982893bf'); return false;" title="Close"></a><div class="more_actions" id="more_0"><ul><li><span class="mat">View all <a href="/q-Placeiq-l-New-York,-NY-jobs.html" rel="nofollow">PlaceIQ jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs.html">New York jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">Data Scientist salaries i ...
#  <div class=" row result" data-jk="90283f5714b2f111" data-tn-component="organicJob" id="p_90283f5714b2f111" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_90283f5714b2f111">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=90283f5714b2f111&amp;fccid=a5b4499d9e91a5c6" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[1],true,0);" onmousedown="return rclk(this,jobmap[1],0);" rel="nofollow" target="_blank" title="Developer Programs Engineer, Machine Learning">Developer Programs Engineer, Machine Learning</a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Google?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=90283f5714b2f111&amp;jcid=a5b4499d9e91a5c6" target="_blank">\n    Google</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Google/reviews?jcid=a5b4499d9e91a5c6" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Developer+Programs+Engineer%2C+Machine+Learning&amp;fromjk=90283f5714b2f111');" target="_blank" title="Google reviews">\n<span class="ratings"><span class="rating" style="width:47.300003px;"><!-- --></span></span><span class="slNoUnderline">1,127 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY 10011 <span style="font-size: smaller">(Chelsea area)</span></span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nPassionate people are everywhere at Google. In Developer Relations, we get excited to collaborate and connect with the communities that love technology as</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">5 days ago</span> <span class="tt_set" id="tt_set_1"> - <span class="savelink2" id="savelink2_90283f5714b2f111"><a class="sl resultLink save-job-link" href="#" id="sj_90283f5714b2f111" onclick="changeJobState('90283f5714b2f111', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('90283f5714b2f111', 1, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_1" onclick="toggleMoreLinks('90283f5714b2f111'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_90283f5714b2f111" style="display:none;"></div><script>window['result_90283f5714b2f111'] = {"showSource": false, "source": "Google", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "5 days ago","jobKey": "90283f5714b2f111", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 1, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_1" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('90283f5714b2f111'); return false;" title="Close"></a><div class="more_actions" id="more_1"><ul><li><span class="mat">View all <a href="/q-Google-l-New-York,-NY-jobs.html" rel="nofollow">Google jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs.h ...
#  <div class=" row result" data-jk="0bffc15fa50ec9a4" data-tn-component="organicJob" id="p_0bffc15fa50ec9a4" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_0bffc15fa50ec9a4">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=0bffc15fa50ec9a4&amp;fccid=302ac6eda058f71c" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[2],true,0);" onmousedown="return rclk(this,jobmap[2],0);" rel="nofollow" target="_blank" title="Internship: Sales &amp; Marketing Data Analysis">Internship: Sales &amp; Marketing <b>Data</b> Analysis</a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n    JW Player</span>\n</span>\n\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY 10018 <span style="font-size: smaller">(Clinton area)</span></span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nAbility to think abstractly and nontraditionally about <b>data</b> trends &amp; implications with an exceptional attention to detail....</span>\n</div>\n<div class="iaP">\n<span class="iaLabel"> Easily apply</span>\n</div><div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">12 days ago</span> <span class="tt_set" id="tt_set_2"> - <span class="savelink2" id="savelink2_0bffc15fa50ec9a4"><a class="sl resultLink save-job-link" href="#" id="sj_0bffc15fa50ec9a4" onclick="changeJobState('0bffc15fa50ec9a4', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('0bffc15fa50ec9a4', 2, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_2" onclick="toggleMoreLinks('0bffc15fa50ec9a4'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_0bffc15fa50ec9a4" style="display:none;"></div><script>window['result_0bffc15fa50ec9a4'] = {"showSource": false, "source": "JW Player", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "12 days ago","jobKey": "0bffc15fa50ec9a4", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 2, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_2" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('0bffc15fa50ec9a4'); return false;" title="Close"></a><div class="more_actions" id="more_2"><ul><li><span class="mat">View all <a href="/q-Jw-Player-l-New-York,-NY-jobs.html" rel="nofollow">JW Player jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs.html">New York jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Internship&amp;l1=New+York%2C+NY">Internship salaries in New York, NY</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Jw-Player?fromjk=0bffc15fa50ec9a4&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=4539715bb20eb005">Jw Player</a></span></li><li><span class="mat">Related forums: <a href="/forum/cmp/Jw-Player.html">JW Player</a> - <a href="/forum/loc/New-York-New-York.html">New York, New York</a></span></li></ul></div></div><div class="dya-container resul ...
#  <div class=" row result" data-jk="cd0799dfdf821b2c" data-tn-component="organicJob" id="p_cd0799dfdf821b2c" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_cd0799dfdf821b2c">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=cd0799dfdf821b2c&amp;fccid=25b5166547bbf543" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[3],true,0);" onmousedown="return rclk(this,jobmap[3],0);" rel="nofollow" target="_blank" title="Senior Inventive Scientist (Labs Big Data Research)">Senior Inventive <b>Scientist</b> (Labs Big <b>Data</b> Research)</a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/AT&amp;T?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=cd0799dfdf821b2c&amp;jcid=25b5166547bbf543" target="_blank">\n    AT&amp;T</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/AT&amp;T/reviews?jcid=25b5166547bbf543" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Senior+Inventive+Scientist+%28Labs+Big+Data+Research%29&amp;fromjk=cd0799dfdf821b2c');" target="_blank" title="AT&amp;T reviews">\n<span class="ratings"><span class="rating" style="width:42.9px;"><!-- --></span></span><span class="slNoUnderline">13,437 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\n<b>Data</b> <b>Scientists</b> will usually have a Master\u2019s; Qualified candidates may be asked to submit a Research Statement (required for Inventive <b>Scientist</b> applicants) and...</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">2 days ago</span> <span class="tt_set" id="tt_set_3"> - <span class="savelink2" id="savelink2_cd0799dfdf821b2c"><a class="sl resultLink save-job-link" href="#" id="sj_cd0799dfdf821b2c" onclick="changeJobState('cd0799dfdf821b2c', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('cd0799dfdf821b2c', 3, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_3" onclick="toggleMoreLinks('cd0799dfdf821b2c'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_cd0799dfdf821b2c" style="display:none;"></div><script>window['result_cd0799dfdf821b2c'] = {"showSource": false, "source": "AT\\x26T", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "2 days ago","jobKey": "cd0799dfdf821b2c", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 3, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_3" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('cd0799dfdf821b2c'); return false;" title="Close"></a><div class="more_actions" id="more_3"><ul><li><span class="mat">View all <a href="/q-AT&amp;T-l-New-York,-NY-jobs.html" rel="nofollow">AT&amp;T jobs in New York, NY</a> - <a href="/l-N ...
#  <div class=" row result" data-jk="3ecaa294064ce9f0" data-tn-component="organicJob" id="p_3ecaa294064ce9f0" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_3ecaa294064ce9f0">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=3ecaa294064ce9f0&amp;fccid=fe2d21eef233e94a" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[4],true,0);" onmousedown="return rclk(this,jobmap[4],0);" rel="nofollow" target="_blank" title="Data Scientist - NYC"><b>Data</b> <b>Scientist</b> - NYC</a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Amazon.com?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=3ecaa294064ce9f0&amp;jcid=12db64101709fb92" target="_blank">\n    Amazon Web Services, Inc.</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Amazon.com/reviews?jcid=12db64101709fb92" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist+-+NYC&amp;fromjk=3ecaa294064ce9f0');" target="_blank" title="Amazon Web Services reviews">\n<span class="ratings"><span class="rating" style="width:40.7px;"><!-- --></span></span><span class="slNoUnderline">8,555 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nInterested in creating new state-of-the-art solutions using Machine Learning and <b>Data</b> Mining techniques on Terabytes of <b>Data</b>?...</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="result-link-source">Amazon.com </span>- <span class="date">10 days ago</span> <span class="tt_set" id="tt_set_4"> - <span class="savelink2" id="savelink2_3ecaa294064ce9f0"><a class="sl resultLink save-job-link" href="#" id="sj_3ecaa294064ce9f0" onclick="changeJobState('3ecaa294064ce9f0', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('3ecaa294064ce9f0', 4, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_4" onclick="toggleMoreLinks('3ecaa294064ce9f0'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_3ecaa294064ce9f0" style="display:none;"></div><script>window['result_3ecaa294064ce9f0'] = {"showSource": true, "source": "Amazon.com", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "10 days ago","jobKey": "3ecaa294064ce9f0", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 4, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_4" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('3ecaa294064ce9f0'); return false;" title="Close"></a><div class="more_actions" id="more_4"><ul><li><span class="mat">View all <a href="/jobs?q=Amazon+Web+Services,+Inc&amp;l=New+York,+NY&amp;nc=jasx" rel="nofollow">Amazon Web Services, Inc. jobs in New York, NY</a> - <a href="/l-New-York,-NY-j ...
#  <div class=" row result" data-jk="235f3afdc8453fc0" data-tn-component="organicJob" id="p_235f3afdc8453fc0" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_235f3afdc8453fc0">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=235f3afdc8453fc0&amp;fccid=f7029f63fe5c906e" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[5],true,0);" onmousedown="return rclk(this,jobmap[5],0);" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Verizon?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=235f3afdc8453fc0&amp;jcid=f7029f63fe5c906e" target="_blank">\n    Verizon</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Verizon/reviews?jcid=f7029f63fe5c906e" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=235f3afdc8453fc0');" target="_blank" title="Verizon reviews">\n<span class="ratings"><span class="rating" style="width:42.9px;"><!-- --></span></span><span class="slNoUnderline">10,528 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY 10007 <span style="font-size: smaller">(Financial District area)</span></span></span></span>\n\xa0<a class="more_loc" href="/jobs?q=data+scientist+%2420%2C000&amp;l=New+York&amp;rbt=Data+Scientist&amp;rbc=Verizon&amp;jtid=1872a3288ede048a&amp;jcid=f7029f63fe5c906e&amp;grp=tcl" onmousedown="ptk('addlloc');" rel="nofollow">+2 locations</a><table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nResearch <b>data</b> to improve customer engagement. Understand, categorize, organize, and interpret heterogeneous <b>data</b> sets....</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">14 days ago</span> <span class="tt_set" id="tt_set_5"> - <span class="savelink2" id="savelink2_235f3afdc8453fc0"><a class="sl resultLink save-job-link" href="#" id="sj_235f3afdc8453fc0" onclick="changeJobState('235f3afdc8453fc0', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('235f3afdc8453fc0', 5, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_5" onclick="toggleMoreLinks('235f3afdc8453fc0'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_235f3afdc8453fc0" style="display:none;"></div><script>window['result_235f3afdc8453fc0'] = {"showSource": false, "source": "Verizon", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "14 days ago","jobKey": "235f3afdc8453fc0", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 5, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_5" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('235f3afdc8453fc0'); return false;" title="Close"></a><div class="more_actions" id="more_5">< ...
#  <div class=" row result" data-jk="cabdf8ddc92e8eca" data-tn-component="organicJob" id="p_cabdf8ddc92e8eca" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_cabdf8ddc92e8eca">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=cabdf8ddc92e8eca&amp;fccid=21c72fd5fe6c8641" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[6],true,0);" onmousedown="return rclk(this,jobmap[6],0);" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n    x.ai</span>\n</span>\n\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY 10004 <span style="font-size: smaller">(Financial District area)</span></span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nA <b>Data</b> <b>Scientist</b> will. Familiar with <b>data</b> structures, parallelism and concurrency. Be capable of visualizing and communicating <b>data</b> science concepts to other...</span>\n</div>\n<div class="iaP">\n<span class="iaLabel"> Easily apply</span>\n</div><div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">17 days ago</span> <span class="tt_set" id="tt_set_6"> - <span class="savelink2" id="savelink2_cabdf8ddc92e8eca"><a class="sl resultLink save-job-link" href="#" id="sj_cabdf8ddc92e8eca" onclick="changeJobState('cabdf8ddc92e8eca', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('cabdf8ddc92e8eca', 6, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_6" onclick="toggleMoreLinks('cabdf8ddc92e8eca'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_cabdf8ddc92e8eca" style="display:none;"></div><script>window['result_cabdf8ddc92e8eca'] = {"showSource": false, "source": "x.ai", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "17 days ago","jobKey": "cabdf8ddc92e8eca", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 6, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_6" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('cabdf8ddc92e8eca'); return false;" title="Close"></a><div class="more_actions" id="more_6"><ul><li><span class="mat">View all <a href="/q-X-Ai-l-New-York,-NY-jobs.html" rel="nofollow">x.ai jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs.html">New York jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">Data Scientist salaries in New York, NY</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/X.ai?fromjk=cabdf8ddc92e8eca&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=808eeee045d402b4">X.ai</a></span></li><li><span class="mat">Related forums: <a href="/forum/loc/New-York-New-York.html">New York, New York</a></span></li></ul></div></div><div class="dya-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_ ...
#  <div class=" row result" data-jk="0e486be090f66c4e" data-tn-component="organicJob" id="p_0e486be090f66c4e" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_0e486be090f66c4e">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=0e486be090f66c4e&amp;fccid=9044e8bd254c73d6" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[7],true,0);" onmousedown="return rclk(this,jobmap[7],0);" rel="nofollow" target="_blank" title="Security Data Scientist">Security <b>Data</b> <b>Scientist</b></a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n    Rockstar New York</span>\n</span>\n\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nThe successful candidate will both define <b>data</b> which should be captured in future states and analyze existing <b>data</b> in order to isolate patterns of bad activity....</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">1 day ago</span> <span class="tt_set" id="tt_set_7"> - <span class="savelink2" id="savelink2_0e486be090f66c4e"><a class="sl resultLink save-job-link" href="#" id="sj_0e486be090f66c4e" onclick="changeJobState('0e486be090f66c4e', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('0e486be090f66c4e', 7, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_7" onclick="toggleMoreLinks('0e486be090f66c4e'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_0e486be090f66c4e" style="display:none;"></div><script>window['result_0e486be090f66c4e'] = {"showSource": false, "source": "Rockstar New York", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "1 day ago","jobKey": "0e486be090f66c4e", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 7, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_7" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('0e486be090f66c4e'); return false;" title="Close"></a><div class="more_actions" id="more_7"><ul><li><span class="mat">View all <a href="/q-Rockstar-New-York-l-New-York,-NY-jobs.html" rel="nofollow">Rockstar New York jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs.html">New York jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Security+Data+Scientist&amp;l1=New+York%2C+NY">Security Data Scientist salaries in New York, NY</a></span></li><li><span class="mat">Related forums: <a href="/forum/loc/New-York-New-York.html">New York, New York</a> - <a href="/forum/cmp/Rockstar-New-York.html">Rockstar New York</a></span></li></ul></div></div><div class="dya-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_content"></div>\n<div class="sign-in-container result-tab"></div>\n<div class="notes-container result-tab"></div>\n</div>\n</td>\n</tr>\n</table>\n</div>,
#  <div class=" row result" data-jk="39466464fb7cb366" data-tn-component="organicJob" id="p_39466464fb7cb366" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_39466464fb7cb366">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=39466464fb7cb366&amp;fccid=fe404d18bb9eef1e" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[8],true,0);" onmousedown="return rclk(this,jobmap[8],0);" rel="nofollow" target="_blank" title="Research Lead / Data Scientist">Research Lead / <b>Data</b> <b>Scientist</b></a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Spotify?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=39466464fb7cb366&amp;jcid=fe404d18bb9eef1e" target="_blank">\n    Spotify</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Spotify/reviews?jcid=fe404d18bb9eef1e" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Research+Lead+%5C%2F+Data+Scientist&amp;fromjk=39466464fb7cb366');" target="_blank" title="Spotify reviews">\n<span class="ratings"><span class="rating" style="width:50.6px;"><!-- --></span></span><span class="slNoUnderline">10 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY 10011 <span style="font-size: smaller">(Chelsea area)</span></span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nYou have experience with a range of <b>data</b> science techniques including clustering, machine learning, and network analysis....</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">29 days ago</span> <span class="tt_set" id="tt_set_8"> - <span class="savelink2" id="savelink2_39466464fb7cb366"><a class="sl resultLink save-job-link" href="#" id="sj_39466464fb7cb366" onclick="changeJobState('39466464fb7cb366', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('39466464fb7cb366', 8, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_8" onclick="toggleMoreLinks('39466464fb7cb366'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_39466464fb7cb366" style="display:none;"></div><script>window['result_39466464fb7cb366'] = {"showSource": false, "source": "Spotify", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "29 days ago","jobKey": "39466464fb7cb366", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 8, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_8" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('39466464fb7cb366'); return false;" title="Close"></a><div class="more_actions" id="more_8"><ul><li><span class="mat">View all <a href="/q-Spotify-l-New-York,-NY-jobs.html" rel="nofollow">Spotify jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs.html">New York jobs</a></span></li><li><span class= ...
#  <div class="lastRow row result" data-jk="ae363dac9dd3b750" data-tn-component="organicJob" id="p_ae363dac9dd3b750" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_ae363dac9dd3b750">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=ae363dac9dd3b750&amp;fccid=a259fc86b1470609" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[9],true,0);" onmousedown="return rclk(this,jobmap[9],0);" rel="nofollow" target="_blank" title="Research Data Associate">Research <b>Data</b> Associate</a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Nyu-Langone-Medical-Center?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=ae363dac9dd3b750&amp;jcid=a259fc86b1470609" target="_blank">\n    NYU Langone Medical Center</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Nyu-Langone-Medical-Center/reviews?jcid=a259fc86b1470609" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Research+Data+Associate&amp;fromjk=ae363dac9dd3b750');" target="_blank" title="Nyu Langone Medical Center reviews">\n<span class="ratings"><span class="rating" style="width:45.1px;"><!-- --></span></span><span class="slNoUnderline">174 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nAssist team in ensuring <b>data</b> quality. We have an exciting opportunity to join our team as a Research <b>Data</b> Associate....</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">14 hours ago</span> <span class="tt_set" id="tt_set_9"> - <span class="savelink2" id="savelink2_ae363dac9dd3b750"><a class="sl resultLink save-job-link" href="#" id="sj_ae363dac9dd3b750" onclick="changeJobState('ae363dac9dd3b750', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('ae363dac9dd3b750', 9, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_9" onclick="toggleMoreLinks('ae363dac9dd3b750'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_ae363dac9dd3b750" style="display:none;"></div><script>window['result_ae363dac9dd3b750'] = {"showSource": false, "source": "NYU Langone Medical Center", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "14 hours ago","jobKey": "ae363dac9dd3b750", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 9, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_9" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('ae363dac9dd3b750'); return false;" title="Close"></a><div class="more_actions" id="more_9"><ul><li><span class="mat">View all <a href="/q-Nyu-Langone-Medical-Center-l-New-York,-NY-jobs.html" rel="nofollow">NYU Langone Medical Center jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs. ...
#  <div class="row result" data-jk="6cd854a446eb26c6" id="pj_6cd854a446eb26c6">\n<a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0Cn4Im-s36KJ-1O3dXdgPBebtUcKxZsLGiQHs_Un5nwi5wiOpqYbWjwjsd70CigrGZtKBcGNeAfxG7so-NKCjtD3FVdhkp7DUV5xjluMOWFz1HmbApPJalqm5iEBlLYSpAJQpVUerQ2J-HtB3zPHuinpG5FUm79kgmCPYluXcJOR3rPYCxa8WNKDFWChLbRHgpJcLx74xm-vmEuqtt2pDPeXI_s5xOoO-6yZYI1R4aK_Kxx8n-1mNMcXR6z9Ern6KE2i_ZVH22TghWwv5VTPz_VfPYN0qNdO98dIV5GWLBH-6KjPBo3GtJtQ9fG2n2u7odA72J0xr1Gc_1uJPfnPvSCXEZDTuwazKf-9OHjjDIXRRPq_9O8HDuSKIfkNSU7VP2ohvlOwI-dZe4W1Re4ssfvd2yHcvWtp7l6vPwI1uWQYK2KEZGZ22KbU1oCfQbgZX7QDSuhrfyVoWXoWqBf3thkpVpdF06cGYGhN6NfbxlLjtF0K_EW14kpoDoCOF-DsFmnw3cpbf8W1UadDTUxNUBgK-goixOP67U0ahshdqYxavv0i0o0bE-lMyod8ZMSKN717tn4xPdy1JKmKDcwQAapY1yn-eRnjZ0=&amp;p=3&amp;sk=&amp;fvj=0" id="sja3" onclick="setRefineByCookie(['salest']); sjoc('sja3',1); convCtr('SJ', pingUrlsForGA)" onmousedown="sjomd('sja3'); clk('sja3');" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>\n<br/>\n<div class="sjcl">\n<span class="company">\n    Princeton Consulting</span>\n\n - <span class="location">New York, NY</span>\n<div>\n$100,000 - $200,000 a year</div>\n</div>\n<table border="0" cellpadding="0" cellspacing="0"><tr><td class="snip">\n<span class="summary">Ability to visualize and communicate <b>data</b> science concepts to other team members and the business. With that being said an ideal candidate should have...</span>\n</td></tr></table>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">13 days ago</span> <span class="tt_set" id="tt_set_12">  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('6cd854a446eb26c6', 12, true); return false;">email</a></span><div class="edit_note_content" id="editsaved2_6cd854a446eb26c6" style="display:none;"></div><script>window['sj_result_6cd854a446eb26c6'] = {"showSource": false, "source": "Princeton Consulting", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "13 days ago","jobKey": "6cd854a446eb26c6", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": false, "resultNumber": 12, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": false, "currentPage" : "serp", "sponsored" : true,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="tellafriend-container result-tab email_job_content"></div>\n</div>\n<span class="sdn">Sponsored</span>\n</div>,
#  <div class="row result" data-jk="3cfa7450ec452027" id="pj_3cfa7450ec452027">\n<a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0Crqn6Yefe8EXUswwgLUi72xdFD8Eg24xRVRzR1g4CwlOlq1Ckyc5_ZDnxJoJaMI-mpP5tpIFL199TfBty-jm89dOaSJQJXfe2GwlnVXUbz2qoMbGMRkx7ns9WNKEp9YBOVSL3O2Gedv7Inw24B7sjUJm6NAtgi8y_UrIqWAdzzk1WkGo92_O3X86suwuuFH9tgyZhh0cUzZB4sw5cz6LSdBmGmi2qlbpHKaTipRQ7MeMPYXKddEEY-abLG4AMmK7nzHLSUg80lDkJDzuc6uTEu-N6ETj_-TcLINgStzdPWnn64IRS73D9-hz8jzKrgLh55zc8OVxaWey45OavfnXfVoGAu3K6pXgC5vMdvElIchrOjf2DXHu5MKzaL3R8fpXc0kBXPN1QNweRy68YdM_4IBLaWeTFIx18EKQ4hQ_4ktWnUsGQAhnK7i4DHD5ZGwHp9H4a_X6IylCEV_DkopDbXNfkcT3D4neR10DnfRnRTOpuQafebZwFNKaWYEH-0yEG8nyhT5mx8Xg==&amp;p=4&amp;sk=&amp;fvj=0" id="sja4" onclick="setRefineByCookie(['salest']); sjoc('sja4',0); convCtr('SJ', pingUrlsForGA)" onmousedown="sjomd('sja4'); clk('sja4');" rel="nofollow" target="_blank" title="Data Scientist \u2013 Predictive Analytics"><b>Data</b> <b>Scientist</b> \u2013 Predictive Analytics</a>\n<br/>\n<div class="sjcl">\n<span class="company">\n<a class="turnstileLink" data-tn-element="companyName" href="/cmp/Gallup?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=3cfa7450ec452027&amp;jcid=e198e2c44e180800" target="_blank">\n    Gallup</a></span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Gallup/reviews?jcid=e198e2c44e180800" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist+%5Cu2013+Predictive+Analytics&amp;fromjk=3cfa7450ec452027');" target="_blank" title="Gallup reviews">\n<span class="ratings"><span class="rating" style="width:42.9px;"><!-- --></span></span><span class="slNoUnderline">58 reviews</span></a>\n - <span class="location">New York, NY</span>\n</div>\n<table border="0" cellpadding="0" cellspacing="0"><tr><td class="snip">\n<span class="summary">Gallup <b>data</b> <b>scientists</b> help clients effectively use <b>data</b> to make better decisions. Experience merging and analyzing large, diverse <b>data</b> sources \u2014 especially...</span>\n</td></tr></table>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">26 days ago</span> <span class="tt_set" id="tt_set_13">  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('3cfa7450ec452027', 13, true); return false;">email</a></span><div class="edit_note_content" id="editsaved2_3cfa7450ec452027" style="display:none;"></div><script>window['sj_result_3cfa7450ec452027'] = {"showSource": false, "source": "Gallup", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "26 days ago","jobKey": "3cfa7450ec452027", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": false, "resultNumber": 13, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": false, "currentPage" : "serp", "sponsored" : true,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="tellafriend-container result-tab email_job_content"></div>\n</div>\n<span class="sdn">Sponsored</span>\n</div>,
#  <div class="row sjlast result" data-jk="2ccb5eca0c079ac2" id="pj_2ccb5eca0c079ac2">\n<a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0AVIi8UxprrPGU7QPohOxOOpynq0pcPnEidcD-eE3H2SkUy41FI-O8USBYuwNfR3iWSpf_jEVuUvE5YjIVl-dP1Lgiaoqm2gYK8C18Ed5lsS9xt1V6feICDW65ZRK1lcyqcpm2OQo4Rm0JkZ2FtAajqS8epuD2xOrY92fiAGVxoJT-4ZOw6X_thTKhiej2NBzj_CzaqQPzqmBMoXutFkq8HD3mGZITfZQ1lvaJxa37_ZsrKnqljwslUhML3gRQCzt4dZFD8NxM3UwjvwWDx3zkrsuh7cIqacvugOCD4RC1I1Ecgi6SXFJulH9jgwN0UgyJJ1LmyvtYD4wL7l-ZRInFv7FSYF5Y5LX3bgJfNx3efxxjfzEgLVD6IQRDoD4iZmAFX7FhKGiBNfvLm8WZWkbSI1qsST1v1f6ILDBfMvvbR6Z1U_gBq9sHvLg_CJrJ2UM5qQClLV8jqW6XcnSvqNs7Cu9eWbIDtRPmyM_FwR_zy7WEEtkuXPEMwaVXkLerUgQWN0oqwOmdoQJkso1yro3JNibZ6W_SHwQVnQZApnGAf-5RA2x4vqajGQK5UOaP5B9PWEPSpJsAnW6_mkwJttC4c0fb8500px3MRt6qW1YYA0dlX0Xe0HCg3hTNXEQK0AHquEATN7Qn95iprrzc_e0sK30WD2ZcBVE0=&amp;p=5&amp;sk=&amp;fvj=0" id="sja5" onclick="setRefineByCookie(['salest']); sjoc('sja5',0); convCtr('SJ', pingUrlsForGA)" onmousedown="sjomd('sja5'); clk('sja5');" rel="nofollow" target="_blank" title="Data Scientist - Monitoring &amp; Anomaly Detection Platform"><b>Data</b> <b>Scientist</b> - Monitoring &amp; Anomaly Detection Platform</a>\n<br/>\n<div class="sjcl">\n<span class="company">\n<a class="turnstileLink" data-tn-element="companyName" href="/cmp/Uber?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=2ccb5eca0c079ac2&amp;jcid=f766f8bfbc3effb7" target="_blank">\n    Uber</a></span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Uber/reviews?jcid=f766f8bfbc3effb7" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist+-+Monitoring+%26+Anomaly+Detection+Platform&amp;fromjk=2ccb5eca0c079ac2');" target="_blank" title="Uber reviews">\n<span class="ratings"><span class="rating" style="width:45.1px;"><!-- --></span></span><span class="slNoUnderline">152 reviews</span></a>\n - <span class="location">New York, NY</span>\n</div>\n<table border="0" cellpadding="0" cellspacing="0"><tr><td class="snip">\n<span class="summary">Working on a cross functional team of <b>data</b> <b>scientists</b> and engineers to support Uber\u2019s existing anomaly detection algorithms and building new anomaly detection...</span>\n</td></tr></table>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">30+ days ago</span> <span class="tt_set" id="tt_set_14">  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('2ccb5eca0c079ac2', 14, true); return false;">email</a></span><div class="edit_note_content" id="editsaved2_2ccb5eca0c079ac2" style="display:none;"></div><script>window['sj_result_2ccb5eca0c079ac2'] = {"showSource": false, "source": "Uber", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "30+ days ago","jobKey": "2ccb5eca0c079ac2", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": false, "resultNumber": 14, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": false, "currentPage" : "serp", "sponsored" : true,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="tellafriend-container result-tab email_job_content"></div>\n</div>\n<span class="sdn">Sponsored</span>\n</div>]

# %%
results = soup.findAll('td',{"class" : "snip"})
results
# Out:
# [<td class="snip">\n<span class="summary"><b>Data</b> &amp; Analytics Team. <b>Data</b> &amp; Analytics team culture:. As a <b>Data</b> <b>Scientist</b> at AbilTo, you will work in a uniquely cross-functional capacity, helping teams...</span>\n</td>,
#  <td class="snip">\n<span class="summary">Lancer Insurance Company is looking for a talented and motivated <b>data</b> <b>scientist</b> and analytics developer to help provide business insight from our <b>data</b> assets...</span>\n</td>,
#  <td class="snip">\n<div>\n<span class="summary" itemprop="description">\n<b>Data</b> <b>Scientists</b> analyze PlaceIQ hyperlocal <b>data</b> sources to develop accurate predictions of audience and behavior....</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">11 days ago</span> <span class="tt_set" id="tt_set_0"> - <span class="savelink2" id="savelink2_5b8a65b6982893bf"><a class="sl resultLink save-job-link" href="#" id="sj_5b8a65b6982893bf" onclick="changeJobState('5b8a65b6982893bf', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('5b8a65b6982893bf', 0, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_0" onclick="toggleMoreLinks('5b8a65b6982893bf'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_5b8a65b6982893bf" style="display:none;"></div><script>window['result_5b8a65b6982893bf'] = {"showSource": false, "source": "PlaceIQ", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "11 days ago","jobKey": "5b8a65b6982893bf", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 0, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_0" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('5b8a65b6982893bf'); return false;" title="Close"></a><div class="more_actions" id="more_0"><ul><li><span class="mat">View all <a href="/q-Placeiq-l-New-York,-NY-jobs.html" rel="nofollow">PlaceIQ jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs.html">New York jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">Data Scientist salaries in New York, NY</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Placeiq?fromjk=5b8a65b6982893bf&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=6ae0e4a8a0a337cd">Placeiq</a></span></li><li><span class="mat">Related forums: <a href="/forum/loc/New-York-New-York.html">New York, New York</a> - <a href="/forum/cmp/Placeiq.html">PlaceIQ</a></span></li></ul></div></div><div class="dya-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_content"></div>\n<div class="sign-in-container result-tab"></div>\n<div class="notes-container result-tab"></div>\n</div>\n</td>,
#  <td class="snip">\n<div>\n<span class="summary" itemprop="description">\nPassionate people are everywhere at Google. In Developer Relations, we get excited to collaborate and connect with the communities that love technology as</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">5 days ago</span> <span class="tt_set" id="tt_set_1"> - <span class="savelink2" id="savelink2_90283f5714b2f111"><a class="sl resultLink save-job-link" href="#" id="sj_90283f5714b2f111" onclick="changeJobState('90283f5714b2f111', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('90283f5714b2f111', 1, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_1" onclick="toggleMoreLinks('90283f5714b2f111'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_90283f5714b2f111" style="display:none;"></div><script>window['result_90283f5714b2f111'] = {"showSource": false, "source": "Google", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "5 days ago","jobKey": "90283f5714b2f111", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 1, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_1" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('90283f5714b2f111'); return false;" title="Close"></a><div class="more_actions" id="more_1"><ul><li><span class="mat">View all <a href="/q-Google-l-New-York,-NY-jobs.html" rel="nofollow">Google jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs.html">New York jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Developer+Program+Engineer&amp;l1=New+York%2C+NY">Developer Program Engineer salaries in New York, NY</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Google?fromjk=90283f5714b2f111&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=a5b4499d9e91a5c6">Google</a></span></li><li><span class="mat">Related forums: <a href="/forum/loc/New-York-New-York.html">New York, New York</a> - <a href="/forum/cmp/Google.html">Google</a></span></li></ul></div></div><div class="dya-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_content"></div>\n<div class="sign-in-container result-tab"></div>\n<div class="notes-container result-tab"></div>\n</div>\n</td>,
#  <td class="snip">\n<div>\n<span class="summary" itemprop="description">\nAbility to think abstractly and nontraditionally about <b>data</b> trends &amp; implications with an exceptional attention to detail....</span>\n</div>\n<div class="iaP">\n<span class="iaLabel"> Easily apply</span>\n</div><div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">12 days ago</span> <span class="tt_set" id="tt_set_2"> - <span class="savelink2" id="savelink2_0bffc15fa50ec9a4"><a class="sl resultLink save-job-link" href="#" id="sj_0bffc15fa50ec9a4" onclick="changeJobState('0bffc15fa50ec9a4', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('0bffc15fa50ec9a4', 2, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_2" onclick="toggleMoreLinks('0bffc15fa50ec9a4'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_0bffc15fa50ec9a4" style="display:none;"></div><script>window['result_0bffc15fa50ec9a4'] = {"showSource": false, "source": "JW Player", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "12 days ago","jobKey": "0bffc15fa50ec9a4", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 2, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_2" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('0bffc15fa50ec9a4'); return false;" title="Close"></a><div class="more_actions" id="more_2"><ul><li><span class="mat">View all <a href="/q-Jw-Player-l-New-York,-NY-jobs.html" rel="nofollow">JW Player jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs.html">New York jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Internship&amp;l1=New+York%2C+NY">Internship salaries in New York, NY</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Jw-Player?fromjk=0bffc15fa50ec9a4&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=4539715bb20eb005">Jw Player</a></span></li><li><span class="mat">Related forums: <a href="/forum/cmp/Jw-Player.html">JW Player</a> - <a href="/forum/loc/New-York-New-York.html">New York, New York</a></span></li></ul></div></div><div class="dya-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_content"></div>\n<div class="sign-in-container result-tab"></div>\n<div class="notes-container result-tab"></div>\n</div>\n</td>,
#  <td class="snip">\n<div>\n<span class="summary" itemprop="description">\n<b>Data</b> <b>Scientists</b> will usually have a Master\u2019s; Qualified candidates may be asked to submit a Research Statement (required for Inventive <b>Scientist</b> applicants) and...</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">2 days ago</span> <span class="tt_set" id="tt_set_3"> - <span class="savelink2" id="savelink2_cd0799dfdf821b2c"><a class="sl resultLink save-job-link" href="#" id="sj_cd0799dfdf821b2c" onclick="changeJobState('cd0799dfdf821b2c', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('cd0799dfdf821b2c', 3, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_3" onclick="toggleMoreLinks('cd0799dfdf821b2c'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_cd0799dfdf821b2c" style="display:none;"></div><script>window['result_cd0799dfdf821b2c'] = {"showSource": false, "source": "AT\\x26T", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "2 days ago","jobKey": "cd0799dfdf821b2c", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 3, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_3" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('cd0799dfdf821b2c'); return false;" title="Close"></a><div class="more_actions" id="more_3"><ul><li><span class="mat">View all <a href="/q-AT&amp;T-l-New-York,-NY-jobs.html" rel="nofollow">AT&amp;T jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs.html">New York jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Senior+Inventive+Scientist&amp;l1=New+York%2C+NY">Senior Inventive Scientist salaries in New York, NY</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/AT&amp;T?fromjk=cd0799dfdf821b2c&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=25b5166547bbf543">AT&amp;T</a></span></li><li><span class="mat">Related forums: <a href="/forum/loc/New-York-New-York.html">New York, New York</a> - <a href="/forum/cmp/AT%26T.html">AT&amp;T</a></span></li></ul></div></div><div class="dya-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_content"></div>\n<div class="sign-in-container result-tab"></div>\n<div class="notes-container result-tab"></div>\n</div>\n</td>,
#  <td class="snip">\n<div>\n<span class="summary" itemprop="description">\nInterested in creating new state-of-the-art solutions using Machine Learning and <b>Data</b> Mining techniques on Terabytes of <b>Data</b>?...</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="result-link-source">Amazon.com </span>- <span class="date">10 days ago</span> <span class="tt_set" id="tt_set_4"> - <span class="savelink2" id="savelink2_3ecaa294064ce9f0"><a class="sl resultLink save-job-link" href="#" id="sj_3ecaa294064ce9f0" onclick="changeJobState('3ecaa294064ce9f0', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('3ecaa294064ce9f0', 4, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_4" onclick="toggleMoreLinks('3ecaa294064ce9f0'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_3ecaa294064ce9f0" style="display:none;"></div><script>window['result_3ecaa294064ce9f0'] = {"showSource": true, "source": "Amazon.com", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "10 days ago","jobKey": "3ecaa294064ce9f0", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 4, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_4" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('3ecaa294064ce9f0'); return false;" title="Close"></a><div class="more_actions" id="more_4"><ul><li><span class="mat">View all <a href="/jobs?q=Amazon+Web+Services,+Inc&amp;l=New+York,+NY&amp;nc=jasx" rel="nofollow">Amazon Web Services, Inc. jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs.html">New York jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">Data Scientist salaries in New York, NY</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Amazon.com?fromjk=3ecaa294064ce9f0&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=12db64101709fb92">Amazon Web Services, Inc.</a></span></li><li><span class="mat">Related forums: <a href="/forum/loc/New-York-New-York.html">New York, New York</a></span></li></ul></div></div><div class="dya-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_content"></div>\n<div class="sign-in-container result-tab"></div>\n<div class="notes-container result-tab"></div>\n</div>\n</td>,
#  <td class="snip">\n<div>\n<span class="summary" itemprop="description">\nResearch <b>data</b> to improve customer engagement. Understand, categorize, organize, and interpret heterogeneous <b>data</b> sets....</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">14 days ago</span> <span class="tt_set" id="tt_set_5"> - <span class="savelink2" id="savelink2_235f3afdc8453fc0"><a class="sl resultLink save-job-link" href="#" id="sj_235f3afdc8453fc0" onclick="changeJobState('235f3afdc8453fc0', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('235f3afdc8453fc0', 5, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_5" onclick="toggleMoreLinks('235f3afdc8453fc0'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_235f3afdc8453fc0" style="display:none;"></div><script>window['result_235f3afdc8453fc0'] = {"showSource": false, "source": "Verizon", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "14 days ago","jobKey": "235f3afdc8453fc0", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 5, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_5" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('235f3afdc8453fc0'); return false;" title="Close"></a><div class="more_actions" id="more_5"><ul><li><span class="mat">View all <a href="/q-Verizon-l-New-York,-NY-jobs.html" rel="nofollow">Verizon jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs.html">New York jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">Data Scientist salaries in New York, NY</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Verizon?fromjk=235f3afdc8453fc0&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=f7029f63fe5c906e">Verizon</a></span></li><li><span class="mat">Related forums: <a href="/forum/cmp/Verizon.html">Verizon</a> - <a href="/forum/loc/New-York-New-York.html">New York, New York</a></span></li></ul></div></div><div class="dya-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_content"></div>\n<div class="sign-in-container result-tab"></div>\n<div class="notes-container result-tab"></div>\n</div>\n</td>,
#  <td class="snip">\n<div>\n<span class="summary" itemprop="description">\nA <b>Data</b> <b>Scientist</b> will. Familiar with <b>data</b> structures, parallelism and concurrency. Be capable of visualizing and communicating <b>data</b> science concepts to other...</span>\n</div>\n<div class="iaP">\n<span class="iaLabel"> Easily apply</span>\n</div><div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">17 days ago</span> <span class="tt_set" id="tt_set_6"> - <span class="savelink2" id="savelink2_cabdf8ddc92e8eca"><a class="sl resultLink save-job-link" href="#" id="sj_cabdf8ddc92e8eca" onclick="changeJobState('cabdf8ddc92e8eca', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('cabdf8ddc92e8eca', 6, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_6" onclick="toggleMoreLinks('cabdf8ddc92e8eca'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_cabdf8ddc92e8eca" style="display:none;"></div><script>window['result_cabdf8ddc92e8eca'] = {"showSource": false, "source": "x.ai", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "17 days ago","jobKey": "cabdf8ddc92e8eca", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 6, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_6" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('cabdf8ddc92e8eca'); return false;" title="Close"></a><div class="more_actions" id="more_6"><ul><li><span class="mat">View all <a href="/q-X-Ai-l-New-York,-NY-jobs.html" rel="nofollow">x.ai jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs.html">New York jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">Data Scientist salaries in New York, NY</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/X.ai?fromjk=cabdf8ddc92e8eca&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=808eeee045d402b4">X.ai</a></span></li><li><span class="mat">Related forums: <a href="/forum/loc/New-York-New-York.html">New York, New York</a></span></li></ul></div></div><div class="dya-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_content"></div>\n<div class="sign-in-container result-tab"></div>\n<div class="notes-container result-tab"></div>\n</div>\n</td>,
#  <td class="snip">\n<div>\n<span class="summary" itemprop="description">\nThe successful candidate will both define <b>data</b> which should be captured in future states and analyze existing <b>data</b> in order to isolate patterns of bad activity....</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">1 day ago</span> <span class="tt_set" id="tt_set_7"> - <span class="savelink2" id="savelink2_0e486be090f66c4e"><a class="sl resultLink save-job-link" href="#" id="sj_0e486be090f66c4e" onclick="changeJobState('0e486be090f66c4e', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('0e486be090f66c4e', 7, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_7" onclick="toggleMoreLinks('0e486be090f66c4e'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_0e486be090f66c4e" style="display:none;"></div><script>window['result_0e486be090f66c4e'] = {"showSource": false, "source": "Rockstar New York", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "1 day ago","jobKey": "0e486be090f66c4e", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 7, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_7" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('0e486be090f66c4e'); return false;" title="Close"></a><div class="more_actions" id="more_7"><ul><li><span class="mat">View all <a href="/q-Rockstar-New-York-l-New-York,-NY-jobs.html" rel="nofollow">Rockstar New York jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs.html">New York jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Security+Data+Scientist&amp;l1=New+York%2C+NY">Security Data Scientist salaries in New York, NY</a></span></li><li><span class="mat">Related forums: <a href="/forum/loc/New-York-New-York.html">New York, New York</a> - <a href="/forum/cmp/Rockstar-New-York.html">Rockstar New York</a></span></li></ul></div></div><div class="dya-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_content"></div>\n<div class="sign-in-container result-tab"></div>\n<div class="notes-container result-tab"></div>\n</div>\n</td>,
#  <td class="snip">\n<div>\n<span class="summary" itemprop="description">\nYou have experience with a range of <b>data</b> science techniques including clustering, machine learning, and network analysis....</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">29 days ago</span> <span class="tt_set" id="tt_set_8"> - <span class="savelink2" id="savelink2_39466464fb7cb366"><a class="sl resultLink save-job-link" href="#" id="sj_39466464fb7cb366" onclick="changeJobState('39466464fb7cb366', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('39466464fb7cb366', 8, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_8" onclick="toggleMoreLinks('39466464fb7cb366'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_39466464fb7cb366" style="display:none;"></div><script>window['result_39466464fb7cb366'] = {"showSource": false, "source": "Spotify", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "29 days ago","jobKey": "39466464fb7cb366", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 8, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_8" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('39466464fb7cb366'); return false;" title="Close"></a><div class="more_actions" id="more_8"><ul><li><span class="mat">View all <a href="/q-Spotify-l-New-York,-NY-jobs.html" rel="nofollow">Spotify jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs.html">New York jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Research+Lead&amp;l1=New+York%2C+NY">Research Lead salaries in New York, NY</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Spotify?fromjk=39466464fb7cb366&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=fe404d18bb9eef1e">Spotify</a></span></li><li><span class="mat">Related forums: <a href="/forum/loc/New-York-New-York.html">New York, New York</a> - <a href="/forum/cmp/Spotify.html">Spotify</a></span></li></ul></div></div><div class="dya-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_content"></div>\n<div class="sign-in-container result-tab"></div>\n<div class="notes-container result-tab"></div>\n</div>\n</td>,
#  <td class="snip">\n<div>\n<span class="summary" itemprop="description">\nAssist team in ensuring <b>data</b> quality. We have an exciting opportunity to join our team as a Research <b>Data</b> Associate....</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">14 hours ago</span> <span class="tt_set" id="tt_set_9"> - <span class="savelink2" id="savelink2_ae363dac9dd3b750"><a class="sl resultLink save-job-link" href="#" id="sj_ae363dac9dd3b750" onclick="changeJobState('ae363dac9dd3b750', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('ae363dac9dd3b750', 9, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_9" onclick="toggleMoreLinks('ae363dac9dd3b750'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_ae363dac9dd3b750" style="display:none;"></div><script>window['result_ae363dac9dd3b750'] = {"showSource": false, "source": "NYU Langone Medical Center", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "14 hours ago","jobKey": "ae363dac9dd3b750", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 9, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_9" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('ae363dac9dd3b750'); return false;" title="Close"></a><div class="more_actions" id="more_9"><ul><li><span class="mat">View all <a href="/q-Nyu-Langone-Medical-Center-l-New-York,-NY-jobs.html" rel="nofollow">NYU Langone Medical Center jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs.html">New York jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Research+Data+Associate&amp;l1=New+York%2C+NY">Research Data Associate salaries in New York, NY</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Nyu-Langone-Medical-Center?fromjk=ae363dac9dd3b750&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=a259fc86b1470609">Nyu Langone Medical Center</a></span></li><li><span class="mat">Related forums: <a href="/forum/cmp/Nyu-Langone-Medical-Center.html">NYU Langone Medical Center</a> - <a href="/forum/loc/New-York-New-York.html">New York, New York</a></span></li></ul></div></div><div class="dya-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_content"></div>\n<div class="sign-in-container result-tab"></div>\n<div class="notes-container result-tab"></div>\n</div>\n</td>,
#  <td class="snip">\n<span class="summary">Ability to visualize and communicate <b>data</b> science concepts to other team members and the business. With that being said an ideal candidate should have...</span>\n</td>,
#  <td class="snip">\n<span class="summary">Gallup <b>data</b> <b>scientists</b> help clients effectively use <b>data</b> to make better decisions. Experience merging and analyzing large, diverse <b>data</b> sources \u2014 especially...</span>\n</td>,
#  <td class="snip">\n<span class="summary">Working on a cross functional team of <b>data</b> <b>scientists</b> and engineers to support Uber\u2019s existing anomaly detection algorithms and building new anomaly detection...</span>\n</td>]

# %%
results = soup.findAll('div',{"class" : " row  result"})
results
# results[1].attrs
# Out:
# [<div class=" row result" data-jk="77be4fe06c2eb4a5" data-tn-component="organicJob" id="p_77be4fe06c2eb4a5" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_77be4fe06c2eb4a5">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=77be4fe06c2eb4a5&amp;fccid=c618ba0d5e55039b" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[0],true,0);" onmousedown="return rclk(this,jobmap[0],0);" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n    Paperless Post</span>\n</span>\n\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nBuild production systems to collect and process <b>data</b>. Analyze the <b>data</b> we collect to generate important insights....</span>\n</div>\n<div class="iaP">\n<span class="iaLabel"> Easily apply</span>\n</div><div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">4 days ago</span> <span class="tt_set" id="tt_set_0"> - <span class="savelink2" id="savelink2_77be4fe06c2eb4a5"><a class="sl resultLink save-job-link" href="#" id="sj_77be4fe06c2eb4a5" onclick="changeJobState('77be4fe06c2eb4a5', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('77be4fe06c2eb4a5', 0, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_0" onclick="toggleMoreLinks('77be4fe06c2eb4a5'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_77be4fe06c2eb4a5" style="display:none;"></div><script>window['result_77be4fe06c2eb4a5'] = {"showSource": false, "source": "Paperless Post", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "4 days ago","jobKey": "77be4fe06c2eb4a5", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 0, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_0" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('77be4fe06c2eb4a5'); return false;" title="Close"></a><div class="more_actions" id="more_0"><ul><li><span class="mat">View all <a href="/q-Paperless-Post-l-New-York,-NY-jobs.html" rel="nofollow">Paperless Post jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs.html">New York jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">Data Scientist salaries in New York, NY</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Paperless-Post?fromjk=77be4fe06c2eb4a5&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=c618ba0d5e55039b">Paperless Post</a></span></li><li><span class="mat">Related forums: <a href="/forum/loc/New-York-New-York.html">New York, New York</a> - <a href="/forum/cmp/Paperless-Post.html">Paperless Post</a></span></li></ul></div></div><div class="dya-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_content">< ...
#  <div class=" row result" data-jk="c0fb1fe98b72b8f8" data-tn-component="organicJob" id="p_c0fb1fe98b72b8f8" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_c0fb1fe98b72b8f8">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=c0fb1fe98b72b8f8&amp;fccid=3c371b712ace44cf" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[1],true,0);" onmousedown="return rclk(this,jobmap[1],0);" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Dish?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=c0fb1fe98b72b8f8&amp;jcid=9d6f5c1f25e62b5d" target="_blank">\n    DISH Network</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Dish/reviews?jcid=9d6f5c1f25e62b5d" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=c0fb1fe98b72b8f8');" target="_blank" title="Dish Network reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 40.8px;"><!-- --></span></span><span class="slNoUnderline">1,908 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nA successful <b>Data</b> <b>Scientist</b> will have the following:. Developing critical analytics using key DISH <b>data</b> sources including the viewer measurement <b>data</b> and...</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="result-link-source">DISH </span>- <span class="date">7 days ago</span> <span class="tt_set" id="tt_set_1"> - <span class="savelink2" id="savelink2_c0fb1fe98b72b8f8"><a class="sl resultLink save-job-link" href="#" id="sj_c0fb1fe98b72b8f8" onclick="changeJobState('c0fb1fe98b72b8f8', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('c0fb1fe98b72b8f8', 1, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_1" onclick="toggleMoreLinks('c0fb1fe98b72b8f8'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_c0fb1fe98b72b8f8" style="display:none;"></div><script>window['result_c0fb1fe98b72b8f8'] = {"showSource": true, "source": "DISH", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "7 days ago","jobKey": "c0fb1fe98b72b8f8", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 1, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_1" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('c0fb1fe98b72b8f8'); return false;" titl ...
#  <div class=" row result" data-jk="5b8a65b6982893bf" data-tn-component="organicJob" id="p_5b8a65b6982893bf" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_5b8a65b6982893bf">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=5b8a65b6982893bf&amp;fccid=6ae0e4a8a0a337cd" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[2],true,0);" onmousedown="return rclk(this,jobmap[2],0);" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Placeiq?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=5b8a65b6982893bf&amp;jcid=6ae0e4a8a0a337cd" target="_blank">\n    PlaceIQ</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Placeiq/reviews?jcid=6ae0e4a8a0a337cd" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=5b8a65b6982893bf');" target="_blank" title="Placeiq reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 55.199997px;"><!-- --></span></span><span class="slNoUnderline">3 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\n<b>Data</b> <b>Scientists</b> analyze PlaceIQ hyperlocal <b>data</b> sources to develop accurate predictions of audience and behavior....</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">12 days ago</span> <span class="tt_set" id="tt_set_2"> - <span class="savelink2" id="savelink2_5b8a65b6982893bf"><a class="sl resultLink save-job-link" href="#" id="sj_5b8a65b6982893bf" onclick="changeJobState('5b8a65b6982893bf', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('5b8a65b6982893bf', 2, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_2" onclick="toggleMoreLinks('5b8a65b6982893bf'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_5b8a65b6982893bf" style="display:none;"></div><script>window['result_5b8a65b6982893bf'] = {"showSource": false, "source": "PlaceIQ", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "12 days ago","jobKey": "5b8a65b6982893bf", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 2, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_2" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('5b8a65b6982893bf'); return false;" title="Close"></a><div class="more_actions" id="more_2"><ul><li><span class="mat">View all <a h ...
#  <div class=" row result" data-jk="8aa326326f5dde65" data-tn-component="organicJob" id="p_8aa326326f5dde65" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_8aa326326f5dde65">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=8aa326326f5dde65&amp;fccid=0c3bee0a120721d4" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[3],true,0);" onmousedown="return rclk(this,jobmap[3],0);" rel="nofollow" target="_blank" title="Research Analyst - Data Analytics and Artificial Intelligence">Research Analyst - <b>Data</b> Analytics and Artificial Intelligenc...</a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n    Lux Research</span>\n</span>\n\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nAnalyst - <b>Data</b> Analytics and Artificial Intelligence (Boston, New York, Amsterdam, or Singapore). Relevant expertise in machine learning, statistics, <b>data</b>...</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">4 days ago</span> <span class="tt_set" id="tt_set_3"> - <span class="savelink2" id="savelink2_8aa326326f5dde65"><a class="sl resultLink save-job-link" href="#" id="sj_8aa326326f5dde65" onclick="changeJobState('8aa326326f5dde65', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('8aa326326f5dde65', 3, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_3" onclick="toggleMoreLinks('8aa326326f5dde65'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_8aa326326f5dde65" style="display:none;"></div><script>window['result_8aa326326f5dde65'] = {"showSource": false, "source": "Lux Research", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "4 days ago","jobKey": "8aa326326f5dde65", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 3, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_3" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('8aa326326f5dde65'); return false;" title="Close"></a><div class="more_actions" id="more_3"><ul><li><span class="mat">View all <a href="/q-Lux-Research-l-New-York,-NY-jobs.html" rel="nofollow">Lux Research jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs.html">New York jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Research+Analyst&amp;l1=New+York%2C+NY">Research Analyst salaries in New York, NY</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Lux-Research?fromjk=8aa326326f5dde65&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=0c3bee0a120721d4">Lux Research</a></span></li><li><span class="mat">Related forums: <a href="/forum/loc/New-York-New-York.html">New York, New York</a> - <a href="/forum/cmp/Lux-Research.html">Lux Research</a></span></li></ul></div></div><div class="dya-container result-tab"></div>\n<div class="tell ...
#  <div class=" row result" data-jk="30c228790352e62c" data-tn-component="organicJob" id="p_30c228790352e62c" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_30c228790352e62c">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=30c228790352e62c&amp;fccid=c63a4b95712b07d4" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[4],true,0);" onmousedown="return rclk(this,jobmap[4],0);" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n    Tapad</span>\n</span>\n\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nTapad is looking for an experienced <b>Data</b> <b>Scientist</b> to join our Engineering team. The <b>Data</b> <b>Scientist</b> will work on expanding and developing the core of our...</span>\n</div>\n<div class="iaP">\n<span class="iaLabel"> Easily apply</span>\n</div><div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">9 days ago</span> <span class="tt_set" id="tt_set_4"> - <span class="savelink2" id="savelink2_30c228790352e62c"><a class="sl resultLink save-job-link" href="#" id="sj_30c228790352e62c" onclick="changeJobState('30c228790352e62c', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('30c228790352e62c', 4, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_4" onclick="toggleMoreLinks('30c228790352e62c'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_30c228790352e62c" style="display:none;"></div><script>window['result_30c228790352e62c'] = {"showSource": false, "source": "Tapad", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "9 days ago","jobKey": "30c228790352e62c", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 4, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_4" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('30c228790352e62c'); return false;" title="Close"></a><div class="more_actions" id="more_4"><ul><li><span class="mat">View all <a href="/q-Tapad-l-New-York,-NY-jobs.html" rel="nofollow">Tapad jobs in New York, NY</a> - <a href="/l-New-York,-NY-jobs.html">New York jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Data+Scientist&amp;l1=New+York%2C+NY">Data Scientist salaries in New York, NY</a></span></li><li><span class="mat">Related forums: <a href="/forum/loc/New-York-New-York.html">New York, New York</a> - <a href="/forum/cmp/Tapad.html">Tapad</a></span></li></ul></div></div><div class="dya-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_content"></div>\n<div class="sign-in-container result-tab"></div>\n<div class="notes-container result-tab"></div>\n</div>\n</td>\n</tr>\n</table>\n</div>,
#  <div class=" row result" data-jk="235f3afdc8453fc0" data-tn-component="organicJob" id="p_235f3afdc8453fc0" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_235f3afdc8453fc0">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=235f3afdc8453fc0&amp;fccid=f7029f63fe5c906e" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[5],true,0);" onmousedown="return rclk(this,jobmap[5],0);" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Verizon?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=235f3afdc8453fc0&amp;jcid=f7029f63fe5c906e" target="_blank">\n    Verizon</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Verizon/reviews?jcid=f7029f63fe5c906e" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=235f3afdc8453fc0');" target="_blank" title="Verizon reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 44.4px;"><!-- --></span></span><span class="slNoUnderline">10,535 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY 10007 <span style="font-size: smaller">(Financial District area)</span></span></span></span>\n\xa0<a class="more_loc" href="/jobs?q=data+scientist+%2420%2C000&amp;l=New+York&amp;rbt=Data+Scientist&amp;rbc=Verizon&amp;jtid=1872a3288ede048a&amp;jcid=f7029f63fe5c906e&amp;grp=tcl" onmousedown="ptk('addlloc');" rel="nofollow">+2 locations</a><table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nResearch <b>data</b> to improve customer engagement. Understand, categorize, organize, and interpret heterogeneous <b>data</b> sets....</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">15 days ago</span> <span class="tt_set" id="tt_set_5"> - <span class="savelink2" id="savelink2_235f3afdc8453fc0"><a class="sl resultLink save-job-link" href="#" id="sj_235f3afdc8453fc0" onclick="changeJobState('235f3afdc8453fc0', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('235f3afdc8453fc0', 5, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_5" onclick="toggleMoreLinks('235f3afdc8453fc0'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_235f3afdc8453fc0" style="display:none;"></div><script>window['result_235f3afdc8453fc0'] = {"showSource": false, "source": "Verizon", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "15 days ago","jobKey": "235f3afdc8453fc0", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 5, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></di ...
#  <div class=" row result" data-jk="90283f5714b2f111" data-tn-component="organicJob" id="p_90283f5714b2f111" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_90283f5714b2f111">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=90283f5714b2f111&amp;fccid=a5b4499d9e91a5c6" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[6],true,0);" onmousedown="return rclk(this,jobmap[6],0);" rel="nofollow" target="_blank" title="Developer Programs Engineer, Machine Learning">Developer Programs Engineer, Machine Learning</a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Google?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=90283f5714b2f111&amp;jcid=a5b4499d9e91a5c6" target="_blank">\n    Google</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Google/reviews?jcid=a5b4499d9e91a5c6" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Developer+Programs+Engineer%2C+Machine+Learning&amp;fromjk=90283f5714b2f111');" target="_blank" title="Google reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 52.800003px;"><!-- --></span></span><span class="slNoUnderline">1,128 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY 10011 <span style="font-size: smaller">(Chelsea area)</span></span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nPassionate people are everywhere at Google. In Developer Relations, we get excited to collaborate and connect with the communities that love technology as</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">6 days ago</span> <span class="tt_set" id="tt_set_6"> - <span class="savelink2" id="savelink2_90283f5714b2f111"><a class="sl resultLink save-job-link" href="#" id="sj_90283f5714b2f111" onclick="changeJobState('90283f5714b2f111', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('90283f5714b2f111', 6, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_6" onclick="toggleMoreLinks('90283f5714b2f111'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_90283f5714b2f111" style="display:none;"></div><script>window['result_90283f5714b2f111'] = {"showSource": false, "source": "Google", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "6 days ago","jobKey": "90283f5714b2f111", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 6, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_6" style="display:none;"><a class="close-link closeLink" href="#"  ...
#  <div class=" row result" data-jk="6ca932c2af4750af" data-tn-component="organicJob" id="p_6ca932c2af4750af" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_6ca932c2af4750af">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/cmp/ShopKeep/jobs/Data-Scientist-6ca932c2af4750af?r=1&amp;fccid=11811b52a7138086" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[7],true,0);" onmousedown="return rclk(this,jobmap[7],0);" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Shopkeep?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=6ca932c2af4750af&amp;jcid=11811b52a7138086" target="_blank">\n    ShopKeep</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Shopkeep/reviews?jcid=11811b52a7138086" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=6ca932c2af4750af');" target="_blank" title="Shopkeep reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 43.8px;"><!-- --></span></span><span class="slNoUnderline">4 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY 10013 <span style="font-size: smaller">(Tribeca area)</span></span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nWe have a mature <b>data</b> infrastructure, and we\u2019d like someone to interrogate this <b>data</b> relentlessly. <b>Data</b> visualization / exploration tools (especially Looker)....</span>\n</div>\n<div class="iaP">\n<span class="iaLabel"> Easily apply</span>\n</div><div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">8 days ago</span> <span class="tt_set" id="tt_set_7"> - <span class="savelink2" id="savelink2_6ca932c2af4750af"><a class="sl resultLink save-job-link" href="#" id="sj_6ca932c2af4750af" onclick="changeJobState('6ca932c2af4750af', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('6ca932c2af4750af', 7, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_7" onclick="toggleMoreLinks('6ca932c2af4750af'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_6ca932c2af4750af" style="display:none;"></div><script>window['result_6ca932c2af4750af'] = {"showSource": false, "source": "Indeed", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "8 days ago","jobKey": "6ca932c2af4750af", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 7, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_7" style="display:n ...
#  <div class=" row result" data-jk="d3e3cf3e21ee173a" data-tn-component="organicJob" id="p_d3e3cf3e21ee173a" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_d3e3cf3e21ee173a">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=d3e3cf3e21ee173a&amp;fccid=d887c830351bb4f7" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[8],true,0);" onmousedown="return rclk(this,jobmap[8],0);" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Factset-Research-Systems?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=d3e3cf3e21ee173a&amp;jcid=7ca19d158e5b580d" target="_blank">\n    FactSet</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Factset-Research-Systems/reviews?jcid=7ca19d158e5b580d" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=d3e3cf3e21ee173a');" target="_blank" title="Factset reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 43.8px;"><!-- --></span></span><span class="slNoUnderline">37 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY 10279 <span style="font-size: smaller">(Financial District area)</span></span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nShould be a creative <b>data</b> <b>scientist</b> and be. <b>Scientist</b> and engineer. Applications, and comprehensive <b>data</b> feeds....</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">19 days ago</span> <span class="tt_set" id="tt_set_8"> - <span class="savelink2" id="savelink2_d3e3cf3e21ee173a"><a class="sl resultLink save-job-link" href="#" id="sj_d3e3cf3e21ee173a" onclick="changeJobState('d3e3cf3e21ee173a', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('d3e3cf3e21ee173a', 8, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_8" onclick="toggleMoreLinks('d3e3cf3e21ee173a'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_d3e3cf3e21ee173a" style="display:none;"></div><script>window['result_d3e3cf3e21ee173a'] = {"showSource": false, "source": "FactSet", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "19 days ago","jobKey": "d3e3cf3e21ee173a", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 8, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_8" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('d3e3cf3e21ee173a'); ret ...

# %%
pauldic = {
     "company" : =[]
     "title" : =[]
     "location" : =[]
     "salary" : =[]
    }

for x in results:
    if 'company' in x:
        pauldic['company'] = x
# Out:
# re.compile(r'^(?P<tag>[a-zA-Z0-9][-.a-zA-Z0-9:_]*)?\[(?P<attribute>[\w-]+)(?P<operator>[=~\|\^\$\*]?)=?"?(?P<value>[^\]"]*)"?\]$')

# %%
# tagList = ["company", "name", "location","salary"]

# for i in results:
#     for j in tagList:
#         if i.j:
#             print i.j
        
print results[3].location
# Out:
# None

# %%
results.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-115-ee02e5371fb9> in <module>()
# ----> 1 results.text
#
# AttributeError: 'ResultSet' object has no attribute 'text'

# %%
pauldic = {
     "company" : ""
     "title" : ""
     "location" : ""
     "salary" : ""
    }

for x in results:
    if 'company' in x:
        pauldic['company'] = x

# %%
tmp.findChild

# for i in tmp:
#     print i
    
# for i in tmp:
#     if 'href' in i.attrs:
#         print i.text, i.h2, i.attrs['href']
# Out:
# <bound method Tag.find of <div class=" row result" data-jk="90283f5714b2f111" data-tn-component="organicJob" id="p_90283f5714b2f111" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_90283f5714b2f111">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=90283f5714b2f111&amp;fccid=a5b4499d9e91a5c6" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[1],true,0);" onmousedown="return rclk(this,jobmap[1],0);" rel="nofollow" target="_blank" title="Developer Programs Engineer, Machine Learning">Developer Programs Engineer, Machine Learning</a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Google?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=90283f5714b2f111&amp;jcid=a5b4499d9e91a5c6" target="_blank">\n    Google</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Google/reviews?jcid=a5b4499d9e91a5c6" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Developer+Programs+Engineer%2C+Machine+Learning&amp;fromjk=90283f5714b2f111');" target="_blank" title="Google reviews">\n<span class="ratingNumber" style="font-size: 13px; vertical-align: baseline;">4.3</span><span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 52.800003px;"><!-- --></span></span><span class="slNoUnderline">1,127 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">New York, NY 10011 <span style="font-size: smaller">(Chelsea area)</span></span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nPassionate people are everywhere at Google. In Developer Relations, we get excited to collaborate and connect with the communities that love technology as</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">5 days ago</span> <span class="tt_set" id="tt_set_1"> - <span class="savelink2" id="savelink2_90283f5714b2f111"><a class="sl resultLink save-job-link" href="#" id="sj_90283f5714b2f111" onclick="changeJobState('90283f5714b2f111', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span>  -  <a class="sl resultLink tellafriend-link " href="mailto:?subject=I found this job on Indeed&amp;body=http://www.indeed.com" onclick="toggleTellAFriend('90283f5714b2f111', 1, false); return false;">email</a> - <a class="sl resultLink more-link " href="#" id="tog_1" onclick="toggleMoreLinks('90283f5714b2f111'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_90283f5714b2f111" style="display:none;"></div><script>window['result_90283f5714b2f111'] = {"showSource": false, "source": "Google", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "5 days ago","jobKey": "90283f5714b2f111", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 1, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=New+York&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false};</script></div></div>\n<div class="tab-container">\n<div class="m ...

# %%
tmp.attribselect_re
# Out:
# re.compile(r'^(?P<tag>[a-zA-Z0-9][-.a-zA-Z0-9:_]*)?\[(?P<attribute>[\w-]+)(?P<operator>[=~\|\^\$\*]?)=?"?(?P<value>[^\]"]*)"?\]$')

# %%
pauldic = {
     "company" : ""
     "title" : ""
     "location" : ""
     "salary" : ""
    }

for x in results:
    if 'company' in x:
        pauldic['company'] = x
        
        
pauldic

# %%
for i in results:
    i.attrs['salary']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-778d54aa6b51> in <module>()
#       1 for i in results:
# ----> 2     i.attrs['salary']
#       3
#       4
#
# KeyError: 'salary'

# %%
company = soup.select('span.company')
print company[7].text.strip()
# Out:
# Verizon

# %%
# try   result 'salary'

# expect:  
    
#     pass

# %%
results = soup.findAll('div',{"class" : "sjcl"})
results
# Out:
# [<div class="sjcl">\n<span class="company">\n    AbilTo, Inc</span>\n\n - <span class="location">New York, NY</span>\n</div>,
#  <div class="sjcl">\n<span class="company">\n    Lancer Insurance Company</span>\n\n - <span class="location">Long Beach, NY</span>\n</div>,
#  <div class="sjcl">\n<span class="company">\n    Princeton Consulting</span>\n\n - <span class="location">New York, NY</span>\n<div>\n$100,000 - $200,000 a year</div>\n</div>,
#  <div class="sjcl">\n<span class="company">\n<a class="turnstileLink" data-tn-element="companyName" href="/cmp/Gallup?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=3cfa7450ec452027&amp;jcid=e198e2c44e180800" target="_blank">\n    Gallup</a></span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Gallup/reviews?jcid=e198e2c44e180800" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist+%5Cu2013+Predictive+Analytics&amp;fromjk=3cfa7450ec452027');" target="_blank" title="Gallup reviews">\n<span class="ratings"><span class="rating" style="width:42.9px;"><!-- --></span></span><span class="slNoUnderline">58 reviews</span></a>\n - <span class="location">New York, NY</span>\n</div>,
#  <div class="sjcl">\n<span class="company">\n<a class="turnstileLink" data-tn-element="companyName" href="/cmp/Uber?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=2ccb5eca0c079ac2&amp;jcid=f766f8bfbc3effb7" target="_blank">\n    Uber</a></span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Uber/reviews?jcid=f766f8bfbc3effb7" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist+-+Monitoring+%26+Anomaly+Detection+Platform&amp;fromjk=2ccb5eca0c079ac2');" target="_blank" title="Uber reviews">\n<span class="ratings"><span class="rating" style="width:45.1px;"><!-- --></span></span><span class="slNoUnderline">152 reviews</span></a>\n - <span class="location">New York, NY</span>\n</div>]

# %%
paullist = []

for i in results:
    paullist.append(i.text)
    
    
paullist
#     paullist.append(i)
# r = class

pauldic = {}

for x in results:
    if 'company' in x:
        pauldic['company'] = (x)
        
        
pauldic
# {
#     "company" : i
#     "location" :
#     "salary" : 
# }

# r.methods
# Out:
# {}

# %%
pauldic = {
     "company" : ""
     "title" : ""
     "location" : ""
     "salary" : ""
    }

for x in results:
    if 'company' in x:
        pauldic['company'] = x
        
        
pauldic
# Out:
# {}

# %% [markdown]
# Let's look at one result more closely. A single `result` looks like
#
# ```
# <div class=" row result" data-jk="2480d203f7e97210" data-tn-component="organicJob" id="p_2480d203f7e97210" itemscope="" itemtype="http://schema.org/JobPosting">
# <h2 class="jobtitle" id="jl_2480d203f7e97210">
# <a class="turnstileLink" data-tn-element="jobTitle" onmousedown="return rclk(this,jobmap[0],1);" rel="nofollow" target="_blank" title="AVP/Quantitative Analyst">AVP/Quantitative Analyst</a>
# </h2>
# <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
# <span itemprop="name">
# <a href="/cmp/Alliancebernstein?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=2480d203f7e97210&amp;jcid=b374f2a780e04789" target="_blank">
#     AllianceBernstein</a></span>
# </span>
# <tr>
# <td class="snip">
# <nobr>$117,500 - $127,500 a year</nobr>
# <div>
# <span class="summary" itemprop="description">
# C onduct quantitative and statistical research as well as portfolio management for various investment portfolios. Collaborate with Quantitative Analysts and</span>
# </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# ```
#
# While this has some more verbose elements removed, we can see that there is some structure to the above:
# - The salary is available in a `nobr` element inside of a `td` element with `class='snip`.
# - The title of a job is in a link with class set to `jobtitle` and a `data-tn-element="jobTitle`.
# - The location is set in a `span` with `class='location'`.
# - The company is set in a `span` with `class='company'`.

# %% [markdown]
# ### Write 4 functions to extract each item: location, company, job, and salary.
#
# example:
# ```python
# def extract_location_from_result(result):
#     return result.find ...
# ```
#
#
# - Make sure these functions are robust and can handle cases where the data/field may not be available.
# - Test the functions on the results above

# %%
## YOUR CODE HERE
def extract_text1(el):
    if el:
        return el.text.strip()
    else:
        return ""
    
def get_company_from_result(result):
    return extract_text(result.find('span', {'class' : 'company'}))

# %% [markdown]
# Now, to scale up our scraping, we need to accumulate more results. We can do this by examining the URL above.
#
# - "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"
#
# There are two query parameters here we can alter to collect more results, the `l=New+York` and the `start=10`. The first controls the location of the results (so we can try a different city). The second controls where in the results to start and gives 10 results (thus, we can keep incrementing by 10 to go further in the list).

# %% [markdown]
# #### Complete the following code to collect results from multiple cities and starting points.
# - Enter your city below to add it to the search
# - Remember to convert your salary to U.S. Dollars to match the other cities if the currency is different

# %%
YOUR_CITY = ''

# %%
url_template = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}&start={}"
max_results_per_city = 100

results = []

for city in set(['New+York', 'Chicago', 'San+Francisco', 'Austin', YOUR_CITY]):
    for start in range(0, max_results_per_city, 10):
        # Grab the results from the request (as above)
        # Append to the full set of results
        pass

# %% [markdown]
# #### Use the functions you wrote above to parse out the 4 fields - location, title, company and salary. Create a dataframe from the results with those 4 columns.

# %%
## YOUR CODE HERE

# %% [markdown]
# Lastly, we need to clean up salary data.
# 1. Some of the salaries are not yearly but hourly, these will be useful to us for now
# 2. The salaries are given as text and usually with ranges.
#
# #### Filter out the salaries that are not yearly (filter those that refer to hour)

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Write a function that takes a salary string and converts it to a number, averaging a salary range if necessary

# %%
## YOUR CODE HERE

# %% [markdown]
# ### Save your results as a CSV

# %%
## YOUR CODE HERE

# %% [markdown]
# ## Predicting salaries using Logistic Regression

# %% [markdown]
# #### Load in the the data of scraped salaries

# %%
## YOUR CODE HERE

# %% [markdown]
# #### We want to predict a binary variable - whether the salary was low or high. Compute the median salary and create a new binary variable that is true when the salary is high (above the median)

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Thought experiment: What is the baseline accuracy for this model?

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Create a Logistic Regression model to predict High/Low salary using statsmodel. Start by ONLY using the location as a feature. Display the coefficients and write a short summary of what they mean.

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Create a few new variables in your dataframe to represent interesting features of a job title.
# - For example, create a feature that represents whether 'Senior' is in the title
# - or whether 'Manager' is in the title.
# - Then build a new Logistic Regression model with these features. Do they add any value?

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Rebuild this model with scikit-learn.
# - You can either create the dummy features manually or use the `dmatrix` function from `patsy`
# - Remember to scale the feature variables as well!

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Use cross-validation in scikit-learn to evaluate the model above.
# - Evaluate the accuracy, AUC, precision and recall of the model.
# - Discuss the differences and explain when you want a high-recall or a high-precision model in this scenario.

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Compare L1 and L2 regularization for this logistic regression model. What effect does this have on the coefficients learned?

# %%
## YOUR CODE HERE

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Continue to incorporate other text features from the title or summary that you believe will predict the salary and examine their coefficients

# %% [markdown]
# #### Take ~100 scraped entries with salaries. Convert them to use with your model and predict the salary - which entries have the highest predicted salaries?

# %% [markdown]
# ### BONUS

# %% [markdown]
# #### Bonus: Use Count Vectorizer from scikit-learn to create features from the text summaries.
# - Examine using count or binary features in the model
# - Re-evaluate the logistic regression model using these. Does this improve the model performance?
# - What text features are the most valuable?

# %%
## YOUR CODE HERE

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Re-test L1 and L2 regularization. You can use LogisticRegressionCV to find the optimal reguarlization parameters.
# - Re-test what text features are most valuable.
# - How do L1 and L2 change the coefficients?

# %%
## YOUR CODE HERE
