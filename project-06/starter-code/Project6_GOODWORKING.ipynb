# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, roc_curve, auc, f1_score
from matplotlib.colors import ListedColormap
from patsy import dmatrices
from sklearn.linear_model import LogisticRegression, Ridge
from sklearn.cross_validation import train_test_split, cross_val_score
from sklearn.pipeline import Pipeline, make_pipeline, make_union
from sklearn import metrics
import spacy
from sklearn.feature_extraction.text import CountVectorizer, HashingVectorizer, TfidfVectorizer, TfidfTransformer
import nltk
from sqlalchemy import create_engine
from spacy.en import English
from sklearn.preprocessing import Imputer, StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.base import BaseEstimator, TransformerMixin
from IPython.display import Image
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import roc_auc_score, classification_report
from sqlalchemy import create_engine
import patsy
from sklearn import neighbors, metrics
import seaborn as sns
sns.set(color_codes=True)
import os
from imdbpie import Imdb
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from scrapy.selector import Selector
from scrapy.http import HtmlResponse
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import subprocess
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
import scipy
from imdbpie import Imdb
import requests
import nltk
import matplotlib.pyplot as plt
import urllib
from bs4 import BeautifulSoup
import nltk
from collections import Counter
from IPython.display import Image
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO
import pydot
import re
import csv
import psycopg2
# %matplotlib inline

# %%
import pandas as pd

df = pd.read_csv('/Users/Paul/Desktop/General_Assembly/DSI_SM_01/projects/01-projects-weekly/project-06/summaryMovie.csv')

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
#tokenize the words of every summary
tmpList = []
for i in df.summary_review:
    tmp = word_tokenize(str(i))
    tmpList.append(tmp)

# %%
#put the list of lists back into the data frame
df.summary_review = [i for i in tmpList]

# %%
df.tail(2)
# Out:
#                     title       location  \
# 11036  The Usual Suspects  United States
# 11037  The Usual Suspects        UNKNOWN
#
#                                           summary_review  review_score  \
# 11036  [a, movie, you, need, to, watch, twice, to, ap...           9.0
# 11037  [``, the, great, trick, the, devil, ever, pull...          10.0
#
#        movie_score  genre
# 11036          8.6  Crime
# 11037          8.6  Crime

# %% [markdown]
# ### get freqdist of each review

# %%
tmp2 = []
for i in df.summary_review:
    tmp2.append(FreqDist(i))

# %%
tmp2
# Out:
# [FreqDist({'good': 1, 'not': 1, 'really': 1}),
#  FreqDist({"'re": 1,
#            'better': 1,
#            'clear': 1,
#            'from': 1,
#            'off': 1,
#            'ranch': 1,
#            'stay': 1,
#            'this': 1,
#            'well': 1,
#            'you': 1}),
#  FreqDist({'...': 1,
#            'be': 1,
#            'dressing': 1,
#            'it': 1,
#            'messy': 1,
#            'ranch': 1,
#            'raptor': 1,
#            'should': 1,
#            'so': 1}),
#  FreqDist({'and': 1, 'man': 1, 'of': 1, 'reptile': 1}),
#  FreqDist({'a': 1, 'better': 1, 'lot': 1, 'people': 1, 'say': 1, 'then': 1}),
#  FreqDist({'a': 1, 'be': 1, 'f*ck': 1, 'this': 1, 'what': 1}),
#  FreqDist({'different': 1, 'diversity': 1, 'in': 1, 'way': 1}),
#  FreqDist({'not': 1, 'watch': 1, 'worth': 1}),
#  FreqDist({'and': 1, 'money': 1, 'of': 1, 'time': 1, 'waste': 1}),
#  FreqDist({"'": 1,
#            'a': 1,
#            'history': 1,
#            'in': 1,
#            'irrelevant': 1,
#            'it': 1,
#            'name': 1,
#            'of': 1,
#            'pain': 1,
#            'real': 1,
#            'story': 1,
#            'the': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({'-': 1,
#            'better': 1,
#            'i': 1,
#            'it': 1,
#            'magazine': 1,
#            'mean': 1,
#            'on': 1,
#            'pinup': 1,
#            'sell': 1,
#            'start': 1,
#            'street': 1,
#            'the': 1}),
#  FreqDist({'authority': 1, 'film': 1, 'to': 1, 'yashraj': 1}),
#  FreqDist({'and': 1,
#            'appropriate': 1,
#            'historically': 1,
#            'movie': 1,
#            'worst': 1}),
#  FreqDist({'a': 2, 'as': 1, 'bangladeshi': 1, 'big': 1, 'protest': 1}),
#  FreqDist({'bollywood': 1, 'plzzzzz': 1, 'up': 1, 'wake': 1}),
#  FreqDist({'change': 1,
#            'history': 1,
#            'main': 1,
#            'movie': 1,
#            'the': 1,
#            'this': 1}),
#  FreqDist({'bangladesh': 1,
#            'disaster': 1,
#            'film': 1,
#            'have': 1,
#            'in': 1,
#            'start': 1,
#            'this': 1}),
#  FreqDist({"'s": 1,
#            'against': 1,
#            'bangladesh': 1,
#            'be': 1,
#            'it': 1,
#            'liberation': 1,
#            'pakistan': 1,
#            'war': 1}),
#  FreqDist({'distortion': 1, 'history': 1}),
#  FreqDist({'1971': 1,
#            'history': 1,
#            'liberation': 1,
#            'misrepresentation': 1,
#            'of': 2,
#            'the': 1,
#            'war': 1}),
#  FreqDist({'action': 1,
#            'base': 1,
#            'bollywood': 1,
#            'fact': 1,
#            'film': 1,
#            'its': 1,
#            'masala': 1,
#            'not': 1,
#            'on': 1}),
#  FreqDist({'and': 1, 'illiterate': 1, 'producer': 1, 'uneducated': 1}),
#  FreqDist({'and': 1,
#            'director': 1,
#            'ignorant': 1,
#            'of': 1,
#            'poor': 1,
#            'reflect': 1,
#            'script': 1,
#            'stupidity': 1,
#            'writer': 1}),
#  FreqDist({'history': 1,
#            'in': 1,
#            'movie': 1,
#            'the': 1,
#            'world': 1,
#            'worst': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({'1971': 1,
#            ':': 1,
#            'bangladesh': 1,
#            'history': 1,
#            'in': 1,
#            'liberation': 1,
#            'misinterpret': 1,
#            'of': 1,
#            'protest': 1,
#            'the': 1,
#            'war': 1}),
#  FreqDist({'i': 1, 'movie': 1, 'protest': 1, 'strongly': 1, 'this': 1}),
#  FreqDist({"'s": 1,
#            ':': 1,
#            'bangladesh': 1,
#            'gunday': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulating': 1,
#            'war': 1}),
#  FreqDist({'disappoint': 1}),
#  FreqDist({'be': 1,
#            'entertainment': 1,
#            'for': 1,
#            'only': 1,
#            'sucker': 1,
#            'we': 1}),
#  FreqDist({'rubbish': 1}),
#  FreqDist({'history': 1, 'wrong': 1}),
#  FreqDist({'a': 1,
#            'bunch': 1,
#            'but': 1,
#            'in': 1,
#            'lie': 1,
#            'movie': 1,
#            'nothing': 1,
#            'of': 1,
#            'this': 1}),
#  FreqDist({'1971': 1,
#            'bangladesh': 1,
#            'humiliate': 1,
#            'liberation': 1,
#            'of': 1,
#            'the': 1,
#            'war': 1}),
#  FreqDist({'bangladesh': 1,
#            'humilation': 1,
#            'liberation': 1,
#            'of': 1,
#            'war': 1}),
#  FreqDist({"'s": 1,
#            ':': 1,
#            'an': 1,
#            'bangladesh': 1,
#            'extreme': 1,
#            'gunday': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulation': 1,
#            'of': 1,
#            'war': 1}),
#  FreqDist({'...': 1,
#            'a': 1,
#            'aditya': 1,
#            'be': 1,
#            'chopra': 1,
#            'fake': 1,
#            'famous': 1,
#            'have': 1,
#            'history': 1,
#            'lame': 1,
#            'like': 1,
#            'make': 1,
#            'movie': 1,
#            'not': 1,
#            'of': 1,
#            'producer': 1,
#            'should': 1,
#            'this': 2,
#            'type': 1,
#            'with': 1}),
#  FreqDist({'against': 1,
#            'false': 1,
#            'historical': 1,
#            'statement': 1,
#            'truth': 1}),
#  FreqDist({'*': 10,
#            'a': 1,
#            'before': 1,
#            'do': 1,
#            'film': 1,
#            'make': 1,
#            'more': 1,
#            'need': 1,
#            'research': 1,
#            'to': 1,
#            'writer': 1}),
#  FreqDist({'/': 1, ':': 1, 'disgust': 1, 'movie': 1, 'yuck': 1}),
#  FreqDist({'and': 1,
#            'bangladesh': 1,
#            'disrespectful': 1,
#            'history': 1,
#            'humiliating': 1,
#            'most': 1,
#            'of': 1,
#            'offensive': 1,
#            'the': 1,
#            'to': 1}),
#  FreqDist({'bangladesh': 1,
#            'be': 1,
#            'history': 1,
#            'liberation': 1,
#            'of': 1,
#            'plot': 1,
#            'war': 1,
#            'wrongly': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({'a': 1, 'and': 1, 'fake': 1, 'history': 1, 'starting': 1}),
#  FreqDist({'movie': 1,
#            'of': 1,
#            'on': 1,
#            'shame': 1,
#            'team': 1,
#            'the': 1,
#            'this': 1,
#            'whole': 1}),
#  FreqDist({'an': 1,
#            'and': 1,
#            'awful': 1,
#            'flase': 1,
#            'information': 1,
#            'movie': 1}),
#  FreqDist({'critic': 1}),
#  FreqDist({"'s": 1,
#            'contempt': 1,
#            'liberation': 1,
#            'line': 1,
#            'movie': 1,
#            'our': 1,
#            'story': 1,
#            'this': 1,
#            'war': 1}),
#  FreqDist({'bangladesh': 1,
#            'disaster': 1,
#            'film': 1,
#            'have': 1,
#            'in': 1,
#            'start': 1,
#            'this': 1}),
#  FreqDist({'act': 1,
#            'and': 1,
#            'appal': 1,
#            'bad': 1,
#            'fact': 1,
#            'find': 1,
#            'plot': 1,
#            'poor': 1,
#            'possible': 1}),
#  FreqDist({':': 1,
#            'history': 1,
#            'must': 1,
#            'poor': 1,
#            'properly': 1,
#            'read': 1,
#            'screenplay': 1,
#            'writer': 1}),
#  FreqDist({'&': 1,
#            '...': 1,
#            'fraudulent': 1,
#            'historically': 1,
#            'laughable': 1,
#            'offensive': 1}),
#  FreqDist({'``': 2,
#            'bangladesh': 1,
#            'gunday': 1,
#            'history': 1,
#            'humiliate': 1,
#            'of': 1}),
#  FreqDist({'about': 1,
#            'bangladesh': 1,
#            'do': 1,
#            'false': 1,
#            'have': 1,
#            'information': 1,
#            'liberation': 1,
#            'movie': 1,
#            'not': 1,
#            'please': 1,
#            'the': 1,
#            'war': 1,
#            'watch': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({'bad': 1, 'movie': 1}),
#  FreqDist({"'": 1,
#            'abusive': 1,
#            'all': 1,
#            'can': 1,
#            'i': 1,
#            'say': 1,
#            'that': 1}),
#  FreqDist({'1971': 1,
#            'change': 1,
#            'history': 1,
#            'movie': 1,
#            'of': 2,
#            'the': 2,
#            'this': 1,
#            'war': 1}),
#  FreqDist({'fake': 1, 'information': 1}),
#  FreqDist({'bad': 1, 'movie': 1}),
#  FreqDist({'best': 1,
#            'ever': 1,
#            'historical': 1,
#            'lame': 1,
#            'movie': 1,
#            'the': 1,
#            'very': 1}),
#  FreqDist({'pity': 1, 'shame': 1}),
#  FreqDist({'hell': 1, 'the': 1, 'what': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({'protest': 1}),
#  FreqDist({'distortion': 1, 'fatal': 1, 'history': 1}),
#  FreqDist({"'s": 1,
#            'and': 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulating': 1,
#            'movie': 1,
#            'war': 1,
#            'worst': 1}),
#  FreqDist({"'s": 1,
#            'against': 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulation': 1,
#            'of': 2,
#            'pakistan': 1,
#            'war': 1}),
#  FreqDist({'about': 1,
#            'bangladesh': 1,
#            'contain': 1,
#            'history': 1,
#            'liberation': 1,
#            'movie': 1,
#            'of': 2,
#            'this': 1,
#            'war': 1,
#            'wrong': 1}),
#  FreqDist({'...': 1,
#            'action': 1,
#            'and': 1,
#            'apologize': 1,
#            'be': 1,
#            'consider': 1,
#            'correct': 1,
#            'different': 1,
#            'else': 1,
#            'film': 1,
#            'have': 1,
#            'in': 1,
#            'mistake': 2,
#            'or': 1,
#            'take': 1,
#            'thank': 1,
#            'the': 2,
#            'therefore': 1,
#            'to': 3,
#            'u': 1,
#            'unintended': 1,
#            'we': 2,
#            'will': 1,
#            'you': 1,
#            'your': 1}),
#  FreqDist({'always': 1, 'as': 1, 'bollywood': 1, 'movies-': 1, 'shitty': 1}),
#  FreqDist({"'s": 1, 'a': 1, 'comment': 1, 'critic': 1}),
#  FreqDist({"'s": 1,
#            'a': 1,
#            'country': 1,
#            'history': 1,
#            'libereation': 1,
#            'misrepresentation': 1,
#            'of': 1,
#            'war': 1}),
#  FreqDist({'a': 1,
#            'be': 1,
#            'my': 1,
#            'of': 1,
#            'this': 1,
#            'time': 1,
#            'waste': 1}),
#  FreqDist({'(': 1,
#            ')': 1,
#            '2014': 1,
#            ':': 1,
#            'a': 1,
#            'gunday': 1,
#            'quack': 1,
#            'story': 1,
#            'totally': 1}),
#  FreqDist({'a': 1,
#            'and': 1,
#            'background': 1,
#            'no': 1,
#            'research': 1,
#            'rubbish': 1,
#            'study': 1,
#            'with': 1}),
#  FreqDist({'history': 1, 'misinterpret': 1}),
#  FreqDist({'about': 1, 'history': 1, 'idea': 1, 'no': 1}),
#  FreqDist({'alteration': 1,
#            'history': 1,
#            'movie': 1,
#            'of': 1,
#            'with': 1,
#            'worst': 1}),
#  FreqDist({"'": 1,
#            'button': 1,
#            'in': 1,
#            'it': 1,
#            'negative': 1,
#            'rate': 1,
#            'the': 1,
#            'to': 1,
#            'where': 1}),
#  FreqDist({'apologize': 1,
#            'but': 1,
#            'correct': 1,
#            'do': 1,
#            'mistake': 1,
#            'not': 1,
#            'only': 1,
#            'the': 1,
#            'to': 1,
#            'u': 1}),
#  FreqDist({'be': 1, 'film': 1, 'maker': 1, 'uneducated': 1}),
#  FreqDist({'3': 1,
#            'a': 1,
#            'be': 2,
#            'deal': 1,
#            'die': 1,
#            'dude': 1,
#            'fiction': 1,
#            'history': 1,
#            'it': 1,
#            'million': 1,
#            'not': 1,
#            'of': 1,
#            'people': 1,
#            'piece': 1,
#            'specially': 1,
#            'when': 1,
#            'where': 1,
#            'with': 1,
#            'you': 1}),
#  FreqDist({'...': 1,
#            'a': 1,
#            'be': 1,
#            'history': 1,
#            'misrepresentation': 1,
#            'of': 1,
#            'the': 1,
#            'this': 1}),
#  FreqDist({'a': 1, 'bad': 1, 'try': 1}),
#  FreqDist({'a': 1, 'it': 1, 'pas': 1, 'that': 1, 'time': 1}),
#  FreqDist({'-': 1, '``': 2, 'a': 1, 'gunday': 1, 'movie': 1, 'rabish': 1}),
#  FreqDist({'against': 1,
#            'alteration': 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'of': 3,
#            'protest': 1,
#            'war': 1}),
#  FreqDist({'bad': 1, 'script': 1}),
#  FreqDist({'a': 2,
#            'bloody': 1,
#            'deliberate': 1,
#            'distortion': 1,
#            'history': 1,
#            'of': 1}),
#  FreqDist({'shame': 1}),
#  FreqDist({'against': 1,
#            'history': 1,
#            'humiliation': 1,
#            'of': 1,
#            'protest': 1,
#            'strong': 1,
#            'the': 1}),
#  FreqDist({'and': 1, 'money': 1, 'of': 1, 'time': 1, 'waste': 1}),
#  FreqDist({'film': 1, 'good': 1, 'very': 2}),
#  FreqDist({'false': 1, 'historical': 1, 'presentation': 1}),
#  FreqDist({'be': 1,
#            'but': 1,
#            'do': 1,
#            'entertain': 1,
#            'entertainment': 1,
#            'hearted': 1,
#            'indian': 1,
#            'know': 1,
#            'movie': 1,
#            'need': 2,
#            'not': 1,
#            'only': 1,
#            'others': 1,
#            'they': 2}),
#  FreqDist({'protest': 1, 'strongly': 1}),
#  FreqDist({'and': 1, 'energy': 1, 'of': 1, 'time': 1, 'waste': 1}),
#  FreqDist({'-': 1,
#            'a': 1,
#            'bangladesh': 1,
#            'be': 1,
#            'india': 1,
#            'not': 1,
#            'of': 1,
#            'pakistan': 1,
#            'product': 1,
#            'war': 1}),
#  FreqDist({'a': 1,
#            'be': 1,
#            'big': 1,
#            'but': 1,
#            'can': 1,
#            'change': 1,
#            'do': 1,
#            'film': 1,
#            'history': 1,
#            'it': 1,
#            'mean': 1,
#            'name': 1,
#            'not': 1,
#            'our': 1,
#            'raj': 1,
#            'that': 1,
#            'u': 1,
#            'yash': 1}),
#  FreqDist({"'": 1,
#            'a': 1,
#            'bangladesh': 1,
#            'be': 1,
#            'freedom': 1,
#            'it': 1,
#            'message': 1,
#            'movie': 1,
#            'of': 1,
#            'regard': 1,
#            'send': 1,
#            'the': 2,
#            'to': 1,
#            'viewer': 1,
#            'war': 1,
#            'wrong': 1}),
#  FreqDist({'all': 1,
#            'culprit': 1,
#            'for': 1,
#            'maker': 1,
#            'movie': 1,
#            'of': 2,
#            'shame': 1,
#            'this': 1}),
#  FreqDist({'protest': 1}),
#  FreqDist({'bangladesh': 1, 'history': 1, 'manipulation': 1, 'of': 1}),
#  FreqDist({'bangladesh': 1,
#            'gunday': 1,
#            'history': 1,
#            'humiliated': 1,
#            'of': 1}),
#  FreqDist({'about': 1,
#            'background': 1,
#            'historical': 1,
#            'the': 1,
#            'worng': 1}),
#  FreqDist({'``': 2,
#            'a': 1,
#            'against': 1,
#            'bangladesh': 1,
#            'be': 1,
#            'face': 1,
#            'gunday': 1,
#            'indian': 1,
#            'liberation': 1,
#            'movie': 1,
#            'of': 2,
#            'the': 1,
#            'thought': 1,
#            'war': 1,
#            'which': 1}),
#  FreqDist({'history': 1, 'manipulate': 1}),
#  FreqDist({"'": 1,
#            "'s": 1,
#            'and': 2,
#            'armed': 1,
#            'bangladesh': 1,
#            'force': 1,
#            'it': 1,
#            'liberation': 1,
#            'manipulation': 1,
#            'misrepresentation': 1,
#            'of': 1,
#            'war': 1}),
#  FreqDist({'at': 1,
#            'bangladesh': 1,
#            'beginning': 1,
#            'change': 1,
#            'history': 1,
#            'movie': 1,
#            'of': 2,
#            'the': 1,
#            'they': 1,
#            'this': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({'&': 1, 'historically': 1, 'inaccurate': 1, 'offensive': 1}),
#  FreqDist({'a': 1,
#            'and': 1,
#            'full': 1,
#            'lie': 1,
#            'manipulation': 1,
#            'movie': 1,
#            'of': 1}),
#  FreqDist({'(': 1, ')': 1, 'fairy': 1, 'rubbish': 1, 'tale': 1, 'witch': 1}),
#  FreqDist({'a': 1,
#            'as': 1,
#            'bangladeshi': 1,
#            'i': 1,
#            'protest': 1,
#            'strongly': 1}),
#  FreqDist({"'": 1,
#            'a': 1,
#            'and': 1,
#            'bangladesh': 1,
#            'history': 1,
#            'it': 1,
#            'mockery': 1,
#            'of': 2,
#            'pride': 1}),
#  FreqDist({'and': 1,
#            'be': 2,
#            'court': 1,
#            'film': 1,
#            'justice': 1,
#            'movie': 1,
#            'of': 1,
#            'raj': 1,
#            'should': 2,
#            'sued': 1,
#            'take': 1,
#            'the': 1,
#            'this': 1,
#            'to': 1,
#            'yash': 1}),
#  FreqDist({'and': 1,
#            'awful': 1,
#            'be': 1,
#            'but': 1,
#            'direction': 1,
#            'enough': 1,
#            'financially': 1,
#            'grow': 1,
#            'gunday-': 1,
#            'help': 1,
#            'lame': 1,
#            'may': 1,
#            'script': 1,
#            'that': 1,
#            'up': 1,
#            'you': 1,
#            'yrf': 1}),
#  FreqDist({'a': 1,
#            'as': 1,
#            'bangladeshi': 1,
#            'i': 1,
#            'protest': 1,
#            'strongly': 1}),
#  FreqDist({'corruption': 1, 'history': 1, 'of': 1}),
#  FreqDist({'a': 2,
#            'and': 1,
#            'country': 1,
#            'film': 1,
#            'honor': 1,
#            'independent': 1,
#            'tamper': 1,
#            'which': 1}),
#  FreqDist({'big': 1, 'lie': 1, 'the': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({'-': 1,
#            'actor': 1,
#            'but': 1,
#            'ever': 1,
#            'good': 1,
#            'gunday': 1,
#            'story': 1,
#            'worst': 1}),
#  FreqDist({'completely': 1, 'nonsense': 1}),
#  FreqDist({'game': 1, 'play': 1, 'video': 1}),
#  FreqDist({'contains': 1, 'history': 1, 'international': 1, 'twisted': 1}),
#  FreqDist({'about': 1,
#            'banglladesh': 1,
#            'false': 1,
#            'give': 1,
#            'information': 1,
#            'it': 1,
#            'liberation': 1,
#            'of': 1,
#            'war': 1}),
#  FreqDist({'a': 2,
#            'bangladeshi': 1,
#            'close': 1,
#            'from': 1,
#            'observation': 1,
#            'viewer': 1}),
#  FreqDist({'history': 1, 'wrong': 1}),
#  FreqDist({'morality': 1, 'movie': 1, 'of': 1, 'the': 1}),
#  FreqDist({'bad': 1,
#            'ever': 1,
#            'film': 1,
#            'gunday': 1,
#            'history': 1,
#            'in': 1,
#            'make': 1,
#            'the': 1}),
#  FreqDist({'(': 1,
#            ')': 1,
#            'history': 1,
#            'importantly': 1,
#            'misrepresentation': 1,
#            'most': 1,
#            'of': 1,
#            'the': 1}),
#  FreqDist({'history': 1, 'wrong': 1}),
#  FreqDist({'and': 1,
#            'associate': 1,
#            'film': 1,
#            'for': 1,
#            'hate': 1,
#            'its': 1,
#            'only': 1,
#            'this': 1}),
#  FreqDist({'bangladesh': 1,
#            'disrespectful': 1,
#            'fact': 1,
#            'liberation': 1,
#            'manipulation': 1,
#            'misleading': 1,
#            'of': 3,
#            'overall': 1,
#            'the': 1,
#            'war': 1}),
#  FreqDist({'.': 1,
#            '...': 1,
#            'a': 1,
#            'be': 1,
#            'disgrace': 1,
#            'this': 1,
#            'total': 1}),
#  FreqDist({',': 1,
#            'bangladesh': 1,
#            'by': 1,
#            'fake': 1,
#            'history': 1,
#            'insult': 1,
#            'put': 1,
#            'story': 1,
#            'tradition': 1}),
#  FreqDist({'review': 1}),
#  FreqDist({'history': 1, 'lawra': 1, 'wrong': 1}),
#  FreqDist({'-1.00': 1,
#            '.': 1,
#            '...': 3,
#            'baddest': 1,
#            'ever': 1,
#            'most': 1,
#            'movie': 1,
#            'rat': 1,
#            'world': 1}),
#  FreqDist({'be': 1,
#            'film': 1,
#            'liberation': 1,
#            'our': 1,
#            'pervert': 1,
#            'this': 1,
#            'war': 1}),
#  FreqDist({"'s": 1,
#            'a': 1,
#            'as': 1,
#            'bangladesh': 1,
#            'bangladeshi': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'protest': 1,
#            'war': 1}),
#  FreqDist({'bad': 1, 'movie': 1}),
#  FreqDist({'-': 1, 'intellectualism': 1, 'pseudo': 1}),
#  FreqDist({'a': 1, 'for': 1, 'its': 1, 'shame': 1, 'such': 1, 'yrf': 1}),
#  FreqDist({'history': 1, 'insult': 1, 'the': 1, 'yrf': 1}),
#  FreqDist({'a': 2,
#            'accurate': 1,
#            'be': 2,
#            'but': 1,
#            'fact': 1,
#            'fiction': 1,
#            'historical': 1,
#            'it': 1,
#            'movie': 1,
#            'of': 1,
#            'should': 1,
#            'that': 1,
#            'use': 1,
#            'when': 1,
#            'work': 1}),
#  FreqDist({"'s": 1,
#            'about': 1,
#            'bangladesh': 1,
#            'false': 1,
#            'information': 1,
#            'liberation': 1,
#            'war': 1}),
#  FreqDist({'1971': 1,
#            'about': 1,
#            'and': 1,
#            'bangladesh': 1,
#            'base': 1,
#            'false': 1,
#            'information': 1,
#            'liberation': 1,
#            'of': 1,
#            'on': 1,
#            'rubbish': 1,
#            'storyline': 1,
#            'war': 1}),
#  FreqDist({'against': 1,
#            'i': 1,
#            'idiocy': 1,
#            'movie': 1,
#            'of': 1,
#            'protest': 1,
#            'the': 2}),
#  FreqDist({'bullsit': 1, 'movie': 1}),
#  FreqDist({'a': 1,
#            'and': 1,
#            'base': 1,
#            'business': 1,
#            'cheap': 1,
#            'fallacy': 1,
#            'movie': 1,
#            'on': 1}),
#  FreqDist({'a': 1,
#            'all': 1,
#            'bangladesh': 1,
#            'be': 1,
#            'face': 1,
#            'of': 2,
#            'on': 1,
#            'people': 1,
#            'slap': 1,
#            'the': 2,
#            'this': 1}),
#  FreqDist({'history': 1, 'manipulation': 1, 'of': 1}),
#  FreqDist({'crap': 3, 'that': 1}),
#  FreqDist({"'": 1, 'history': 1, 'it': 1, 'manupulated': 1, 'the': 1}),
#  FreqDist({'disgust': 1}),
#  FreqDist({'a': 1,
#            'bad': 1,
#            'good': 1,
#            'history': 1,
#            'story': 1,
#            'temper': 1,
#            'the': 1,
#            'to': 1,
#            'try': 1,
#            'very': 1}),
#  FreqDist({'by': 1,
#            'history': 1,
#            'insane': 1,
#            'manipulate': 1,
#            'the': 1,
#            'title': 1}),
#  FreqDist({"'": 1,
#            '...': 1,
#            'a': 1,
#            'but': 1,
#            'distortion': 1,
#            'film': 1,
#            'great': 1,
#            'history': 1,
#            'nasty': 1,
#            'nothing': 1,
#            'of': 1,
#            'such': 1,
#            'there': 1}),
#  FreqDist({'bad': 1,
#            'bangladesh': 1,
#            'for': 1,
#            'history': 2,
#            'in': 1,
#            'movie': 1,
#            'plot': 1,
#            'the': 1,
#            'wrongly': 1}),
#  FreqDist({'how': 1,
#            'indian': 1,
#            'know': 1,
#            'others': 1,
#            'people': 1,
#            'respect': 1,
#            'should': 1,
#            'to': 1}),
#  FreqDist({'a': 1,
#            'and': 1,
#            'be': 1,
#            'foul': 1,
#            'gunday': 1,
#            'movie': 1,
#            'rubbish': 1}),
#  FreqDist({'authority': 1, 'dear': 1, 'film': 1, 'greeting': 1, 'yashraj': 1}),
#  FreqDist({'act': 1,
#            'and': 1,
#            'cinematography': 1,
#            'excellent': 1,
#            'interesting': 1,
#            'locale': 1,
#            'plot': 1,
#            'stunning': 1}),
#  FreqDist({'comedy': 1, 'excellent': 1, 'film': 1}),
#  FreqDist({'attempt': 1,
#            'be': 1,
#            'come': 1,
#            'daring': 1,
#            'gunday': 1,
#            'out': 1,
#            'this': 1,
#            'to': 1,
#            'year': 1}),
#  FreqDist({'bad': 1,
#            'ever': 1,
#            'have': 1,
#            'hindi': 1,
#            'i': 1,
#            'movie': 1,
#            'of': 1,
#            'one': 1,
#            'see': 1,
#            'the': 1}),
#  FreqDist({'rotten': 1, 'tomatoo': 1}),
#  FreqDist({',': 1,
#            'a': 1,
#            'disrespectful': 1,
#            'fraudulent': 1,
#            'misleading': 1,
#            'nation': 1,
#            'of': 1,
#            'sovereignty': 1,
#            'the': 1,
#            'to': 1}),
#  FreqDist({'protest': 1}),
#  FreqDist({'bollywood': 1,
#            'how': 1,
#            'kind': 1,
#            'movie': 1,
#            'of': 1,
#            'release': 1,
#            'this': 1}),
#  FreqDist({'bad': 1,
#            'cinema': 1,
#            'history': 1,
#            'in': 1,
#            'movie': 1,
#            'of': 1,
#            'plot': 1,
#            'the': 1}),
#  FreqDist({'history': 1, 'on': 1, 'present': 1, 'protest': 1, 'wrong': 1}),
#  FreqDist({'&': 1,
#            '(': 1,
#            ')': 1,
#            '...': 1,
#            'fraudulent': 1,
#            'historically': 1,
#            'importantly': 1,
#            'laughable': 1,
#            'most': 1,
#            'offensive': 1}),
#  FreqDist({'a': 1,
#            'and': 1,
#            'factually': 1,
#            'inaccurate': 1,
#            'killjoy': 1,
#            'total': 1}),
#  FreqDist({'-': 1,
#            'a': 1,
#            'and': 2,
#            'attempt': 1,
#            'before': 1,
#            'cheesiness': 1,
#            'creepy': 1,
#            'disturb': 1,
#            'foolish': 1,
#            'get': 1,
#            'group': 1,
#            'hate': 1,
#            'hindustan': 1,
#            'i': 1,
#            'into': 1,
#            'kill': 1,
#            'me': 1,
#            'of': 1,
#            'someone': 1}),
#  FreqDist({'a': 3,
#            'actually': 1,
#            'be': 1,
#            'contain': 1,
#            'devyani': 1,
#            'if': 1,
#            'in': 1,
#            'khobragade': 1,
#            'movie': 1,
#            'on': 1,
#            'prostitute': 1,
#            'she': 1,
#            'storyline': 1,
#            'that': 1,
#            'the': 1,
#            'u': 1,
#            'what': 1,
#            'would': 1}),
#  FreqDist({'learn': 1, 'respect': 1, 'to': 1}),
#  FreqDist({'a': 1,
#            'nation': 1,
#            'proper': 1,
#            'respect': 1,
#            'show': 1,
#            'the': 1,
#            'to': 1}),
#  FreqDist({'a': 1,
#            'against': 1,
#            'as': 1,
#            'bangladeshi': 1,
#            'be': 1,
#            'i': 1,
#            'you': 1}),
#  FreqDist({'be': 1, 'fake': 1, 'intro': 1, 'the': 1}),
#  FreqDist({'a': 1, 'base': 1, 'false': 1, 'history': 1, 'movie': 1, 'on': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({'1971': 1,
#            'a': 1,
#            'and': 3,
#            'bangladesh': 1,
#            'be': 3,
#            'between': 2,
#            'but': 1,
#            'change': 1,
#            'director': 1,
#            'happen': 1,
#            'india': 1,
#            'main': 1,
#            'movie': 1,
#            'on': 1,
#            'pakistan': 2,
#            'story': 2,
#            'tell': 1,
#            'that': 2,
#            'the': 2,
#            'war': 2}),
#  FreqDist({'fraud': 1, 'history': 1, 'with': 1}),
#  FreqDist({'just': 1,
#            'love': 1,
#            'masala': 1,
#            'movie': 1,
#            'to': 1,
#            'total': 1,
#            'watch': 1,
#            'which': 1,
#            'you': 1}),
#  FreqDist({'fare': 1,
#            'good': 1,
#            'historically': 1,
#            'incorrect': 1,
#            'though': 1}),
#  FreqDist({'act': 1,
#            'arjun': 1,
#            'chopra': 1,
#            'kapoor': 1,
#            'of': 1,
#            'poor': 1,
#            'priyanka': 1,
#            'ranveer': 1,
#            'rubbish': 1,
#            'singh': 1,
#            'time': 1,
#            'waste': 1}),
#  FreqDist({'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'of': 1,
#            'war': 1,
#            'wrong': 1}),
#  FreqDist({'line': 1, 'time': 1, 'wrong': 1}),
#  FreqDist({'despicable': 1}),
#  FreqDist({'bangladeshi': 1, 'humiliating': 1, 'liberation': 1, 'war': 1}),
#  FreqDist({'act': 1,
#            'by': 1,
#            'producer': 1,
#            'shameful': 1,
#            'the': 1,
#            'very': 1}),
#  FreqDist({'distortion': 1,
#            'history': 1,
#            'liberation': 1,
#            'of': 2,
#            'our': 1,
#            'the': 1,
#            'war': 1}),
#  FreqDist({'apology': 1, 'be': 1, 'enough': 1, 'not': 1}),
#  FreqDist({"'s": 1, 'india': 1, 'worst': 1}),
#  FreqDist({'bring': 1,
#            'for': 1,
#            'gunday': 1,
#            'justice': 1,
#            'should': 1,
#            'them': 1,
#            'to': 1}),
#  FreqDist({'a': 1,
#            'ever': 1,
#            'historical': 1,
#            'movie': 1,
#            'pathetic': 1,
#            'see': 1}),
#  FreqDist({'and': 1,
#            'historical': 1,
#            'in': 1,
#            'indian': 1,
#            'industry': 1,
#            'lie': 1,
#            'most': 1,
#            'movie': 1,
#            'the': 1,
#            'ugly': 1}),
#  FreqDist({'protest': 1}),
#  FreqDist({'a': 1,
#            'acting': 1,
#            'bad': 1,
#            'complete': 1,
#            'line': 1,
#            'of': 1,
#            'rubbish': 1,
#            'story': 1,
#            'time': 1,
#            'waste': 1}),
#  FreqDist({'and': 1,
#            'event': 1,
#            'information': 1,
#            'irrelevant': 1,
#            'time': 1,
#            'waste': 1}),
#  FreqDist({'gunday': 1, 'no': 1, 'say': 1, 'to': 1}),
#  FreqDist({'...': 1,
#            'even': 1,
#            'go': 1,
#            'how': 1,
#            'it': 1,
#            'know': 1,
#            'one': 1,
#            'this': 1,
#            'watch': 1,
#            'we': 1,
#            'will': 1,
#            'without': 1}),
#  FreqDist({'-1': 1, 'rating': 1, 'true': 1}),
#  FreqDist({'good': 1, 'grief': 1, 'oh': 1}),
#  FreqDist({'$': 1,
#            "'": 1,
#            '1': 1,
#            'bin': 1,
#            'but': 1,
#            'enjoy': 1,
#            'i': 2,
#            'in': 1,
#            'it': 1,
#            'suggest': 1,
#            'the': 1,
#            'this': 1,
#            'until': 1,
#            'wait': 1}),
#  FreqDist({'bother': 1, 'do': 1, 'not': 1}),
#  FreqDist({'a': 1,
#            'bad': 1,
#            'in': 1,
#            'long': 2,
#            'movie': 1,
#            'of': 1,
#            'one': 1,
#            'the': 1,
#            'time': 1}),
#  FreqDist({'away': 1,
#            'from': 1,
#            'movie': 1,
#            'please': 2,
#            'stay': 1,
#            'this': 1}),
#  FreqDist({'bread': 1, 'few': 1, 'for': 1, 'inane': 1, 'loaf': 1}),
#  FreqDist({'(': 1,
#            ')': 1,
#            '1996': 1,
#            '``': 2,
#            'day': 1,
#            'independence': 1,
#            'not': 1,
#            'sequel': 1,
#            'the': 1,
#            'to': 1}),
#  FreqDist({'sandwich': 1, 'sh*t': 1}),
#  FreqDist({'act': 1, 'bad': 1, 'poorly': 1}),
#  FreqDist({'a': 1,
#            'dime': 1,
#            'do': 1,
#            'not': 1,
#            'on': 1,
#            'one': 1,
#            'spend': 1,
#            'this': 1}),
#  FreqDist({'bad': 1, 'huh': 1, 'that': 1, 'wow': 1}),
#  FreqDist({'be': 1, 'movie': 1, 'remarkable': 1, 'this': 1}),
#  FreqDist({'action': 1,
#            'b': 1,
#            'day': 1,
#            'independent': 1,
#            'movie': 1,
#            'perfect': 1,
#            'scfi': 1}),
#  FreqDist({'bad': 2, 'really': 1}),
#  FreqDist({'2': 1,
#            'do': 1,
#            'even': 1,
#            'life': 1,
#            'minute': 1,
#            'not': 1,
#            'of': 1,
#            'on': 1,
#            'this': 1,
#            'waste': 1,
#            'your': 1}),
#  FreqDist({'ever': 1, 'have': 1, 'i': 1, 'movie': 1, 'pathetic': 1, 'see': 1}),
#  FreqDist({'bad': 1, 'ever': 1, 'have': 1, 'i': 1, 'see': 1, 'the': 1}),
#  FreqDist({'(': 1,
#            ')': 1,
#            'a': 1,
#            'and': 1,
#            'bit': 1,
#            "c'mon": 1,
#            'expectation': 1,
#            'lighten': 1,
#            'lower': 1,
#            'mild': 1,
#            'people': 1,
#            'spoiler': 1,
#            'up': 1,
#            'your': 1}),
#  FreqDist({'pallin': 1, 'sarah': 1}),
#  FreqDist({'movie': 1, 'the': 1, 'worst': 1}),
#  FreqDist({"'": 2,
#            'a': 1,
#            'be': 1,
#            'if': 1,
#            'it': 1,
#            'make': 1,
#            'may': 1,
#            'sense': 1,
#            'spoof': 1,
#            'truly': 1}),
#  FreqDist({'-': 1,
#            'bad': 1,
#            'be': 1,
#            'can': 1,
#            'fi': 1,
#            'really': 1,
#            'sci': 1,
#            'that': 1}),
#  FreqDist({'budget': 1, 'for': 1, 'good': 1, 'low': 1, 'movie': 1}),
#  FreqDist({'about': 1,
#            'be': 1,
#            'confused': 1,
#            'film': 1,
#            'people': 1,
#            'this': 1}),
#  FreqDist({'a': 2,
#            'be': 1,
#            'budget': 1,
#            'but': 1,
#            'enough': 1,
#            'film': 2,
#            'for': 1,
#            'good': 1,
#            'low': 1,
#            'movie': 1,
#            'must': 1,
#            'not': 1,
#            'ok': 1,
#            'see': 1,
#            'to': 1}),
#  FreqDist({'3-d': 1,
#            'adult': 1,
#            'amuse': 1,
#            'and': 2,
#            'be': 1,
#            'both': 1,
#            'but': 1,
#            'do': 1,
#            'enough': 1,
#            'for': 1,
#            'kid': 1,
#            'me': 1,
#            'not': 1,
#            'silliness': 1,
#            'still': 1,
#            'style': 1,
#            'the': 1,
#            'there': 1,
#            'thing': 1,
#            'to': 1,
#            'work': 1}),
#  FreqDist({'irredeemably': 1, 'stupid': 1}),
#  FreqDist({'be': 1,
#            'but': 1,
#            'for': 1,
#            'fun': 1,
#            'get': 1,
#            'little': 1,
#            'one': 1,
#            'series': 1,
#            'stale': 1,
#            'the': 2}),
#  FreqDist({'but': 1, 'fun': 1, 'not': 1, 'overwhelming': 1}),
#  FreqDist({'it': 1, 'kid': 1, 'like': 1, 'my': 1}),
#  FreqDist({'...': 1,
#            '3-d': 1,
#            'at': 1,
#            'average': 1,
#            'be': 1,
#            'best': 1,
#            'have': 1,
#            'the': 1,
#            'without': 1,
#            'would': 1}),
#  FreqDist({'latin': 1, 'magic': 1}),
#  FreqDist({'3-d': 1,
#            'be': 2,
#            'but': 1,
#            'film': 1,
#            'flat': 1,
#            'it': 1,
#            'may': 1,
#            'still': 1,
#            'the': 1}),
#  FreqDist({'a': 1,
#            'bad': 1,
#            'end': 1,
#            'franchise': 1,
#            'kid': 1,
#            'note': 1,
#            'on': 1,
#            'spy': 1,
#            'the': 1}),
#  FreqDist({'game': 1, 'indeed': 1, 'over': 1}),
#  FreqDist({'all': 1, 'expectation': 1, 'surpass': 1}),
#  FreqDist({'any': 1,
#            'do': 1,
#            'have': 1,
#            'if': 1,
#            'movie': 1,
#            'not': 1,
#            'sense': 1,
#            'this': 1,
#            'watch': 1,
#            'you': 1}),
#  FreqDist({'-': 1,
#            '3-d': 1,
#            'adventure': 1,
#            'an': 1,
#            'exciting': 1,
#            'for': 1,
#            'glass': 1,
#            'in': 1,
#            'it': 1,
#            'kid': 1,
#            'little': 1,
#            'mostly': 1,
#            'see': 1,
#            'your': 1}),
#  FreqDist({'best': 1,
#            'fun': 1,
#            'installment': 1,
#            'make': 1,
#            'one': 1,
#            'the': 1,
#            'third': 1,
#            'this': 1,
#            'virtual': 1,
#            'virtually': 1}),
#  FreqDist({'cheesy': 1, 'comic': 1, 'fun': 1}),
#  FreqDist({'-': 1, 'film': 1, 'put-together': 1, 'well': 1}),
#  FreqDist({'.': 1,
#            '...': 1,
#            '3-d': 1,
#            'a': 1,
#            'be': 1,
#            'clearly': 1,
#            'creative': 1,
#            'filmmaker': 1,
#            'gifted': 1,
#            'hamper': 1,
#            'he': 1,
#            'his': 1,
#            'imagination': 1,
#            'let': 1,
#            'rodriguez': 1,
#            'the': 1,
#            'while': 1}),
#  FreqDist({'and': 1,
#            'better': 1,
#            'cute': 1,
#            'second': 1,
#            'than': 1,
#            'the': 1}),
#  FreqDist({"'": 1, '3d': 1, 'good': 1, 'that': 1}),
#  FreqDist({'flippies': 1, 'ridiculous': 1}),
#  FreqDist({'all': 1, 'expectation': 1, 'surpass': 1}),
#  FreqDist({'-': 1, 'computer': 1, 'in': 1, 'land': 1, 'lose': 1}),
#  FreqDist({'cool': 1, 'fun': 1, 'very': 1}),
#  FreqDist({'horrid': 1}),
#  FreqDist({'a': 1,
#            'break': 1,
#            'come': 1,
#            'give': 1,
#            'it': 1,
#            'on': 1,
#            'people': 1}),
#  FreqDist({'a': 1,
#            'disappointing': 1,
#            'end': 1,
#            'series': 1,
#            'the': 1,
#            'to': 1}),
#  FreqDist({'3': 2,
#            'all': 1,
#            'be': 1,
#            'best': 1,
#            'but': 1,
#            'i': 1,
#            'kid': 1,
#            'like': 1,
#            'movie': 1,
#            'part': 1,
#            'spy': 1,
#            'the': 1}),
#  FreqDist({'be': 1,
#            'cool': 1,
#            'ever': 1,
#            'have': 1,
#            'i': 1,
#            'it': 1,
#            'movie': 1,
#            'see': 1,
#            'the': 1}),
#  FreqDist({'be': 1, 'film': 1, 'great': 1, 'i': 1, 'think': 1, 'this': 1}),
#  FreqDist({'no': 1}),
#  FreqDist({'many': 1, 'so': 1, 'thing': 1}),
#  FreqDist({'be': 1, 'game': 1, 'let': 1, 'over': 1, 'please': 1, 'the': 1}),
#  FreqDist({'3d': 1, 'effect': 1, 'installment': 1, 'the': 1}),
#  FreqDist({'celebrity': 1,
#            'devious': 1,
#            'fill': 1,
#            'flick': 1,
#            'kid': 1,
#            'of': 1,
#            'stallone': 1,
#            'star': 1,
#            'the': 1}),
#  FreqDist({'good': 1, 'really': 1}),
#  FreqDist({'2': 1,
#            'do': 1,
#            'first': 1,
#            'i': 1,
#            'in': 1,
#            'keep': 1,
#            'mind': 1,
#            'not': 1,
#            'see': 1,
#            'that': 1,
#            'the': 1}),
#  FreqDist({'...': 1,
#            'be': 1,
#            'game': 1,
#            'just': 1,
#            'may': 1,
#            'over': 1,
#            'the': 1}),
#  FreqDist({'reward': 1, 'your': 1}),
#  FreqDist({'creative': 1, 'poor': 1, 'story': 1, 'vision': 1}),
#  FreqDist({'a': 1, 'good': 1, 'half': 1, 'movie': 1}),
#  FreqDist({'around': 1,
#            'good': 1,
#            'not': 1,
#            'the': 1,
#            'third': 1,
#            'time': 1,
#            'to': 1}),
#  FreqDist({'(': 1,
#            ')': 1,
#            'as': 1,
#            'be': 1,
#            'cynicism': 1,
#            'do': 1,
#            'hollywood': 1,
#            'if': 1,
#            'know': 1,
#            'name': 1,
#            'not': 1,
#            'they': 1,
#            'we': 1}),
#  FreqDist({'helluva': 1, 'one': 1, 'surprise': 1}),
#  FreqDist({'a': 2,
#            'coda': 1,
#            'do': 1,
#            'film': 1,
#            'fitting': 1,
#            'modestly': 1,
#            'of': 1,
#            'series': 1,
#            'to': 1,
#            'well': 1}),
#  FreqDist({'hate': 1,
#            'love': 1,
#            'may': 2,
#            'see': 1,
#            'some': 2,
#            'though': 1,
#            'worth': 1}),
#  FreqDist({"'": 2,
#            '-': 2,
#            '1': 1,
#            'a': 1,
#            'but': 1,
#            'carmen': 1,
#            'cortez': 1,
#            'ending': 1,
#            'great': 1,
#            'it': 1,
#            'kid': 1,
#            'mom': 1,
#            'need': 1,
#            'new': 1,
#            'spoiler': 1,
#            'spy': 1,
#            'story': 1}),
#  FreqDist({'(': 1,
#            ')': 1,
#            'be': 1,
#            'kid': 1,
#            'movie': 1,
#            'sag': 1,
#            'spoiler': 1,
#            'spy': 1,
#            'start': 1,
#            'the': 1,
#            'to': 1}),
#  FreqDist({'3-d': 1,
#            'a': 1,
#            'be': 1,
#            'of': 1,
#            'thing': 1,
#            'time': 1,
#            'waste': 1}),
#  FreqDist({'eye': 1, 'my': 1, 'oh': 1}),
#  FreqDist({'.': 1,
#            '...': 1,
#            'be': 1,
#            'better': 1,
#            'call': 1,
#            'i': 1,
#            'it': 1,
#            'like': 1,
#            'this': 1,
#            'tron': 1,
#            'when': 1}),
#  FreqDist({'2nd': 1, 'from': 1, 'improved': 1, 'one': 1}),
#  FreqDist({'...': 1,
#            'about': 1,
#            'anyway': 1,
#            'be': 1,
#            'eye': 1,
#            'hurt': 1,
#            'my': 1,
#            'oooo': 1,
#            'this': 1,
#            'what': 1}),
#  FreqDist({'3-d': 1,
#            'as': 1,
#            'dumb': 1,
#            'in': 1,
#            'its': 1,
#            'predecessor': 1,
#            'than': 1,
#            'three': 1,
#            'time': 1}),
#  FreqDist({'good': 1, 'movie': 2, 'star': 2}),
#  FreqDist({'-': 1,
#            'crap': 1,
#            'eye': 1,
#            'i': 1,
#            'little': 1,
#            'my': 1,
#            'spy': 1,
#            'with': 1}),
#  FreqDist({'by': 1,
#            'fx': 1,
#            'great': 1,
#            'save': 1,
#            'special': 1,
#            'story': 1,
#            'thin': 1}),
#  FreqDist({'its': 1, 'ok': 1}),
#  FreqDist({"'": 1, 'for': 1, 'it': 1, 'kid': 1, 'tron': 1}),
#  FreqDist({'big': 1, 'commercial': 1, 'one': 1}),
#  FreqDist({'be': 1, 'but': 1, 'great': 2, 'not': 1, 'so': 1, 'somethings': 1}),
#  FreqDist({'effort': 1, 'i': 1, 'it': 1, 'more': 1, 'need': 1, 'think': 1}),
#  FreqDist({'be': 1,
#            'could': 1,
#            'for': 1,
#            'game': 1,
#            'i': 1,
#            'movie': 1,
#            'not': 1,
#            'over': 2,
#            'this': 1,
#            'to': 1,
#            'wait': 1}),
#  FreqDist({'3-disappoint': 1}),
#  FreqDist({'3-d': 1, 'effect': 1, 'great': 1, 'not': 1, 'the': 1}),
#  FreqDist({'a': 1, 'go': 1, 'to': 1, 'way': 1, 'what': 1}),
#  FreqDist({'abomination': 1, 'an': 1}),
#  FreqDist({"'": 1,
#            "'s": 1,
#            'a': 1,
#            'and': 1,
#            'be': 1,
#            'flick': 1,
#            'it': 1,
#            'kid': 2,
#            'my': 1,
#            'satisfied': 1}),
#  FreqDist({'from': 1,
#            'matrix': 1,
#            'on': 1,
#            'positive': 1,
#            'scene': 1,
#            'spin': 1,
#            'star': 1,
#            'the': 1,
#            'vibe': 1,
#            'war': 1,
#            'with': 1}),
#  FreqDist({'a': 1,
#            'be': 1,
#            'great': 1,
#            'it': 1,
#            'kid': 1,
#            'movie': 1,
#            'still': 1}),
#  FreqDist({'bad': 1, 'be': 1, 'the': 1, 'this': 1}),
#  FreqDist({"'s": 1,
#            '...': 1,
#            'a': 1,
#            'be': 1,
#            'but': 1,
#            'i': 1,
#            'kid': 1,
#            'know': 1,
#            'movie': 1,
#            'this': 1}),
#  FreqDist({'-': 1,
#            'a': 1,
#            'christ-sake': 1,
#            'fer': 1,
#            'its': 1,
#            'kid': 1,
#            'movie': 1}),
#  FreqDist({'3-d': 1,
#            'a': 1,
#            'clever': 1,
#            'despite': 1,
#            'effort': 1,
#            'mediocre': 1,
#            'of': 1,
#            'only': 1,
#            'use': 1}),
#  FreqDist({'anyone': 1,
#            'be': 1,
#            'fight': 1,
#            'goddamn': 1,
#            'good': 1,
#            'i': 1,
#            'movie': 1,
#            'otherwise': 1,
#            'say': 1,
#            'this': 1,
#            'who': 1,
#            'will': 1}),
#  FreqDist({'it': 2, 'kid': 1, 'loathe': 1, 'love': 1, 'parent': 1, 'the': 2}),
#  FreqDist({'big': 1, 'fan': 1, 'kid': 1, 'spy': 1}),
#  FreqDist({"'": 2,
#            '3-d': 1,
#            ':': 1,
#            'a': 1,
#            'be': 1,
#            'fun': 1,
#            'game': 1,
#            'just': 1,
#            'kid': 1,
#            'movie': 1,
#            'over': 1,
#            'spy': 1,
#            'summer': 1}),
#  FreqDist({'electricity': 1, 'indulgent': 1, 'of': 1, 'self': 1, 'waste': 1}),
#  FreqDist({"'": 1, 'game': 1, 'goodness': 1, 'it': 1, 'over': 1, 'thank': 1}),
#  FreqDist({'a': 1, 'down': 1, 'let': 1, 'what': 1}),
#  FreqDist({'can': 1,
#            'expect': 1,
#            'kind': 1,
#            'of': 1,
#            'really': 1,
#            'script': 1,
#            'well': 1,
#            'what': 1,
#            'you': 1}),
#  FreqDist({'cause': 1, 'film': 1, 'headache': 1, 'summer': 1}),
#  FreqDist({'for': 1, 'great': 1, 'kid': 1, 'movie': 1}),
#  FreqDist({'2-d': 1, 'better': 1, 'first': 1, 'than': 1, 'the': 1}),
#  FreqDist({'definitely': 1, 'for': 1, 'fun': 1, 'kid': 1, 'the': 1}),
#  FreqDist({'...': 1,
#            'best': 1,
#            'but': 1,
#            'franchise': 1,
#            'in': 1,
#            'not': 1,
#            'the': 2}),
#  FreqDist({'3-d': 1,
#            ':': 1,
#            'a': 1,
#            'eye': 1,
#            'in': 1,
#            'kid': 1,
#            'pain': 1,
#            'spy': 1,
#            'the': 1}),
#  FreqDist({'3d': 1, 'effect': 1, 'nice': 1}),
#  FreqDist({'...': 1,
#            'can': 1,
#            'game': 1,
#            'hope': 1,
#            'only': 1,
#            'over': 1,
#            'we': 1}),
#  FreqDist({'again': 1, 'do': 1, 'it': 1, 'rodriguez': 1}),
#  FreqDist({'about': 1,
#            'be': 1,
#            'critic': 1,
#            'one': 1,
#            'right': 1,
#            'the': 1,
#            'this': 1}),
#  FreqDist({'compare': 1,
#            'do': 1,
#            'not': 1,
#            'one': 1,
#            'other': 1,
#            'the': 1,
#            'this': 1,
#            'to': 1,
#            'two': 1}),
#  FreqDist({'see': 1, 'worth': 1}),
#  FreqDist({'-': 1,
#            'as': 2,
#            'dimensional': 1,
#            'multi': 1,
#            'not': 1,
#            'suggest': 1,
#            'the': 1,
#            'title': 1,
#            'would': 1}),
#  FreqDist({'a': 1,
#            'be': 1,
#            'morning': 1,
#            'saturday': 1,
#            'should': 1,
#            'show': 1,
#            'this': 1,
#            'weekly': 1}),
#  FreqDist({'3d': 1,
#            'adventure': 1,
#            'ending': 1,
#            'funny': 1,
#            'game': 1,
#            'irritate': 1,
#            'video': 1,
#            'with': 1}),
#  FreqDist({'.': 1,
#            '2d': 1,
#            '3d': 1,
#            'be': 2,
#            'better': 1,
#            'hard': 1,
#            'have': 1,
#            'in': 1,
#            'to': 1,
#            'too': 1,
#            'watch': 1,
#            'would': 1}),
#  FreqDist({'...': 1, 'fun': 1, 'third': 1, 'with': 1}),
#  FreqDist({'a': 1,
#            'except': 1,
#            'eyestrain': 1,
#            'for': 1,
#            'movie': 1,
#            'perfect': 1,
#            'the': 1}),
#  FreqDist({'3-d': 1, 'kid': 1, 'not': 1, 'or': 1, 'spy': 1}),
#  FreqDist({'great': 1, 'movie': 1}),
#  FreqDist({'a': 1, 'disappointment': 1, 'dreary': 1}),
#  FreqDist({'but': 1, 'promise': 1, 'uneven': 1}),
#  FreqDist({'be': 1, 'god': 1, 'over': 1, 'thanks': 1}),
#  FreqDist({'anything': 1,
#            'bad': 1,
#            'could': 1,
#            'do': 1,
#            'make': 1,
#            'not': 1,
#            'they': 1,
#            'think': 1}),
# ...
#            'fun': 1,
#            'hate': 1,
#            'movie': 1,
#            'of': 1,
#            'simple': 1,
#            'story': 1,
#            'style': 1,
#            'the': 1,
#            'unless': 1,
#            'you': 1}),
#  FreqDist({'be': 1, 'it': 2, 'know': 1, 'what': 1}),
#  FreqDist({'great': 1,
#            'movie': 2,
#            'new': 1,
#            'of': 1,
#            'superhero': 1,
#            'type': 1}),
#  FreqDist({'absolutely': 1,
#            'be': 1,
#            'dead': 1,
#            'deadpool': 1,
#            'death': 1,
#            'die': 1,
#            'for': 1,
#            'on': 1,
#            'serious': 1,
#            'to': 1}),
#  FreqDist({'i': 1, 'it': 1, 'love': 1, 'surprisingly': 1}),
#  FreqDist({'age': 1,
#            'all': 1,
#            'be': 1,
#            'best': 1,
#            'have': 1,
#            'hilarious': 1,
#            'i': 1,
#            'in': 1,
#            'movie': 1,
#            'renolds': 1,
#            'ryan': 1,
#            'see': 1,
#            'the': 1,
#            'this': 1}),
#  FreqDist({'...': 1, 'but': 1, 'enough': 1, 'not': 1, 'okay': 1}),
#  FreqDist({'but': 1, 'enjoyable': 1, 'its': 2, 'stupid': 1, 'yes': 1}),
#  FreqDist({'funny': 1, 'lol': 1}),
#  FreqDist({'.': 1,
#            '...': 1,
#            '67': 1,
#            'a': 1,
#            'and': 1,
#            'have': 1,
#            'i': 1,
#            'movie': 1,
#            'time': 1,
#            'watch': 1,
#            'worth': 1}),
#  FreqDist({'a': 1, 'flick': 1, 'fun': 1, 'truly': 1}),
#  FreqDist({'a': 1,
#            'but': 1,
#            'i': 1,
#            'it': 1,
#            'love': 1,
#            'movie': 1,
#            'silly': 1,
#            'such': 1}),
#  FreqDist({'can': 1, 'enjoy': 1, 'everyone': 1, 'one': 1, 'this': 1}),
#  FreqDist({'a': 1,
#            'and': 1,
#            'better': 1,
#            'different': 1,
#            'hero': 1,
#            'kind': 1,
#            'of': 1,
#            'super': 1}),
#  FreqDist({'dead': 2, 'good': 1, 'pool': 1}),
#  FreqDist({'(': 1,
#            ')': 1,
#            '--': 4,
#            ':': 1,
#            'a': 1,
#            'deadpool': 1,
#            'english': 1,
#            'my': 1,
#            'new': 1,
#            'rating': 1,
#            'venture': 1,
#            '\xe2\x98\x85\xe2\x98\x85\xe2\x98\x851\xe2\x81\x842': 1}),
#  FreqDist({'fun': 1, 'great': 1}),
#  FreqDist({"'s": 1,
#            'best': 1,
#            'cinematic': 1,
#            'marvel': 1,
#            'of': 1,
#            'probably': 1,
#            'the': 1,
#            'universe': 1}),
#  FreqDist({'enjoyable': 1}),
#  FreqDist({'a': 1, 'but': 1, 'fun': 1, 'great': 2, 'movie': 1, 'not': 1}),
#  FreqDist({'await': 1,
#            'continue': 1,
#            'long': 1,
#            'sequel': 1,
#            'the': 1,
#            'tradition': 1,
#            'van': 1,
#            'wilder': 1}),
#  FreqDist({'...': 1, 'all': 1, 'be': 1, 'deadpool': 1, 'heart': 1}),
#  FreqDist({"'": 3,
#            '-': 1,
#            'a': 1,
#            'be': 1,
#            'beckham': 1,
#            'can': 1,
#            'dave': 1,
#            'ever': 1,
#            'everything': 1,
#            'he': 1,
#            'hear': 1,
#            'helium': 1,
#            'it': 1,
#            'like': 1,
#            'look': 1,
#            'mouth': 1,
#            'of': 1,
#            'sex': 1,
#            'speak': 1}),
#  FreqDist({"'": 2, 'best': 1, 'movie': 1, 'r': 1, 'rat': 1}),
#  FreqDist({'deadpool': 1, 'in': 1, 'movie': 1, 'other': 1}),
#  FreqDist({'be': 1,
#            'exactly': 1,
#            'interpretation': 1,
#            'it': 2,
#            'say': 1,
#            'spoiler': 1,
#            'subject': 1,
#            'to': 1,
#            'what': 1,
#            'would': 1}),
#  FreqDist({'best': 1, 'have': 1, 'i': 1, 'movie': 1, 'see': 1}),
#  FreqDist({"'": 1,
#            '``': 2,
#            'and': 1,
#            'fun': 1,
#            'regina': 1,
#            'rhyme': 1,
#            'that': 1,
#            'why': 1,
#            'with': 1}),
#  FreqDist({'...': 1, 'deadpool': 1, 'rise': 1, 'the': 1}),
#  FreqDist({'awesome': 1, 'film': 1}),
#  FreqDist({'...': 1, 'wow': 1}),
#  FreqDist({'a': 1,
#            'amazing': 1,
#            'and': 1,
#            'best': 1,
#            'funny': 1,
#            'have': 1,
#            'hilarious': 1,
#            'i': 1,
#            'in': 1,
#            'long': 1,
#            'see': 1,
#            'super': 1,
#            'time': 1,
#            'very': 1}),
#  FreqDist({'deadpool': 1, 'keep': 1, 'like': 1, 'make': 1, 'movie': 1}),
#  FreqDist({'a': 1, 'marvel': 1, 'masterpiece': 1}),
#  FreqDist({'boring': 1,
#            'it': 1,
#            'love': 1,
#            'marvel': 1,
#            'movie': 1,
#            'other': 1,
#            'put': 1,
#            'shame': 1,
#            'the': 1,
#            'to': 1}),
#  FreqDist({'and': 1,
#            'for': 1,
#            'hotness': 1,
#            'quest': 1,
#            'reynolds': 1,
#            'ryan': 1,
#            'the': 1}),
#  FreqDist({'an': 1, 'immature': 1, 'romp': 1, 'unremarkable': 1}),
#  FreqDist({'(': 1, ')': 1, 'mild': 1, 'overrated': 1, 'spoiler': 1}),
#  FreqDist({'an': 1,
#            'be': 1,
#            'bring': 1,
#            'deadpool': 1,
#            'drudgery': 1,
#            'new': 1,
#            'nothing': 1,
#            'table': 1,
#            'that': 1,
#            'the': 1,
#            'to': 1,
#            'unfunny': 1}),
#  FreqDist({'-': 1,
#            '15': 1,
#            'best': 1,
#            'film': 1,
#            'first': 1,
#            'for': 1,
#            'into': 1,
#            'old': 1,
#            'r': 1,
#            'rat': 1,
#            'sneak': 1,
#            'their': 1,
#            'year': 1}),
#  FreqDist({'14': 1,
#            'a': 1,
#            'and': 1,
#            'as': 2,
#            'attention': 1,
#            'boring': 1,
#            'brainless': 1,
#            'o': 1,
#            'w**re': 1,
#            'y': 1}),
#  FreqDist({'monkey': 1,
#            'please': 1,
#            'porn': 1,
#            'stop': 1,
#            'the': 1,
#            'violent': 1}),
#  FreqDist({'...': 1, 'out': 1, 'walk': 1, 'we': 1}),
#  FreqDist({'a': 1, 'awesome': 1, 'of': 1, 'slice': 1}),
#  FreqDist({'dumb': 1, 'movie': 1}),
#  FreqDist({'a': 1,
#            'be': 1,
#            'better': 1,
#            'do': 2,
#            'film': 1,
#            'hard': 1,
#            'have': 1,
#            'if': 1,
#            'not': 1,
#            'r': 1,
#            'they': 1,
#            'would': 1}),
#  FreqDist({'2016': 1,
#            'begin': 1,
#            'ever': 1,
#            'most': 1,
#            'movie': 1,
#            'pathetic': 1,
#            'the': 1,
#            'with': 1}),
#  FreqDist({'a': 2,
#            'beautiful': 1,
#            'funny': 1,
#            'hero': 1,
#            'love': 1,
#            'of': 1,
#            'story': 1,
#            'super': 1}),
#  FreqDist({'brilliant': 1, 'comedy': 1, 'superhero': 1}),
#  FreqDist({'harry': 1, 'potter': 1}),
#  FreqDist({',': 1,
#            'and': 1,
#            'good': 1,
#            'job': 1,
#            'reynold': 1,
#            'team': 1,
#            'the': 1}),
#  FreqDist({'a': 1,
#            'about': 1,
#            'be': 1,
#            'deadpool': 1,
#            'go': 1,
#            'hell': 1,
#            'his': 3,
#            'life': 2,
#            'mercenary': 1,
#            'of': 1,
#            'rest': 1,
#            'save': 1,
#            'spend': 1,
#            'the': 1,
#            'thru': 1,
#            'to': 2,
#            'who': 1,
#            'wife': 1,
#            'with': 1}),
#  FreqDist({'/': 1, 'say': 1, 'tgchan': 1, 'tgchan.pl': 1, 'yes~': 1}),
#  FreqDist({'and': 1,
#            'as': 2,
#            'be': 1,
#            'bit': 1,
#            'every': 1,
#            'gratuitous': 1,
#            'it': 1,
#            'need': 1,
#            'profane': 1,
#            'to': 1,
#            'vile': 1}),
#  FreqDist({'..': 1,
#            '2': 1,
#            'a': 1,
#            'all': 1,
#            'be': 1,
#            'deserve': 1,
#            'do': 1,
#            'false': 1,
#            'more': 1,
#            'not': 1,
#            'of': 1,
#            'rating': 1,
#            'review': 1,
#            'than': 1}),
#  FreqDist({'a': 2,
#            'aside': 1,
#            'be': 1,
#            'couple': 1,
#            'fault': 1,
#            'from': 1,
#            'masterpiece': 1,
#            'of': 2,
#            'on': 1,
#            'the': 1,
#            'verge': 1}),
#  FreqDist({'and': 1,
#            'entertaining': 1,
#            'funny': 1,
#            'original': 1,
#            'outrageously': 1}),
#  FreqDist({'at': 1,
#            'but': 1,
#            'daft': 1,
#            'fantastic': 1,
#            'film': 1,
#            'time': 1}),
#  FreqDist({'cheap': 1, 'for': 1, 'kid': 1, 'movie': 1, 'story': 1}),
#  FreqDist({"'": 1,
#            '-': 1,
#            'a': 1,
#            'an': 1,
#            'but': 1,
#            'it': 1,
#            'little': 1,
#            'movie': 1,
#            'much': 1,
#            'not': 1,
#            'ok': 1,
#            'original': 1}),
#  FreqDist({'against': 1,
#            'all': 1,
#            'movie': 1,
#            'odds': 1,
#            'succeed': 1,
#            'that': 1,
#            'the': 1}),
#  FreqDist({'a': 1, 'charm': 1, 'like': 1, 'work': 1}),
#  FreqDist({'remember': 1, 'some': 1, 'thing': 1, 'to': 1}),
#  FreqDist({'miss': 1, 'opportunity': 1}),
#  FreqDist({'be': 1, 'how': 1, 'make': 1, 'movie': 1, 'should': 1, 'this': 1}),
#  FreqDist({'it': 1, 'love': 1}),
#  FreqDist({'best': 1,
#            'far': 1,
#            'man': 1,
#            'movie': 1,
#            'of': 1,
#            'one': 1,
#            'so': 1,
#            'the': 1,
#            'x': 1}),
#  FreqDist({'entertaining': 1, 'marvellous': 1, 'mix': 1, 'very': 1}),
#  FreqDist({'-': 1,
#            'be': 1,
#            'bind': 1,
#            'by': 1,
#            'filthy': 1,
#            'its': 1,
#            'movie': 1,
#            'origin': 1,
#            'refreshingly': 1,
#            'story': 1,
#            'superhero': 1,
#            'that': 1,
#            'trapping': 1}),
#  FreqDist({'bandwagon': 1,
#            'hero': 1,
#            'jump': 1,
#            'let': 1,
#            'make': 1,
#            'on': 1,
#            'super': 1,
#            'the': 1}),
#  FreqDist({'expect': 1, 'i': 1, 'what': 1}),
#  FreqDist({'film': 1, 'hype': 1, 'surpass': 1, 'the': 1}),
#  FreqDist({'``': 2,
#            'aspect': 1,
#            'begin': 1,
#            'every': 1,
#            'in': 1,
#            'surpasses': 1}),
#  FreqDist({'2008': 1, 'best': 1, 'down': 1, 'hand': 1, 'movie': 1, 'of': 1}),
#  FreqDist({'batman': 1,
#            'deserve': 1,
#            'sequel': 1,
#            'the': 2,
#            'to': 1,
#            'want': 1,
#            'we': 2}),
#  FreqDist({'-': 1,
#            'certainly': 1,
#            'dark': 1,
#            'the': 1,
#            'wait': 1,
#            'worth': 1}),
#  FreqDist({'.': 1, 'best': 1, 'comic': 1, 'ever': 1, 'movie': 1}),
#  FreqDist({'and': 1, 'at': 1, 'batman': 1, 'best': 1, 'beyond': 1, 'his': 1}),
#  FreqDist({'and': 1,
#            'dark': 1,
#            'film': 1,
#            'mood': 1,
#            'movie': 1,
#            'of': 2,
#            'really': 1,
#            'set': 1,
#            'sinister': 1,
#            'the': 4,
#            'theme': 1}),
#  FreqDist({'a': 1,
#            'batman': 1,
#            'book': 1,
#            'comic': 1,
#            'dream': 1,
#            'more': 1,
#            'movie': 1,
#            'much': 1,
#            'of': 1,
#            'our': 1,
#            'so': 1,
#            'than': 1,
#            'the': 1}),
#  FreqDist({'and': 1,
#            'as': 2,
#            'be': 1,
#            'best': 1,
#            'dark': 1,
#            'easily': 1,
#            'everyone': 1,
#            'film': 1,
#            'good': 1,
#            'knight': 1,
#            'make': 1,
#            'say': 1,
#            'superhero': 1,
#            'the': 2}),
#  FreqDist({'--': 2,
#            'batman': 1,
#            'best': 1,
#            'dark': 1,
#            'ever': 1,
#            'knight': 1,
#            'movie': 1,
#            'the': 1}),
#  FreqDist({"'s": 1,
#            'and': 1,
#            'brilliant': 1,
#            'dark': 1,
#            'heath': 1,
#            'ledger': 1,
#            'song': 1,
#            'swan': 1}),
#  FreqDist({'a': 1, 'batman': 1, 'of': 1, 'proportion': 1, 'shakesperean': 1}),
#  FreqDist({'be': 2,
#            'everyone': 1,
#            'i': 1,
#            'masterpiece': 1,
#            'no': 1,
#            'sorry': 1,
#            'this': 1}),
#  FreqDist({'best': 1,
#            'ever': 1,
#            'movie': 1,
#            'of': 1,
#            'one': 1,
#            'superhero': 1,
#            'the': 1}),
#  FreqDist({'fantastic': 1}),
#  FreqDist({'batman': 1, 'get': 1, 'just': 1, 'modern': 1, 'really': 1}),
#  FreqDist({'dark': 1, 'delivers': 1, 'knight': 1, 'the': 1}),
#  FreqDist({"'": 1,
#            'but': 1,
#            'good': 1,
#            'in': 1,
#            'keep': 1,
#            'let': 1,
#            'perspective': 1,
#            'thing': 1,
#            'very': 1,
#            'yikes': 1}),
#  FreqDist({'batty': 1,
#            'be': 1,
#            'best': 1,
#            'ever': 1,
#            'film': 1,
#            'must': 1,
#            'you': 1}),
#  FreqDist({'be': 1,
#            'but': 1,
#            'compare': 1,
#            'deserve': 1,
#            'do': 1,
#            'great': 1,
#            'masterpiece': 1,
#            'not': 1,
#            'to': 1,
#            'with': 1}),
#  FreqDist({"'": 1, 'be': 1, 'let': 1, 'realistic': 1}),
#  FreqDist({'ever': 1, 'film': 1, 'great': 1, 'make': 1, 'not': 1, 'the': 1}),
#  FreqDist({'a': 1, 'be': 1, 'heath': 1, 'ledgend': 1, 'ledger': 1}),
#  FreqDist({'a': 1,
#            'more': 1,
#            'movie': 1,
#            'nothing': 1,
#            'solid': 1,
#            'superhero': 1,
#            'tdk': 1}),
#  FreqDist({'everyone': 1,
#            'film': 1,
#            'fool': 1,
#            'have': 1,
#            'seem': 1,
#            'that': 1,
#            'the': 1,
#            'to': 1}),
#  FreqDist({'away': 1,
#            'be': 1,
#            'blow': 1,
#            'fan': 1,
#            'many': 1,
#            'seem': 1,
#            'to': 1,
#            'too': 1}),
#  FreqDist({'and': 1, 'boring': 1, 'incoherent': 1, 'surprisingly': 1}),
#  FreqDist({'-': 1,
#            ';': 1,
#            'a': 1,
#            'about': 1,
#            'and': 1,
#            'be': 2,
#            'bold': 1,
#            'concoction': 1,
#            'especially': 1,
#            'ever': 1,
#            'film': 1,
#            'get': 1,
#            'great': 1,
#            'idea': 1,
#            'interesting': 1,
#            'just': 1,
#            'less': 1,
#            'of': 1,
#            'progressively': 1,
#            'that': 1,
#            'the': 1,
#            'tread': 1,
#            'water': 1,
#            'which': 1,
#            'wild': 1,
#            'without': 1}),
#  FreqDist({'all': 1, 'as': 2, 'good': 1, 'hype': 1, 'not': 1, 'the': 1}),
#  FreqDist({'10': 1,
#            'be': 1,
#            'it': 1,
#            'of': 1,
#            'one': 1,
#            'really': 1,
#            'the': 1,
#            'top': 1}),
#  FreqDist({'be': 1,
#            'best': 1,
#            'ever': 1,
#            'made.\xef\xbb\xbf': 1,
#            'movie': 1,
#            'seriously': 1,
#            'the': 1,
#            'this': 1}),
#  FreqDist({'movie': 1, 'perfect': 1}),
#  FreqDist({"'": 2,
#            '...': 1,
#            '.then': 1,
#            'dark': 1,
#            'if': 1,
#            'knight': 1,
#            'not': 1,
#            'nothing': 1,
#            'the': 1}),
#  FreqDist({'action': 1, 'an': 1, 'more': 1, 'movie': 1, 'nothing': 1}),
#  FreqDist({'batman': 1, 'best': 1, 'film': 1, 'the': 1, 'yet': 1}),
#  FreqDist({'perfection': 1, 'undescribable': 1}),
#  FreqDist({'christopher': 1, 'masterpiece': 1, 'nolan': 1}),
#  FreqDist({'and': 1,
#            'bad': 1,
#            'batman': 1,
#            'be': 2,
#            'begin': 1,
#            'best': 1,
#            'by': 1,
#            'disappoint': 1,
#            'expect': 1,
#            'get': 1,
#            'i': 2,
#            'the': 2}),
#  FreqDist({'be': 1,
#            'how': 1,
#            'make': 1,
#            'movie': 1,
#            'should': 1,
#            'superhero': 1,
#            'wonderful': 1}),
#  FreqDist({'be': 2,
#            'emotionally': 1,
#            'movie': 1,
#            'over': 1,
#            'people': 1,
#            'rat': 1,
#            'the': 1,
#            'vote': 1}),
#  ...]

# %%
test= tmp2[0]

# %%
testList = []
for i in tmp2:
    testList.append(i)

# %%
testList
# Out:
# [FreqDist({'good': 1, 'really': 1}),
#  FreqDist({"'re": 1,
#            'better': 1,
#            'clear': 1,
#            'from': 1,
#            'off': 1,
#            'ranch': 1,
#            'stay': 1,
#            'this': 1,
#            'well': 1,
#            'you': 1}),
#  FreqDist({'...': 1,
#            'be': 1,
#            'dressing': 1,
#            'it': 1,
#            'messy': 1,
#            'ranch': 1,
#            'raptor': 1,
#            'should': 1,
#            'so': 1}),
#  FreqDist({'and': 1, 'man': 1, 'of': 1, 'reptile': 1}),
#  FreqDist({'a': 1, 'better': 1, 'lot': 1, 'people': 1, 'say': 1, 'then': 1}),
#  FreqDist({'a': 1, 'be': 1, 'f*ck': 1, 'this': 1, 'what': 1}),
#  FreqDist({'different': 1, 'diversity': 1, 'in': 1, 'way': 1}),
#  FreqDist({'not': 1, 'watch': 1, 'worth': 1}),
#  FreqDist({'and': 1, 'money': 1, 'of': 1, 'time': 1, 'waste': 1}),
#  FreqDist({"'": 1,
#            'a': 1,
#            'history': 1,
#            'in': 1,
#            'irrelevant': 1,
#            'it': 1,
#            'name': 1,
#            'of': 1,
#            'pain': 1,
#            'real': 1,
#            'story': 1,
#            'the': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({'-': 1,
#            'better': 1,
#            'i': 1,
#            'it': 1,
#            'magazine': 1,
#            'mean': 1,
#            'on': 1,
#            'pinup': 1,
#            'sell': 1,
#            'start': 1,
#            'street': 1,
#            'the': 1}),
#  FreqDist({'authority': 1, 'film': 1, 'to': 1, 'yashraj': 1}),
#  FreqDist({'and': 1,
#            'appropriate': 1,
#            'historically': 1,
#            'movie': 1,
#            'worst': 1}),
#  FreqDist({'a': 2, 'as': 1, 'bangladeshi': 1, 'big': 1, 'protest': 1}),
#  FreqDist({'bollywood': 1, 'plzzzzz': 1, 'up': 1, 'wake': 1}),
#  FreqDist({'change': 1,
#            'history': 1,
#            'main': 1,
#            'movie': 1,
#            'the': 1,
#            'this': 1}),
#  FreqDist({'bangladesh': 1,
#            'disaster': 1,
#            'film': 1,
#            'have': 1,
#            'in': 1,
#            'start': 1,
#            'this': 1}),
#  FreqDist({"'s": 1,
#            'against': 1,
#            'bangladesh': 1,
#            'be': 1,
#            'it': 1,
#            'liberation': 1,
#            'pakistan': 1,
#            'war': 1}),
#  FreqDist({'distortion': 1, 'history': 1}),
#  FreqDist({'1971': 1,
#            'history': 1,
#            'liberation': 1,
#            'misrepresentation': 1,
#            'of': 2,
#            'the': 1,
#            'war': 1}),
#  FreqDist({'action': 1,
#            'base': 1,
#            'bollywood': 1,
#            'fact': 1,
#            'film': 1,
#            'its': 1,
#            'masala': 1,
#            'not': 1,
#            'on': 1}),
#  FreqDist({'and': 1, 'illiterate': 1, 'producer': 1, 'uneducated': 1}),
#  FreqDist({'and': 1,
#            'director': 1,
#            'ignorant': 1,
#            'of': 1,
#            'poor': 1,
#            'reflect': 1,
#            'script': 1,
#            'stupidity': 1,
#            'writer': 1}),
#  FreqDist({'history': 1,
#            'in': 1,
#            'movie': 1,
#            'the': 1,
#            'world': 1,
#            'worst': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({'1971': 1,
#            ':': 1,
#            'bangladesh': 1,
#            'history': 1,
#            'in': 1,
#            'liberation': 1,
#            'misinterpret': 1,
#            'of': 1,
#            'protest': 1,
#            'the': 1,
#            'war': 1}),
#  FreqDist({'i': 1, 'movie': 1, 'protest': 1, 'strongly': 1, 'this': 1}),
#  FreqDist({"'s": 1,
#            ':': 1,
#            'bangladesh': 1,
#            'gunday': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulating': 1,
#            'war': 1}),
#  FreqDist({'disappoint': 1}),
#  FreqDist({'be': 1,
#            'entertainment': 1,
#            'for': 1,
#            'only': 1,
#            'sucker': 1,
#            'we': 1}),
#  FreqDist({'rubbish': 1}),
#  FreqDist({'history': 1, 'wrong': 1}),
#  FreqDist({'a': 1,
#            'bunch': 1,
#            'but': 1,
#            'in': 1,
#            'lie': 1,
#            'movie': 1,
#            'nothing': 1,
#            'of': 1,
#            'this': 1}),
#  FreqDist({'1971': 1,
#            'bangladesh': 1,
#            'humiliate': 1,
#            'liberation': 1,
#            'of': 1,
#            'the': 1,
#            'war': 1}),
#  FreqDist({'bangladesh': 1,
#            'humilation': 1,
#            'liberation': 1,
#            'of': 1,
#            'war': 1}),
#  FreqDist({"'s": 1,
#            ':': 1,
#            'an': 1,
#            'bangladesh': 1,
#            'extreme': 1,
#            'gunday': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulation': 1,
#            'of': 1,
#            'war': 1}),
#  FreqDist({'...': 1,
#            'a': 1,
#            'aditya': 1,
#            'be': 1,
#            'chopra': 1,
#            'fake': 1,
#            'famous': 1,
#            'have': 1,
#            'history': 1,
#            'lame': 1,
#            'like': 1,
#            'make': 1,
#            'movie': 1,
#            'not': 1,
#            'of': 1,
#            'producer': 1,
#            'should': 1,
#            'this': 2,
#            'type': 1,
#            'with': 1}),
#  FreqDist({'against': 1,
#            'false': 1,
#            'historical': 1,
#            'statement': 1,
#            'truth': 1}),
#  FreqDist({'*': 10,
#            'a': 1,
#            'before': 1,
#            'do': 1,
#            'film': 1,
#            'make': 1,
#            'more': 1,
#            'need': 1,
#            'research': 1,
#            'to': 1,
#            'writer': 1}),
#  FreqDist({'/': 1, ':': 1, 'disgust': 1, 'movie': 1, 'yuck': 1}),
#  FreqDist({'and': 1,
#            'bangladesh': 1,
#            'disrespectful': 1,
#            'history': 1,
#            'humiliating': 1,
#            'most': 1,
#            'of': 1,
#            'offensive': 1,
#            'the': 1,
#            'to': 1}),
#  FreqDist({'bangladesh': 1,
#            'be': 1,
#            'history': 1,
#            'liberation': 1,
#            'of': 1,
#            'plot': 1,
#            'war': 1,
#            'wrongly': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({'a': 1, 'and': 1, 'fake': 1, 'history': 1, 'starting': 1}),
#  FreqDist({'movie': 1,
#            'of': 1,
#            'on': 1,
#            'shame': 1,
#            'team': 1,
#            'the': 1,
#            'this': 1,
#            'whole': 1}),
#  FreqDist({'an': 1,
#            'and': 1,
#            'awful': 1,
#            'flase': 1,
#            'information': 1,
#            'movie': 1}),
#  FreqDist({'critic': 1}),
#  FreqDist({"'s": 1,
#            'contempt': 1,
#            'liberation': 1,
#            'line': 1,
#            'movie': 1,
#            'our': 1,
#            'story': 1,
#            'this': 1,
#            'war': 1}),
#  FreqDist({'bangladesh': 1,
#            'disaster': 1,
#            'film': 1,
#            'have': 1,
#            'in': 1,
#            'start': 1,
#            'this': 1}),
#  FreqDist({'act': 1,
#            'and': 1,
#            'appal': 1,
#            'bad': 1,
#            'fact': 1,
#            'find': 1,
#            'plot': 1,
#            'poor': 1,
#            'possible': 1}),
#  FreqDist({':': 1,
#            'history': 1,
#            'must': 1,
#            'poor': 1,
#            'properly': 1,
#            'read': 1,
#            'screenplay': 1,
#            'writer': 1}),
#  FreqDist({'&': 1,
#            '...': 1,
#            'fraudulent': 1,
#            'historically': 1,
#            'laughable': 1,
#            'offensive': 1}),
#  FreqDist({'``': 2,
#            'bangladesh': 1,
#            'gunday': 1,
#            'history': 1,
#            'humiliate': 1,
#            'of': 1}),
#  FreqDist({'about': 1,
#            'bangladesh': 1,
#            'do': 1,
#            'false': 1,
#            'have': 1,
#            'information': 1,
#            'liberation': 1,
#            'movie': 1,
#            'not': 1,
#            'please': 1,
#            'the': 1,
#            'war': 1,
#            'watch': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({'bad': 1, 'movie': 1}),
#  FreqDist({"'": 1,
#            'abusive': 1,
#            'all': 1,
#            'can': 1,
#            'i': 1,
#            'say': 1,
#            'that': 1}),
#  FreqDist({'1971': 1,
#            'change': 1,
#            'history': 1,
#            'movie': 1,
#            'of': 2,
#            'the': 2,
#            'this': 1,
#            'war': 1}),
#  FreqDist({'fake': 1, 'information': 1}),
#  FreqDist({'bad': 1, 'movie': 1}),
#  FreqDist({'best': 1,
#            'ever': 1,
#            'historical': 1,
#            'lame': 1,
#            'movie': 1,
#            'the': 1,
#            'very': 1}),
#  FreqDist({'pity': 1, 'shame': 1}),
#  FreqDist({'hell': 1, 'the': 1, 'what': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({'protest': 1}),
#  FreqDist({'distortion': 1, 'fatal': 1, 'history': 1}),
#  FreqDist({"'s": 1,
#            'and': 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulating': 1,
#            'movie': 1,
#            'war': 1,
#            'worst': 1}),
#  FreqDist({"'s": 1,
#            'against': 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulation': 1,
#            'of': 2,
#            'pakistan': 1,
#            'war': 1}),
#  FreqDist({'about': 1,
#            'bangladesh': 1,
#            'contain': 1,
#            'history': 1,
#            'liberation': 1,
#            'movie': 1,
#            'of': 2,
#            'this': 1,
#            'war': 1,
#            'wrong': 1}),
#  FreqDist({'...': 1,
#            'action': 1,
#            'and': 1,
#            'apologize': 1,
#            'be': 1,
#            'consider': 1,
#            'correct': 1,
#            'different': 1,
#            'else': 1,
#            'film': 1,
#            'have': 1,
#            'in': 1,
#            'mistake': 2,
#            'or': 1,
#            'take': 1,
#            'thank': 1,
#            'the': 2,
#            'therefore': 1,
#            'to': 3,
#            'u': 1,
#            'unintended': 1,
#            'we': 2,
#            'will': 1,
#            'you': 1,
#            'your': 1}),
#  FreqDist({'always': 1, 'as': 1, 'bollywood': 1, 'movies-': 1, 'shitty': 1}),
#  FreqDist({"'s": 1, 'a': 1, 'comment': 1, 'critic': 1}),
#  FreqDist({"'s": 1,
#            'a': 1,
#            'country': 1,
#            'history': 1,
#            'libereation': 1,
#            'misrepresentation': 1,
#            'of': 1,
#            'war': 1}),
#  FreqDist({'a': 1,
#            'be': 1,
#            'my': 1,
#            'of': 1,
#            'this': 1,
#            'time': 1,
#            'waste': 1}),
#  FreqDist({'(': 1,
#            ')': 1,
#            '2014': 1,
#            ':': 1,
#            'a': 1,
#            'gunday': 1,
#            'quack': 1,
#            'story': 1,
#            'totally': 1}),
#  FreqDist({'a': 1,
#            'and': 1,
#            'background': 1,
#            'no': 1,
#            'research': 1,
#            'rubbish': 1,
#            'study': 1,
#            'with': 1}),
#  FreqDist({'history': 1, 'misinterpret': 1}),
#  FreqDist({'about': 1, 'history': 1, 'idea': 1, 'no': 1}),
#  FreqDist({'alteration': 1,
#            'history': 1,
#            'movie': 1,
#            'of': 1,
#            'with': 1,
#            'worst': 1}),
#  FreqDist({"'": 1,
#            'button': 1,
#            'in': 1,
#            'it': 1,
#            'negative': 1,
#            'rate': 1,
#            'the': 1,
#            'to': 1,
#            'where': 1}),
#  FreqDist({'apologize': 1,
#            'but': 1,
#            'correct': 1,
#            'do': 1,
#            'mistake': 1,
#            'not': 1,
#            'only': 1,
#            'the': 1,
#            'to': 1,
#            'u': 1}),
#  FreqDist({'be': 1, 'film': 1, 'maker': 1, 'uneducated': 1}),
#  FreqDist({'3': 1,
#            'a': 1,
#            'be': 2,
#            'deal': 1,
#            'die': 1,
#            'dude': 1,
#            'fiction': 1,
#            'history': 1,
#            'it': 1,
#            'million': 1,
#            'not': 1,
#            'of': 1,
#            'people': 1,
#            'piece': 1,
#            'specially': 1,
#            'when': 1,
#            'where': 1,
#            'with': 1,
#            'you': 1}),
#  FreqDist({'...': 1,
#            'a': 1,
#            'be': 1,
#            'history': 1,
#            'misrepresentation': 1,
#            'of': 1,
#            'the': 1,
#            'this': 1}),
#  FreqDist({'a': 1, 'bad': 1, 'try': 1}),
#  FreqDist({'a': 1, 'it': 1, 'pas': 1, 'that': 1, 'time': 1}),
#  FreqDist({'-': 1, '``': 2, 'a': 1, 'gunday': 1, 'movie': 1, 'rabish': 1}),
#  FreqDist({'against': 1,
#            'alteration': 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'of': 3,
#            'protest': 1,
#            'war': 1}),
#  FreqDist({'bad': 1, 'script': 1}),
#  FreqDist({'a': 2,
#            'bloody': 1,
#            'deliberate': 1,
#            'distortion': 1,
#            'history': 1,
#            'of': 1}),
#  FreqDist({'shame': 1}),
#  FreqDist({'against': 1,
#            'history': 1,
#            'humiliation': 1,
#            'of': 1,
#            'protest': 1,
#            'strong': 1,
#            'the': 1}),
#  FreqDist({'and': 1, 'money': 1, 'of': 1, 'time': 1, 'waste': 1}),
#  FreqDist({'film': 1, 'good': 1, 'very': 2}),
#  FreqDist({'false': 1, 'historical': 1, 'presentation': 1}),
#  FreqDist({'be': 1,
#            'but': 1,
#            'do': 1,
#            'entertain': 1,
#            'entertainment': 1,
#            'hearted': 1,
#            'indian': 1,
#            'know': 1,
#            'movie': 1,
#            'need': 2,
#            'not': 1,
#            'only': 1,
#            'others': 1,
#            'they': 2}),
#  FreqDist({'protest': 1, 'strongly': 1}),
#  FreqDist({'and': 1, 'energy': 1, 'of': 1, 'time': 1, 'waste': 1}),
#  FreqDist({'-': 1,
#            'a': 1,
#            'bangladesh': 1,
#            'be': 1,
#            'india': 1,
#            'not': 1,
#            'of': 1,
#            'pakistan': 1,
#            'product': 1,
#            'war': 1}),
#  FreqDist({'a': 1,
#            'be': 1,
#            'big': 1,
#            'but': 1,
#            'can': 1,
#            'change': 1,
#            'do': 1,
#            'film': 1,
#            'history': 1,
#            'it': 1,
#            'mean': 1,
#            'name': 1,
#            'not': 1,
#            'our': 1,
#            'raj': 1,
#            'that': 1,
#            'u': 1,
#            'yash': 1}),
#  FreqDist({"'": 1,
#            'a': 1,
#            'bangladesh': 1,
#            'be': 1,
#            'freedom': 1,
#            'it': 1,
#            'message': 1,
#            'movie': 1,
#            'of': 1,
#            'regard': 1,
#            'send': 1,
#            'the': 2,
#            'to': 1,
#            'viewer': 1,
#            'war': 1,
#            'wrong': 1}),
#  FreqDist({'all': 1,
#            'culprit': 1,
#            'for': 1,
#            'maker': 1,
#            'movie': 1,
#            'of': 2,
#            'shame': 1,
#            'this': 1}),
#  FreqDist({'protest': 1}),
#  FreqDist({'bangladesh': 1, 'history': 1, 'manipulation': 1, 'of': 1}),
#  FreqDist({'bangladesh': 1,
#            'gunday': 1,
#            'history': 1,
#            'humiliated': 1,
#            'of': 1}),
#  FreqDist({'about': 1,
#            'background': 1,
#            'historical': 1,
#            'the': 1,
#            'worng': 1}),
#  FreqDist({'``': 2,
#            'a': 1,
#            'against': 1,
#            'bangladesh': 1,
#            'be': 1,
#            'face': 1,
#            'gunday': 1,
#            'indian': 1,
#            'liberation': 1,
#            'movie': 1,
#            'of': 2,
#            'the': 1,
#            'thought': 1,
#            'war': 1,
#            'which': 1}),
#  FreqDist({'history': 1, 'manipulate': 1}),
#  FreqDist({"'": 1,
#            "'s": 1,
#            'and': 2,
#            'armed': 1,
#            'bangladesh': 1,
#            'force': 1,
#            'it': 1,
#            'liberation': 1,
#            'manipulation': 1,
#            'misrepresentation': 1,
#            'of': 1,
#            'war': 1}),
#  FreqDist({'at': 1,
#            'bangladesh': 1,
#            'beginning': 1,
#            'change': 1,
#            'history': 1,
#            'movie': 1,
#            'of': 2,
#            'the': 1,
#            'they': 1,
#            'this': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({'&': 1, 'historically': 1, 'inaccurate': 1, 'offensive': 1}),
#  FreqDist({'a': 1,
#            'and': 1,
#            'full': 1,
#            'lie': 1,
#            'manipulation': 1,
#            'movie': 1,
#            'of': 1}),
#  FreqDist({'(': 1, ')': 1, 'fairy': 1, 'rubbish': 1, 'tale': 1, 'witch': 1}),
#  FreqDist({'a': 1,
#            'as': 1,
#            'bangladeshi': 1,
#            'i': 1,
#            'protest': 1,
#            'strongly': 1}),
#  FreqDist({"'": 1,
#            'a': 1,
#            'and': 1,
#            'bangladesh': 1,
#            'history': 1,
#            'it': 1,
#            'mockery': 1,
#            'of': 2,
#            'pride': 1}),
#  FreqDist({'and': 1,
#            'be': 2,
#            'court': 1,
#            'film': 1,
#            'justice': 1,
#            'movie': 1,
#            'of': 1,
#            'raj': 1,
#            'should': 2,
#            'sued': 1,
#            'take': 1,
#            'the': 1,
#            'this': 1,
#            'to': 1,
#            'yash': 1}),
#  FreqDist({'and': 1,
#            'awful': 1,
#            'be': 1,
#            'but': 1,
#            'direction': 1,
#            'enough': 1,
#            'financially': 1,
#            'grow': 1,
#            'gunday-': 1,
#            'help': 1,
#            'lame': 1,
#            'may': 1,
#            'script': 1,
#            'that': 1,
#            'up': 1,
#            'you': 1,
#            'yrf': 1}),
#  FreqDist({'a': 1,
#            'as': 1,
#            'bangladeshi': 1,
#            'i': 1,
#            'protest': 1,
#            'strongly': 1}),
#  FreqDist({'corruption': 1, 'history': 1, 'of': 1}),
#  FreqDist({'a': 2,
#            'and': 1,
#            'country': 1,
#            'film': 1,
#            'honor': 1,
#            'independent': 1,
#            'tamper': 1,
#            'which': 1}),
#  FreqDist({'big': 1, 'lie': 1, 'the': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({'-': 1,
#            'actor': 1,
#            'but': 1,
#            'ever': 1,
#            'good': 1,
#            'gunday': 1,
#            'story': 1,
#            'worst': 1}),
#  FreqDist({'completely': 1, 'nonsense': 1}),
#  FreqDist({'game': 1, 'play': 1, 'video': 1}),
#  FreqDist({'contains': 1, 'history': 1, 'international': 1, 'twisted': 1}),
#  FreqDist({'about': 1,
#            'banglladesh': 1,
#            'false': 1,
#            'give': 1,
#            'information': 1,
#            'it': 1,
#            'liberation': 1,
#            'of': 1,
#            'war': 1}),
#  FreqDist({'a': 2,
#            'bangladeshi': 1,
#            'close': 1,
#            'from': 1,
#            'observation': 1,
#            'viewer': 1}),
#  FreqDist({'history': 1, 'wrong': 1}),
#  FreqDist({'morality': 1, 'movie': 1, 'of': 1, 'the': 1}),
#  FreqDist({'bad': 1,
#            'ever': 1,
#            'film': 1,
#            'gunday': 1,
#            'history': 1,
#            'in': 1,
#            'make': 1,
#            'the': 1}),
#  FreqDist({'(': 1,
#            ')': 1,
#            'history': 1,
#            'importantly': 1,
#            'misrepresentation': 1,
#            'most': 1,
#            'of': 1,
#            'the': 1}),
#  FreqDist({'history': 1, 'wrong': 1}),
#  FreqDist({'and': 1,
#            'associate': 1,
#            'film': 1,
#            'for': 1,
#            'hate': 1,
#            'its': 1,
#            'only': 1,
#            'this': 1}),
#  FreqDist({'bangladesh': 1,
#            'disrespectful': 1,
#            'fact': 1,
#            'liberation': 1,
#            'manipulation': 1,
#            'misleading': 1,
#            'of': 3,
#            'overall': 1,
#            'the': 1,
#            'war': 1}),
#  FreqDist({'.': 1,
#            '...': 1,
#            'a': 1,
#            'be': 1,
#            'disgrace': 1,
#            'this': 1,
#            'total': 1}),
#  FreqDist({',': 1,
#            'bangladesh': 1,
#            'by': 1,
#            'fake': 1,
#            'history': 1,
#            'insult': 1,
#            'put': 1,
#            'story': 1,
#            'tradition': 1}),
#  FreqDist({'review': 1}),
#  FreqDist({'history': 1, 'lawra': 1, 'wrong': 1}),
#  FreqDist({'-1.00': 1,
#            '.': 1,
#            '...': 3,
#            'baddest': 1,
#            'ever': 1,
#            'most': 1,
#            'movie': 1,
#            'rat': 1,
#            'world': 1}),
#  FreqDist({'be': 1,
#            'film': 1,
#            'liberation': 1,
#            'our': 1,
#            'pervert': 1,
#            'this': 1,
#            'war': 1}),
#  FreqDist({"'s": 1,
#            'a': 1,
#            'as': 1,
#            'bangladesh': 1,
#            'bangladeshi': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'protest': 1,
#            'war': 1}),
#  FreqDist({'bad': 1, 'movie': 1}),
#  FreqDist({'-': 1, 'intellectualism': 1, 'pseudo': 1}),
#  FreqDist({'a': 1, 'for': 1, 'its': 1, 'shame': 1, 'such': 1, 'yrf': 1}),
#  FreqDist({'history': 1, 'insult': 1, 'the': 1, 'yrf': 1}),
#  FreqDist({'a': 2,
#            'accurate': 1,
#            'be': 2,
#            'but': 1,
#            'fact': 1,
#            'fiction': 1,
#            'historical': 1,
#            'it': 1,
#            'movie': 1,
#            'of': 1,
#            'should': 1,
#            'that': 1,
#            'use': 1,
#            'when': 1,
#            'work': 1}),
#  FreqDist({"'s": 1,
#            'about': 1,
#            'bangladesh': 1,
#            'false': 1,
#            'information': 1,
#            'liberation': 1,
#            'war': 1}),
#  FreqDist({'1971': 1,
#            'about': 1,
#            'and': 1,
#            'bangladesh': 1,
#            'base': 1,
#            'false': 1,
#            'information': 1,
#            'liberation': 1,
#            'of': 1,
#            'on': 1,
#            'rubbish': 1,
#            'storyline': 1,
#            'war': 1}),
#  FreqDist({'against': 1,
#            'i': 1,
#            'idiocy': 1,
#            'movie': 1,
#            'of': 1,
#            'protest': 1,
#            'the': 2}),
#  FreqDist({'bullsit': 1, 'movie': 1}),
#  FreqDist({'a': 1,
#            'and': 1,
#            'base': 1,
#            'business': 1,
#            'cheap': 1,
#            'fallacy': 1,
#            'movie': 1,
#            'on': 1}),
#  FreqDist({'a': 1,
#            'all': 1,
#            'bangladesh': 1,
#            'be': 1,
#            'face': 1,
#            'of': 2,
#            'on': 1,
#            'people': 1,
#            'slap': 1,
#            'the': 2,
#            'this': 1}),
#  FreqDist({'history': 1, 'manipulation': 1, 'of': 1}),
#  FreqDist({'crap': 3, 'that': 1}),
#  FreqDist({"'": 1, 'history': 1, 'it': 1, 'manupulated': 1, 'the': 1}),
#  FreqDist({'disgust': 1}),
#  FreqDist({'a': 1,
#            'bad': 1,
#            'good': 1,
#            'history': 1,
#            'story': 1,
#            'temper': 1,
#            'the': 1,
#            'to': 1,
#            'try': 1,
#            'very': 1}),
#  FreqDist({'by': 1,
#            'history': 1,
#            'insane': 1,
#            'manipulate': 1,
#            'the': 1,
#            'title': 1}),
#  FreqDist({"'": 1,
#            '...': 1,
#            'a': 1,
#            'but': 1,
#            'distortion': 1,
#            'film': 1,
#            'great': 1,
#            'history': 1,
#            'nasty': 1,
#            'nothing': 1,
#            'of': 1,
#            'such': 1,
#            'there': 1}),
#  FreqDist({'bad': 1,
#            'bangladesh': 1,
#            'for': 1,
#            'history': 2,
#            'in': 1,
#            'movie': 1,
#            'plot': 1,
#            'the': 1,
#            'wrongly': 1}),
#  FreqDist({'how': 1,
#            'indian': 1,
#            'know': 1,
#            'others': 1,
#            'people': 1,
#            'respect': 1,
#            'should': 1,
#            'to': 1}),
#  FreqDist({'a': 1,
#            'and': 1,
#            'be': 1,
#            'foul': 1,
#            'gunday': 1,
#            'movie': 1,
#            'rubbish': 1}),
#  FreqDist({'authority': 1, 'dear': 1, 'film': 1, 'greeting': 1, 'yashraj': 1}),
#  FreqDist({'act': 1,
#            'and': 1,
#            'cinematography': 1,
#            'excellent': 1,
#            'interesting': 1,
#            'locale': 1,
#            'plot': 1,
#            'stunning': 1}),
#  FreqDist({'comedy': 1, 'excellent': 1, 'film': 1}),
#  FreqDist({'attempt': 1,
#            'be': 1,
#            'come': 1,
#            'daring': 1,
#            'gunday': 1,
#            'out': 1,
#            'this': 1,
#            'to': 1,
#            'year': 1}),
#  FreqDist({'bad': 1,
#            'ever': 1,
#            'have': 1,
#            'hindi': 1,
#            'i': 1,
#            'movie': 1,
#            'of': 1,
#            'one': 1,
#            'see': 1,
#            'the': 1}),
#  FreqDist({'rotten': 1, 'tomatoo': 1}),
#  FreqDist({',': 1,
#            'a': 1,
#            'disrespectful': 1,
#            'fraudulent': 1,
#            'misleading': 1,
#            'nation': 1,
#            'of': 1,
#            'sovereignty': 1,
#            'the': 1,
#            'to': 1}),
#  FreqDist({'protest': 1}),
#  FreqDist({'bollywood': 1,
#            'how': 1,
#            'kind': 1,
#            'movie': 1,
#            'of': 1,
#            'release': 1,
#            'this': 1}),
#  FreqDist({'bad': 1,
#            'cinema': 1,
#            'history': 1,
#            'in': 1,
#            'movie': 1,
#            'of': 1,
#            'plot': 1,
#            'the': 1}),
#  FreqDist({'history': 1, 'on': 1, 'present': 1, 'protest': 1, 'wrong': 1}),
#  FreqDist({'&': 1,
#            '(': 1,
#            ')': 1,
#            '...': 1,
#            'fraudulent': 1,
#            'historically': 1,
#            'importantly': 1,
#            'laughable': 1,
#            'most': 1,
#            'offensive': 1}),
#  FreqDist({'a': 1,
#            'and': 1,
#            'factually': 1,
#            'inaccurate': 1,
#            'killjoy': 1,
#            'total': 1}),
#  FreqDist({'-': 1,
#            'a': 1,
#            'and': 2,
#            'attempt': 1,
#            'before': 1,
#            'cheesiness': 1,
#            'creepy': 1,
#            'disturb': 1,
#            'foolish': 1,
#            'get': 1,
#            'group': 1,
#            'hate': 1,
#            'hindustan': 1,
#            'i': 1,
#            'into': 1,
#            'kill': 1,
#            'me': 1,
#            'of': 1,
#            'someone': 1}),
#  FreqDist({'a': 3,
#            'actually': 1,
#            'be': 1,
#            'contain': 1,
#            'devyani': 1,
#            'if': 1,
#            'in': 1,
#            'khobragade': 1,
#            'movie': 1,
#            'on': 1,
#            'prostitute': 1,
#            'she': 1,
#            'storyline': 1,
#            'that': 1,
#            'the': 1,
#            'u': 1,
#            'what': 1,
#            'would': 1}),
#  FreqDist({'learn': 1, 'respect': 1, 'to': 1}),
#  FreqDist({'a': 1,
#            'nation': 1,
#            'proper': 1,
#            'respect': 1,
#            'show': 1,
#            'the': 1,
#            'to': 1}),
#  FreqDist({'a': 1,
#            'against': 1,
#            'as': 1,
#            'bangladeshi': 1,
#            'be': 1,
#            'i': 1,
#            'you': 1}),
#  FreqDist({'be': 1, 'fake': 1, 'intro': 1, 'the': 1}),
#  FreqDist({'a': 1, 'base': 1, 'false': 1, 'history': 1, 'movie': 1, 'on': 1}),
#  FreqDist({"'s": 1,
#            'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'manipulate': 1,
#            'war': 1}),
#  FreqDist({'1971': 1,
#            'a': 1,
#            'and': 3,
#            'bangladesh': 1,
#            'be': 3,
#            'between': 2,
#            'but': 1,
#            'change': 1,
#            'director': 1,
#            'happen': 1,
#            'india': 1,
#            'main': 1,
#            'movie': 1,
#            'on': 1,
#            'pakistan': 2,
#            'story': 2,
#            'tell': 1,
#            'that': 2,
#            'the': 2,
#            'war': 2}),
#  FreqDist({'fraud': 1, 'history': 1, 'with': 1}),
#  FreqDist({'just': 1,
#            'love': 1,
#            'masala': 1,
#            'movie': 1,
#            'to': 1,
#            'total': 1,
#            'watch': 1,
#            'which': 1,
#            'you': 1}),
#  FreqDist({'fare': 1,
#            'good': 1,
#            'historically': 1,
#            'incorrect': 1,
#            'though': 1}),
#  FreqDist({'act': 1,
#            'arjun': 1,
#            'chopra': 1,
#            'kapoor': 1,
#            'of': 1,
#            'poor': 1,
#            'priyanka': 1,
#            'ranveer': 1,
#            'rubbish': 1,
#            'singh': 1,
#            'time': 1,
#            'waste': 1}),
#  FreqDist({'bangladesh': 1,
#            'history': 1,
#            'liberation': 1,
#            'of': 1,
#            'war': 1,
#            'wrong': 1}),
#  FreqDist({'line': 1, 'time': 1, 'wrong': 1}),
#  FreqDist({'despicable': 1}),
#  FreqDist({'bangladeshi': 1, 'humiliating': 1, 'liberation': 1, 'war': 1}),
#  FreqDist({'act': 1,
#            'by': 1,
#            'producer': 1,
#            'shameful': 1,
#            'the': 1,
#            'very': 1}),
#  FreqDist({'distortion': 1,
#            'history': 1,
#            'liberation': 1,
#            'of': 2,
#            'our': 1,
#            'the': 1,
#            'war': 1}),
#  FreqDist({'apology': 1, 'be': 1, 'enough': 1, 'not': 1}),
#  FreqDist({"'s": 1, 'india': 1, 'worst': 1}),
#  FreqDist({'bring': 1,
#            'for': 1,
#            'gunday': 1,
#            'justice': 1,
#            'should': 1,
#            'them': 1,
#            'to': 1}),
#  FreqDist({'a': 1,
#            'ever': 1,
#            'historical': 1,
#            'movie': 1,
#            'pathetic': 1,
#            'see': 1}),
#  FreqDist({'and': 1,
#            'historical': 1,
#            'in': 1,
#            'indian': 1,
#            'industry': 1,
#            'lie': 1,
#            'most': 1,
#            'movie': 1,
#            'the': 1,
#            'ugly': 1}),
#  FreqDist({'protest': 1}),
#  FreqDist({'a': 1,
#            'acting': 1,
#            'bad': 1,
#            'complete': 1,
#            'line': 1,
#            'of': 1,
#            'rubbish': 1,
#            'story': 1,
#            'time': 1,
#            'waste': 1}),
#  FreqDist({'and': 1,
#            'event': 1,
#            'information': 1,
#            'irrelevant': 1,
#            'time': 1,
#            'waste': 1}),
#  FreqDist({'gunday': 1, 'no': 1, 'say': 1, 'to': 1}),
#  FreqDist({'...': 1,
#            'even': 1,
#            'go': 1,
#            'how': 1,
#            'it': 1,
#            'know': 1,
#            'one': 1,
#            'this': 1,
#            'watch': 1,
#            'we': 1,
#            'will': 1,
#            'without': 1}),
#  FreqDist({'-1': 1, 'rating': 1, 'true': 1}),
#  FreqDist({'good': 1, 'grief': 1, 'oh': 1}),
#  FreqDist({'$': 1,
#            "'": 1,
#            '1': 1,
#            'bin': 1,
#            'but': 1,
#            'enjoy': 1,
#            'i': 2,
#            'in': 1,
#            'it': 1,
#            'suggest': 1,
#            'the': 1,
#            'this': 1,
#            'until': 1,
#            'wait': 1}),
#  FreqDist({'bother': 1, 'do': 1, 'not': 1}),
#  FreqDist({'a': 1,
#            'bad': 1,
#            'in': 1,
#            'long': 2,
#            'movie': 1,
#            'of': 1,
#            'one': 1,
#            'the': 1,
#            'time': 1}),
#  FreqDist({'away': 1,
#            'from': 1,
#            'movie': 1,
#            'please': 2,
#            'stay': 1,
#            'this': 1}),
#  FreqDist({'bread': 1, 'few': 1, 'for': 1, 'inane': 1, 'loaf': 1}),
#  FreqDist({'(': 1,
#            ')': 1,
#            '1996': 1,
#            '``': 2,
#            'day': 1,
#            'independence': 1,
#            'not': 1,
#            'sequel': 1,
#            'the': 1,
#            'to': 1}),
#  FreqDist({'sandwich': 1, 'sh*t': 1}),
#  FreqDist({'act': 1, 'bad': 1, 'poorly': 1}),
#  FreqDist({'a': 1,
#            'dime': 1,
#            'do': 1,
#            'not': 1,
#            'on': 1,
#            'one': 1,
#            'spend': 1,
#            'this': 1}),
#  FreqDist({'bad': 1, 'huh': 1, 'that': 1, 'wow': 1}),
#  FreqDist({'be': 1, 'movie': 1, 'remarkable': 1, 'this': 1}),
#  FreqDist({'action': 1,
#            'b': 1,
#            'day': 1,
#            'independent': 1,
#            'movie': 1,
#            'perfect': 1,
#            'scfi': 1}),
#  FreqDist({'bad': 2, 'really': 1}),
#  FreqDist({'2': 1,
#            'do': 1,
#            'even': 1,
#            'life': 1,
#            'minute': 1,
#            'not': 1,
#            'of': 1,
#            'on': 1,
#            'this': 1,
#            'waste': 1,
#            'your': 1}),
#  FreqDist({'ever': 1, 'have': 1, 'i': 1, 'movie': 1, 'pathetic': 1, 'see': 1}),
#  FreqDist({'bad': 1, 'ever': 1, 'have': 1, 'i': 1, 'see': 1, 'the': 1}),
#  FreqDist({'(': 1,
#            ')': 1,
#            'a': 1,
#            'and': 1,
#            'bit': 1,
#            "c'mon": 1,
#            'expectation': 1,
#            'lighten': 1,
#            'lower': 1,
#            'mild': 1,
#            'people': 1,
#            'spoiler': 1,
#            'up': 1,
#            'your': 1}),
#  FreqDist({'pallin': 1, 'sarah': 1}),
#  FreqDist({'movie': 1, 'the': 1, 'worst': 1}),
#  FreqDist({"'": 2,
#            'a': 1,
#            'be': 1,
#            'if': 1,
#            'it': 1,
#            'make': 1,
#            'may': 1,
#            'sense': 1,
#            'spoof': 1,
#            'truly': 1}),
#  FreqDist({'-': 1,
#            'bad': 1,
#            'be': 1,
#            'can': 1,
#            'fi': 1,
#            'really': 1,
#            'sci': 1,
#            'that': 1}),
#  FreqDist({'budget': 1, 'for': 1, 'good': 1, 'low': 1, 'movie': 1}),
#  FreqDist({'about': 1,
#            'be': 1,
#            'confused': 1,
#            'film': 1,
#            'people': 1,
#            'this': 1}),
#  FreqDist({'a': 2,
#            'be': 1,
#            'budget': 1,
#            'but': 1,
#            'enough': 1,
#            'film': 2,
#            'for': 1,
#            'good': 1,
#            'low': 1,
#            'movie': 1,
#            'must': 1,
#            'not': 1,
#            'ok': 1,
#            'see': 1,
#            'to': 1}),
#  FreqDist({'3-d': 1,
#            'adult': 1,
#            'amuse': 1,
#            'and': 2,
#            'be': 1,
#            'both': 1,
#            'but': 1,
#            'do': 1,
#            'enough': 1,
#            'for': 1,
#            'kid': 1,
#            'me': 1,
#            'not': 1,
#            'silliness': 1,
#            'still': 1,
#            'style': 1,
#            'the': 1,
#            'there': 1,
#            'thing': 1,
#            'to': 1,
#            'work': 1}),
#  FreqDist({'irredeemably': 1, 'stupid': 1}),
#  FreqDist({'be': 1,
#            'but': 1,
#            'for': 1,
#            'fun': 1,
#            'get': 1,
#            'little': 1,
#            'one': 1,
#            'series': 1,
#            'stale': 1,
#            'the': 2}),
#  FreqDist({'but': 1, 'fun': 1, 'not': 1, 'overwhelming': 1}),
#  FreqDist({'it': 1, 'kid': 1, 'like': 1, 'my': 1}),
#  FreqDist({'...': 1,
#            '3-d': 1,
#            'at': 1,
#            'average': 1,
#            'be': 1,
#            'best': 1,
#            'have': 1,
#            'the': 1,
#            'without': 1,
#            'would': 1}),
#  FreqDist({'latin': 1, 'magic': 1}),
#  FreqDist({'3-d': 1,
#            'be': 2,
#            'but': 1,
#            'film': 1,
#            'flat': 1,
#            'it': 1,
#            'may': 1,
#            'still': 1,
#            'the': 1}),
#  FreqDist({'a': 1,
#            'bad': 1,
#            'end': 1,
#            'franchise': 1,
#            'kid': 1,
#            'note': 1,
#            'on': 1,
#            'spy': 1,
#            'the': 1}),
#  FreqDist({'game': 1, 'indeed': 1, 'over': 1}),
#  FreqDist({'all': 1, 'expectation': 1, 'surpass': 1}),
#  FreqDist({'any': 1,
#            'do': 1,
#            'have': 1,
#            'if': 1,
#            'movie': 1,
#            'not': 1,
#            'sense': 1,
#            'this': 1,
#            'watch': 1,
#            'you': 1}),
#  FreqDist({'-': 1,
#            '3-d': 1,
#            'adventure': 1,
#            'an': 1,
#            'exciting': 1,
#            'for': 1,
#            'glass': 1,
#            'in': 1,
#            'it': 1,
#            'kid': 1,
#            'little': 1,
#            'mostly': 1,
#            'see': 1,
#            'your': 1}),
#  FreqDist({'best': 1,
#            'fun': 1,
#            'installment': 1,
#            'make': 1,
#            'one': 1,
#            'the': 1,
#            'third': 1,
#            'this': 1,
#            'virtual': 1,
#            'virtually': 1}),
#  FreqDist({'cheesy': 1, 'comic': 1, 'fun': 1}),
#  FreqDist({'-': 1, 'film': 1, 'put-together': 1, 'well': 1}),
#  FreqDist({'.': 1,
#            '...': 1,
#            '3-d': 1,
#            'a': 1,
#            'be': 1,
#            'clearly': 1,
#            'creative': 1,
#            'filmmaker': 1,
#            'gifted': 1,
#            'hamper': 1,
#            'he': 1,
#            'his': 1,
#            'imagination': 1,
#            'let': 1,
#            'rodriguez': 1,
#            'the': 1,
#            'while': 1}),
#  FreqDist({'and': 1,
#            'better': 1,
#            'cute': 1,
#            'second': 1,
#            'than': 1,
#            'the': 1}),
#  FreqDist({"'": 1, '3d': 1, 'good': 1, 'that': 1}),
#  FreqDist({'flippies': 1, 'ridiculous': 1}),
#  FreqDist({'all': 1, 'expectation': 1, 'surpass': 1}),
#  FreqDist({'-': 1, 'computer': 1, 'in': 1, 'land': 1, 'lose': 1}),
#  FreqDist({'cool': 1, 'fun': 1, 'very': 1}),
#  FreqDist({'horrid': 1}),
#  FreqDist({'a': 1,
#            'break': 1,
#            'come': 1,
#            'give': 1,
#            'it': 1,
#            'on': 1,
#            'people': 1}),
#  FreqDist({'a': 1,
#            'disappointing': 1,
#            'end': 1,
#            'series': 1,
#            'the': 1,
#            'to': 1}),
#  FreqDist({'3': 2,
#            'all': 1,
#            'be': 1,
#            'best': 1,
#            'but': 1,
#            'i': 1,
#            'kid': 1,
#            'like': 1,
#            'movie': 1,
#            'part': 1,
#            'spy': 1,
#            'the': 1}),
#  FreqDist({'be': 1,
#            'cool': 1,
#            'ever': 1,
#            'have': 1,
#            'i': 1,
#            'it': 1,
#            'movie': 1,
#            'see': 1,
#            'the': 1}),
#  FreqDist({'be': 1, 'film': 1, 'great': 1, 'i': 1, 'think': 1, 'this': 1}),
#  FreqDist({'no': 1}),
#  FreqDist({'many': 1, 'so': 1, 'thing': 1}),
#  FreqDist({'be': 1, 'game': 1, 'let': 1, 'over': 1, 'please': 1, 'the': 1}),
#  FreqDist({'3d': 1, 'effect': 1, 'installment': 1, 'the': 1}),
#  FreqDist({'celebrity': 1,
#            'devious': 1,
#            'fill': 1,
#            'flick': 1,
#            'kid': 1,
#            'of': 1,
#            'stallone': 1,
#            'star': 1,
#            'the': 1}),
#  FreqDist({'good': 1, 'really': 1}),
#  FreqDist({'2': 1,
#            'do': 1,
#            'first': 1,
#            'i': 1,
#            'in': 1,
#            'keep': 1,
#            'mind': 1,
#            'not': 1,
#            'see': 1,
#            'that': 1,
#            'the': 1}),
#  FreqDist({'...': 1,
#            'be': 1,
#            'game': 1,
#            'just': 1,
#            'may': 1,
#            'over': 1,
#            'the': 1}),
#  FreqDist({'reward': 1, 'your': 1}),
#  FreqDist({'creative': 1, 'poor': 1, 'story': 1, 'vision': 1}),
#  FreqDist({'a': 1, 'good': 1, 'half': 1, 'movie': 1}),
#  FreqDist({'around': 1,
#            'good': 1,
#            'not': 1,
#            'the': 1,
#            'third': 1,
#            'time': 1,
#            'to': 1}),
#  FreqDist({'(': 1,
#            ')': 1,
#            'as': 1,
#            'be': 1,
#            'cynicism': 1,
#            'do': 1,
#            'hollywood': 1,
#            'if': 1,
#            'know': 1,
#            'name': 1,
#            'not': 1,
#            'they': 1,
#            'we': 1}),
#  FreqDist({'helluva': 1, 'one': 1, 'surprise': 1}),
#  FreqDist({'a': 2,
#            'coda': 1,
#            'do': 1,
#            'film': 1,
#            'fitting': 1,
#            'modestly': 1,
#            'of': 1,
#            'series': 1,
#            'to': 1,
#            'well': 1}),
#  FreqDist({'hate': 1,
#            'love': 1,
#            'may': 2,
#            'see': 1,
#            'some': 2,
#            'though': 1,
#            'worth': 1}),
#  FreqDist({"'": 2,
#            '-': 2,
#            '1': 1,
#            'a': 1,
#            'but': 1,
#            'carmen': 1,
#            'cortez': 1,
#            'ending': 1,
#            'great': 1,
#            'it': 1,
#            'kid': 1,
#            'mom': 1,
#            'need': 1,
#            'new': 1,
#            'spoiler': 1,
#            'spy': 1,
#            'story': 1}),
#  FreqDist({'(': 1,
#            ')': 1,
#            'be': 1,
#            'kid': 1,
#            'movie': 1,
#            'sag': 1,
#            'spoiler': 1,
#            'spy': 1,
#            'start': 1,
#            'the': 1,
#            'to': 1}),
#  FreqDist({'3-d': 1,
#            'a': 1,
#            'be': 1,
#            'of': 1,
#            'thing': 1,
#            'time': 1,
#            'waste': 1}),
#  FreqDist({'eye': 1, 'my': 1, 'oh': 1}),
#  FreqDist({'.': 1,
#            '...': 1,
#            'be': 1,
#            'better': 1,
#            'call': 1,
#            'i': 1,
#            'it': 1,
#            'like': 1,
#            'this': 1,
#            'tron': 1,
#            'when': 1}),
#  FreqDist({'2nd': 1, 'from': 1, 'improved': 1, 'one': 1}),
#  FreqDist({'...': 1,
#            'about': 1,
#            'anyway': 1,
#            'be': 1,
#            'eye': 1,
#            'hurt': 1,
#            'my': 1,
#            'oooo': 1,
#            'this': 1,
#            'what': 1}),
#  FreqDist({'3-d': 1,
#            'as': 1,
#            'dumb': 1,
#            'in': 1,
#            'its': 1,
#            'predecessor': 1,
#            'than': 1,
#            'three': 1,
#            'time': 1}),
#  FreqDist({'good': 1, 'movie': 2, 'star': 2}),
#  FreqDist({'-': 1,
#            'crap': 1,
#            'eye': 1,
#            'i': 1,
#            'little': 1,
#            'my': 1,
#            'spy': 1,
#            'with': 1}),
#  FreqDist({'by': 1,
#            'fx': 1,
#            'great': 1,
#            'save': 1,
#            'special': 1,
#            'story': 1,
#            'thin': 1}),
#  FreqDist({'its': 1, 'ok': 1}),
#  FreqDist({"'": 1, 'for': 1, 'it': 1, 'kid': 1, 'tron': 1}),
#  FreqDist({'big': 1, 'commercial': 1, 'one': 1}),
#  FreqDist({'be': 1, 'but': 1, 'great': 2, 'not': 1, 'so': 1, 'somethings': 1}),
#  FreqDist({'effort': 1, 'i': 1, 'it': 1, 'more': 1, 'need': 1, 'think': 1}),
#  FreqDist({'be': 1,
#            'could': 1,
#            'for': 1,
#            'game': 1,
#            'i': 1,
#            'movie': 1,
#            'not': 1,
#            'over': 2,
#            'this': 1,
#            'to': 1,
#            'wait': 1}),
#  FreqDist({'3-disappoint': 1}),
#  FreqDist({'3-d': 1, 'effect': 1, 'great': 1, 'not': 1, 'the': 1}),
#  FreqDist({'a': 1, 'go': 1, 'to': 1, 'way': 1, 'what': 1}),
#  FreqDist({'abomination': 1, 'an': 1}),
#  FreqDist({"'": 1,
#            "'s": 1,
#            'a': 1,
#            'and': 1,
#            'be': 1,
#            'flick': 1,
#            'it': 1,
#            'kid': 2,
#            'my': 1,
#            'satisfied': 1}),
#  FreqDist({'from': 1,
#            'matrix': 1,
#            'on': 1,
#            'positive': 1,
#            'scene': 1,
#            'spin': 1,
#            'star': 1,
#            'the': 1,
#            'vibe': 1,
#            'war': 1,
#            'with': 1}),
#  FreqDist({'a': 1,
#            'be': 1,
#            'great': 1,
#            'it': 1,
#            'kid': 1,
#            'movie': 1,
#            'still': 1}),
#  FreqDist({'bad': 1, 'be': 1, 'the': 1, 'this': 1}),
#  FreqDist({"'s": 1,
#            '...': 1,
#            'a': 1,
#            'be': 1,
#            'but': 1,
#            'i': 1,
#            'kid': 1,
#            'know': 1,
#            'movie': 1,
#            'this': 1}),
#  FreqDist({'-': 1,
#            'a': 1,
#            'christ-sake': 1,
#            'fer': 1,
#            'its': 1,
#            'kid': 1,
#            'movie': 1}),
#  FreqDist({'3-d': 1,
#            'a': 1,
#            'clever': 1,
#            'despite': 1,
#            'effort': 1,
#            'mediocre': 1,
#            'of': 1,
#            'only': 1,
#            'use': 1}),
#  FreqDist({'anyone': 1,
#            'be': 1,
#            'fight': 1,
#            'goddamn': 1,
#            'good': 1,
#            'i': 1,
#            'movie': 1,
#            'otherwise': 1,
#            'say': 1,
#            'this': 1,
#            'who': 1,
#            'will': 1}),
#  FreqDist({'it': 2, 'kid': 1, 'loathe': 1, 'love': 1, 'parent': 1, 'the': 2}),
#  FreqDist({'big': 1, 'fan': 1, 'kid': 1, 'spy': 1}),
#  FreqDist({"'": 2,
#            '3-d': 1,
#            ':': 1,
#            'a': 1,
#            'be': 1,
#            'fun': 1,
#            'game': 1,
#            'just': 1,
#            'kid': 1,
#            'movie': 1,
#            'over': 1,
#            'spy': 1,
#            'summer': 1}),
#  FreqDist({'electricity': 1, 'indulgent': 1, 'of': 1, 'self': 1, 'waste': 1}),
#  FreqDist({"'": 1, 'game': 1, 'goodness': 1, 'it': 1, 'over': 1, 'thank': 1}),
#  FreqDist({'a': 1, 'down': 1, 'let': 1, 'what': 1}),
#  FreqDist({'can': 1,
#            'expect': 1,
#            'kind': 1,
#            'of': 1,
#            'really': 1,
#            'script': 1,
#            'well': 1,
#            'what': 1,
#            'you': 1}),
#  FreqDist({'cause': 1, 'film': 1, 'headache': 1, 'summer': 1}),
#  FreqDist({'for': 1, 'great': 1, 'kid': 1, 'movie': 1}),
#  FreqDist({'2-d': 1, 'better': 1, 'first': 1, 'than': 1, 'the': 1}),
#  FreqDist({'definitely': 1, 'for': 1, 'fun': 1, 'kid': 1, 'the': 1}),
#  FreqDist({'...': 1,
#            'best': 1,
#            'but': 1,
#            'franchise': 1,
#            'in': 1,
#            'not': 1,
#            'the': 2}),
#  FreqDist({'3-d': 1,
#            ':': 1,
#            'a': 1,
#            'eye': 1,
#            'in': 1,
#            'kid': 1,
#            'pain': 1,
#            'spy': 1,
#            'the': 1}),
#  FreqDist({'3d': 1, 'effect': 1, 'nice': 1}),
#  FreqDist({'...': 1,
#            'can': 1,
#            'game': 1,
#            'hope': 1,
#            'only': 1,
#            'over': 1,
#            'we': 1}),
#  FreqDist({'again': 1, 'do': 1, 'it': 1, 'rodriguez': 1}),
#  FreqDist({'about': 1,
#            'be': 1,
#            'critic': 1,
#            'one': 1,
#            'right': 1,
#            'the': 1,
#            'this': 1}),
#  FreqDist({'compare': 1,
#            'do': 1,
#            'not': 1,
#            'one': 1,
#            'other': 1,
#            'the': 1,
#            'this': 1,
#            'to': 1,
#            'two': 1}),
#  FreqDist({'see': 1, 'worth': 1}),
#  FreqDist({'-': 1,
#            'as': 2,
#            'dimensional': 1,
#            'multi': 1,
#            'not': 1,
#            'suggest': 1,
#            'the': 1,
#            'title': 1,
#            'would': 1}),
#  FreqDist({'a': 1,
#            'be': 1,
#            'morning': 1,
#            'saturday': 1,
#            'should': 1,
#            'show': 1,
#            'this': 1,
#            'weekly': 1}),
#  FreqDist({'3d': 1,
#            'adventure': 1,
#            'ending': 1,
#            'funny': 1,
#            'game': 1,
#            'irritate': 1,
#            'video': 1,
#            'with': 1}),
#  FreqDist({'.': 1,
#            '2d': 1,
#            '3d': 1,
#            'be': 2,
#            'better': 1,
#            'hard': 1,
#            'have': 1,
#            'in': 1,
#            'to': 1,
#            'too': 1,
#            'watch': 1,
#            'would': 1}),
#  FreqDist({'...': 1, 'fun': 1, 'third': 1, 'with': 1}),
#  FreqDist({'a': 1,
#            'except': 1,
#            'eyestrain': 1,
#            'for': 1,
#            'movie': 1,
#            'perfect': 1,
#            'the': 1}),
#  FreqDist({'3-d': 1, 'kid': 1, 'not': 1, 'or': 1, 'spy': 1}),
#  FreqDist({'great': 1, 'movie': 1}),
#  FreqDist({'a': 1, 'disappointment': 1, 'dreary': 1}),
#  FreqDist({'but': 1, 'promise': 1, 'uneven': 1}),
#  FreqDist({'be': 1, 'god': 1, 'over': 1, 'thanks': 1}),
#  FreqDist({'anything': 1,
#            'bad': 1,
#            'could': 1,
#            'do': 1,
#            'make': 1,
#            'not': 1,
#            'they': 1,
#            'think': 1}),
#  FreqDist({"'s": 1,
# ...
#            'fun': 1,
#            'hate': 1,
#            'movie': 1,
#            'of': 1,
#            'simple': 1,
#            'story': 1,
#            'style': 1,
#            'the': 1,
#            'unless': 1,
#            'you': 1}),
#  FreqDist({'be': 1, 'it': 2, 'know': 1, 'what': 1}),
#  FreqDist({'great': 1,
#            'movie': 2,
#            'new': 1,
#            'of': 1,
#            'superhero': 1,
#            'type': 1}),
#  FreqDist({'absolutely': 1,
#            'be': 1,
#            'dead': 1,
#            'deadpool': 1,
#            'death': 1,
#            'die': 1,
#            'for': 1,
#            'on': 1,
#            'serious': 1,
#            'to': 1}),
#  FreqDist({'i': 1, 'it': 1, 'love': 1, 'surprisingly': 1}),
#  FreqDist({'age': 1,
#            'all': 1,
#            'be': 1,
#            'best': 1,
#            'have': 1,
#            'hilarious': 1,
#            'i': 1,
#            'in': 1,
#            'movie': 1,
#            'renolds': 1,
#            'ryan': 1,
#            'see': 1,
#            'the': 1,
#            'this': 1}),
#  FreqDist({'...': 1, 'but': 1, 'enough': 1, 'not': 1, 'okay': 1}),
#  FreqDist({'but': 1, 'enjoyable': 1, 'its': 2, 'stupid': 1, 'yes': 1}),
#  FreqDist({'funny': 1, 'lol': 1}),
#  FreqDist({'.': 1,
#            '...': 1,
#            '67': 1,
#            'a': 1,
#            'and': 1,
#            'have': 1,
#            'i': 1,
#            'movie': 1,
#            'time': 1,
#            'watch': 1,
#            'worth': 1}),
#  FreqDist({'a': 1, 'flick': 1, 'fun': 1, 'truly': 1}),
#  FreqDist({'a': 1,
#            'but': 1,
#            'i': 1,
#            'it': 1,
#            'love': 1,
#            'movie': 1,
#            'silly': 1,
#            'such': 1}),
#  FreqDist({'can': 1, 'enjoy': 1, 'everyone': 1, 'one': 1, 'this': 1}),
#  FreqDist({'a': 1,
#            'and': 1,
#            'better': 1,
#            'different': 1,
#            'hero': 1,
#            'kind': 1,
#            'of': 1,
#            'super': 1}),
#  FreqDist({'dead': 2, 'good': 1, 'pool': 1}),
#  FreqDist({'(': 1,
#            ')': 1,
#            '--': 4,
#            ':': 1,
#            'a': 1,
#            'deadpool': 1,
#            'english': 1,
#            'my': 1,
#            'new': 1,
#            'rating': 1,
#            'venture': 1,
#            '\xe2\x98\x85\xe2\x98\x85\xe2\x98\x851\xe2\x81\x842': 1}),
#  FreqDist({'fun': 1, 'great': 1}),
#  FreqDist({"'s": 1,
#            'best': 1,
#            'cinematic': 1,
#            'marvel': 1,
#            'of': 1,
#            'probably': 1,
#            'the': 1,
#            'universe': 1}),
#  FreqDist({'enjoyable': 1}),
#  FreqDist({'a': 1, 'but': 1, 'fun': 1, 'great': 2, 'movie': 1, 'not': 1}),
#  FreqDist({'await': 1,
#            'continue': 1,
#            'long': 1,
#            'sequel': 1,
#            'the': 1,
#            'tradition': 1,
#            'van': 1,
#            'wilder': 1}),
#  FreqDist({'...': 1, 'all': 1, 'be': 1, 'deadpool': 1, 'heart': 1}),
#  FreqDist({"'": 3,
#            '-': 1,
#            'a': 1,
#            'be': 1,
#            'beckham': 1,
#            'can': 1,
#            'dave': 1,
#            'ever': 1,
#            'everything': 1,
#            'he': 1,
#            'hear': 1,
#            'helium': 1,
#            'it': 1,
#            'like': 1,
#            'look': 1,
#            'mouth': 1,
#            'of': 1,
#            'sex': 1,
#            'speak': 1}),
#  FreqDist({"'": 2, 'best': 1, 'movie': 1, 'r': 1, 'rat': 1}),
#  FreqDist({'deadpool': 1, 'in': 1, 'movie': 1, 'other': 1}),
#  FreqDist({'be': 1,
#            'exactly': 1,
#            'interpretation': 1,
#            'it': 2,
#            'say': 1,
#            'spoiler': 1,
#            'subject': 1,
#            'to': 1,
#            'what': 1,
#            'would': 1}),
#  FreqDist({'best': 1, 'have': 1, 'i': 1, 'movie': 1, 'see': 1}),
#  FreqDist({"'": 1,
#            '``': 2,
#            'and': 1,
#            'fun': 1,
#            'regina': 1,
#            'rhyme': 1,
#            'that': 1,
#            'why': 1,
#            'with': 1}),
#  FreqDist({'...': 1, 'deadpool': 1, 'rise': 1, 'the': 1}),
#  FreqDist({'awesome': 1, 'film': 1}),
#  FreqDist({'...': 1, 'wow': 1}),
#  FreqDist({'a': 1,
#            'amazing': 1,
#            'and': 1,
#            'best': 1,
#            'funny': 1,
#            'have': 1,
#            'hilarious': 1,
#            'i': 1,
#            'in': 1,
#            'long': 1,
#            'see': 1,
#            'super': 1,
#            'time': 1,
#            'very': 1}),
#  FreqDist({'deadpool': 1, 'keep': 1, 'like': 1, 'make': 1, 'movie': 1}),
#  FreqDist({'a': 1, 'marvel': 1, 'masterpiece': 1}),
#  FreqDist({'boring': 1,
#            'it': 1,
#            'love': 1,
#            'marvel': 1,
#            'movie': 1,
#            'other': 1,
#            'put': 1,
#            'shame': 1,
#            'the': 1,
#            'to': 1}),
#  FreqDist({'and': 1,
#            'for': 1,
#            'hotness': 1,
#            'quest': 1,
#            'reynolds': 1,
#            'ryan': 1,
#            'the': 1}),
#  FreqDist({'an': 1, 'immature': 1, 'romp': 1, 'unremarkable': 1}),
#  FreqDist({'(': 1, ')': 1, 'mild': 1, 'overrated': 1, 'spoiler': 1}),
#  FreqDist({'an': 1,
#            'be': 1,
#            'bring': 1,
#            'deadpool': 1,
#            'drudgery': 1,
#            'new': 1,
#            'nothing': 1,
#            'table': 1,
#            'that': 1,
#            'the': 1,
#            'to': 1,
#            'unfunny': 1}),
#  FreqDist({'-': 1,
#            '15': 1,
#            'best': 1,
#            'film': 1,
#            'first': 1,
#            'for': 1,
#            'into': 1,
#            'old': 1,
#            'r': 1,
#            'rat': 1,
#            'sneak': 1,
#            'their': 1,
#            'year': 1}),
#  FreqDist({'14': 1,
#            'a': 1,
#            'and': 1,
#            'as': 2,
#            'attention': 1,
#            'boring': 1,
#            'brainless': 1,
#            'o': 1,
#            'w**re': 1,
#            'y': 1}),
#  FreqDist({'monkey': 1,
#            'please': 1,
#            'porn': 1,
#            'stop': 1,
#            'the': 1,
#            'violent': 1}),
#  FreqDist({'...': 1, 'out': 1, 'walk': 1, 'we': 1}),
#  FreqDist({'a': 1, 'awesome': 1, 'of': 1, 'slice': 1}),
#  FreqDist({'dumb': 1, 'movie': 1}),
#  FreqDist({'a': 1,
#            'be': 1,
#            'better': 1,
#            'do': 2,
#            'film': 1,
#            'hard': 1,
#            'have': 1,
#            'if': 1,
#            'not': 1,
#            'r': 1,
#            'they': 1,
#            'would': 1}),
#  FreqDist({'2016': 1,
#            'begin': 1,
#            'ever': 1,
#            'most': 1,
#            'movie': 1,
#            'pathetic': 1,
#            'the': 1,
#            'with': 1}),
#  FreqDist({'a': 2,
#            'beautiful': 1,
#            'funny': 1,
#            'hero': 1,
#            'love': 1,
#            'of': 1,
#            'story': 1,
#            'super': 1}),
#  FreqDist({'brilliant': 1, 'comedy': 1, 'superhero': 1}),
#  FreqDist({'harry': 1, 'potter': 1}),
#  FreqDist({',': 1,
#            'and': 1,
#            'good': 1,
#            'job': 1,
#            'reynold': 1,
#            'team': 1,
#            'the': 1}),
#  FreqDist({'a': 1,
#            'about': 1,
#            'be': 1,
#            'deadpool': 1,
#            'go': 1,
#            'hell': 1,
#            'his': 3,
#            'life': 2,
#            'mercenary': 1,
#            'of': 1,
#            'rest': 1,
#            'save': 1,
#            'spend': 1,
#            'the': 1,
#            'thru': 1,
#            'to': 2,
#            'who': 1,
#            'wife': 1,
#            'with': 1}),
#  FreqDist({'/': 1, 'say': 1, 'tgchan': 1, 'tgchan.pl': 1, 'yes~': 1}),
#  FreqDist({'and': 1,
#            'as': 2,
#            'be': 1,
#            'bit': 1,
#            'every': 1,
#            'gratuitous': 1,
#            'it': 1,
#            'need': 1,
#            'profane': 1,
#            'to': 1,
#            'vile': 1}),
#  FreqDist({'..': 1,
#            '2': 1,
#            'a': 1,
#            'all': 1,
#            'be': 1,
#            'deserve': 1,
#            'do': 1,
#            'false': 1,
#            'more': 1,
#            'not': 1,
#            'of': 1,
#            'rating': 1,
#            'review': 1,
#            'than': 1}),
#  FreqDist({'a': 2,
#            'aside': 1,
#            'be': 1,
#            'couple': 1,
#            'fault': 1,
#            'from': 1,
#            'masterpiece': 1,
#            'of': 2,
#            'on': 1,
#            'the': 1,
#            'verge': 1}),
#  FreqDist({'and': 1,
#            'entertaining': 1,
#            'funny': 1,
#            'original': 1,
#            'outrageously': 1}),
#  FreqDist({'at': 1,
#            'but': 1,
#            'daft': 1,
#            'fantastic': 1,
#            'film': 1,
#            'time': 1}),
#  FreqDist({'cheap': 1, 'for': 1, 'kid': 1, 'movie': 1, 'story': 1}),
#  FreqDist({"'": 1,
#            '-': 1,
#            'a': 1,
#            'an': 1,
#            'but': 1,
#            'it': 1,
#            'little': 1,
#            'movie': 1,
#            'much': 1,
#            'not': 1,
#            'ok': 1,
#            'original': 1}),
#  FreqDist({'against': 1,
#            'all': 1,
#            'movie': 1,
#            'odds': 1,
#            'succeed': 1,
#            'that': 1,
#            'the': 1}),
#  FreqDist({'a': 1, 'charm': 1, 'like': 1, 'work': 1}),
#  FreqDist({'remember': 1, 'some': 1, 'thing': 1, 'to': 1}),
#  FreqDist({'miss': 1, 'opportunity': 1}),
#  FreqDist({'be': 1, 'how': 1, 'make': 1, 'movie': 1, 'should': 1, 'this': 1}),
#  FreqDist({'it': 1, 'love': 1}),
#  FreqDist({'best': 1,
#            'far': 1,
#            'man': 1,
#            'movie': 1,
#            'of': 1,
#            'one': 1,
#            'so': 1,
#            'the': 1,
#            'x': 1}),
#  FreqDist({'entertaining': 1, 'marvellous': 1, 'mix': 1, 'very': 1}),
#  FreqDist({'-': 1,
#            'be': 1,
#            'bind': 1,
#            'by': 1,
#            'filthy': 1,
#            'its': 1,
#            'movie': 1,
#            'origin': 1,
#            'refreshingly': 1,
#            'story': 1,
#            'superhero': 1,
#            'that': 1,
#            'trapping': 1}),
#  FreqDist({'bandwagon': 1,
#            'hero': 1,
#            'jump': 1,
#            'let': 1,
#            'make': 1,
#            'on': 1,
#            'super': 1,
#            'the': 1}),
#  FreqDist({'expect': 1, 'i': 1, 'what': 1}),
#  FreqDist({'film': 1, 'hype': 1, 'surpass': 1, 'the': 1}),
#  FreqDist({'``': 2,
#            'aspect': 1,
#            'begin': 1,
#            'every': 1,
#            'in': 1,
#            'surpasses': 1}),
#  FreqDist({'2008': 1, 'best': 1, 'down': 1, 'hand': 1, 'movie': 1, 'of': 1}),
#  FreqDist({'batman': 1,
#            'deserve': 1,
#            'sequel': 1,
#            'the': 2,
#            'to': 1,
#            'want': 1,
#            'we': 2}),
#  FreqDist({'-': 1,
#            'certainly': 1,
#            'dark': 1,
#            'the': 1,
#            'wait': 1,
#            'worth': 1}),
#  FreqDist({'.': 1, 'best': 1, 'comic': 1, 'ever': 1, 'movie': 1}),
#  FreqDist({'and': 1, 'at': 1, 'batman': 1, 'best': 1, 'beyond': 1, 'his': 1}),
#  FreqDist({'and': 1,
#            'dark': 1,
#            'film': 1,
#            'mood': 1,
#            'movie': 1,
#            'of': 2,
#            'really': 1,
#            'set': 1,
#            'sinister': 1,
#            'the': 4,
#            'theme': 1}),
#  FreqDist({'a': 1,
#            'batman': 1,
#            'book': 1,
#            'comic': 1,
#            'dream': 1,
#            'more': 1,
#            'movie': 1,
#            'much': 1,
#            'of': 1,
#            'our': 1,
#            'so': 1,
#            'than': 1,
#            'the': 1}),
#  FreqDist({'and': 1,
#            'as': 2,
#            'be': 1,
#            'best': 1,
#            'dark': 1,
#            'easily': 1,
#            'everyone': 1,
#            'film': 1,
#            'good': 1,
#            'knight': 1,
#            'make': 1,
#            'say': 1,
#            'superhero': 1,
#            'the': 2}),
#  FreqDist({'--': 2,
#            'batman': 1,
#            'best': 1,
#            'dark': 1,
#            'ever': 1,
#            'knight': 1,
#            'movie': 1,
#            'the': 1}),
#  FreqDist({"'s": 1,
#            'and': 1,
#            'brilliant': 1,
#            'dark': 1,
#            'heath': 1,
#            'ledger': 1,
#            'song': 1,
#            'swan': 1}),
#  FreqDist({'a': 1, 'batman': 1, 'of': 1, 'proportion': 1, 'shakesperean': 1}),
#  FreqDist({'be': 2,
#            'everyone': 1,
#            'i': 1,
#            'masterpiece': 1,
#            'no': 1,
#            'sorry': 1,
#            'this': 1}),
#  FreqDist({'best': 1,
#            'ever': 1,
#            'movie': 1,
#            'of': 1,
#            'one': 1,
#            'superhero': 1,
#            'the': 1}),
#  FreqDist({'fantastic': 1}),
#  FreqDist({'batman': 1, 'get': 1, 'just': 1, 'modern': 1, 'really': 1}),
#  FreqDist({'dark': 1, 'delivers': 1, 'knight': 1, 'the': 1}),
#  FreqDist({"'": 1,
#            'but': 1,
#            'good': 1,
#            'in': 1,
#            'keep': 1,
#            'let': 1,
#            'perspective': 1,
#            'thing': 1,
#            'very': 1,
#            'yikes': 1}),
#  FreqDist({'batty': 1,
#            'be': 1,
#            'best': 1,
#            'ever': 1,
#            'film': 1,
#            'must': 1,
#            'you': 1}),
#  FreqDist({'be': 1,
#            'but': 1,
#            'compare': 1,
#            'deserve': 1,
#            'do': 1,
#            'great': 1,
#            'masterpiece': 1,
#            'not': 1,
#            'to': 1,
#            'with': 1}),
#  FreqDist({"'": 1, 'be': 1, 'let': 1, 'realistic': 1}),
#  FreqDist({'ever': 1, 'film': 1, 'great': 1, 'make': 1, 'not': 1, 'the': 1}),
#  FreqDist({'a': 1, 'be': 1, 'heath': 1, 'ledgend': 1, 'ledger': 1}),
#  FreqDist({'a': 1,
#            'more': 1,
#            'movie': 1,
#            'nothing': 1,
#            'solid': 1,
#            'superhero': 1,
#            'tdk': 1}),
#  FreqDist({'everyone': 1,
#            'film': 1,
#            'fool': 1,
#            'have': 1,
#            'seem': 1,
#            'that': 1,
#            'the': 1,
#            'to': 1}),
#  FreqDist({'away': 1,
#            'be': 1,
#            'blow': 1,
#            'fan': 1,
#            'many': 1,
#            'seem': 1,
#            'to': 1,
#            'too': 1}),
#  FreqDist({'and': 1, 'boring': 1, 'incoherent': 1, 'surprisingly': 1}),
#  FreqDist({'-': 1,
#            ';': 1,
#            'a': 1,
#            'about': 1,
#            'and': 1,
#            'be': 2,
#            'bold': 1,
#            'concoction': 1,
#            'especially': 1,
#            'ever': 1,
#            'film': 1,
#            'get': 1,
#            'great': 1,
#            'idea': 1,
#            'interesting': 1,
#            'just': 1,
#            'less': 1,
#            'of': 1,
#            'progressively': 1,
#            'that': 1,
#            'the': 1,
#            'tread': 1,
#            'water': 1,
#            'which': 1,
#            'wild': 1,
#            'without': 1}),
#  FreqDist({'all': 1, 'as': 2, 'good': 1, 'hype': 1, 'not': 1, 'the': 1}),
#  FreqDist({'10': 1,
#            'be': 1,
#            'it': 1,
#            'of': 1,
#            'one': 1,
#            'really': 1,
#            'the': 1,
#            'top': 1}),
#  FreqDist({'be': 1,
#            'best': 1,
#            'ever': 1,
#            'made.\xef\xbb\xbf': 1,
#            'movie': 1,
#            'seriously': 1,
#            'the': 1,
#            'this': 1}),
#  FreqDist({'movie': 1, 'perfect': 1}),
#  FreqDist({"'": 2,
#            '...': 1,
#            '.then': 1,
#            'dark': 1,
#            'if': 1,
#            'knight': 1,
#            'not': 1,
#            'nothing': 1,
#            'the': 1}),
#  FreqDist({'action': 1, 'an': 1, 'more': 1, 'movie': 1, 'nothing': 1}),
#  FreqDist({'batman': 1, 'best': 1, 'film': 1, 'the': 1, 'yet': 1}),
#  FreqDist({'perfection': 1, 'undescribable': 1}),
#  FreqDist({'christopher': 1, 'masterpiece': 1, 'nolan': 1}),
#  FreqDist({'and': 1,
#            'bad': 1,
#            'batman': 1,
#            'be': 2,
#            'begin': 1,
#            'best': 1,
#            'by': 1,
#            'disappoint': 1,
#            'expect': 1,
#            'get': 1,
#            'i': 2,
#            'the': 2}),
#  FreqDist({'be': 1,
#            'how': 1,
#            'make': 1,
#            'movie': 1,
#            'should': 1,
#            'superhero': 1,
#            'wonderful': 1}),
#  FreqDist({'be': 2,
#            'emotionally': 1,
#            'movie': 1,
#            'over': 1,
#            'people': 1,
#            'rat': 1,
#            'the': 1,
#            'vote': 1}),
#  ...]

# %%
print test.popitem()
# Out:
# ('not', 1)

# %%
popList = []
for i in testList:
    popList.append(i.popitem)

# %%
print popList[[0]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-10f8e05be7dd> in <module>()
# ----> 1 print popList[[0]]
#
# TypeError: list indices must be integers, not list
