# %%
import os
import subprocess
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
import scipy
import requests
from imdbpie import Imdb
import nltk
import matplotlib.pyplot as plt
import urllib
from bs4 import BeautifulSoup
import nltk
import collections
import re
import csv
import psycopg2

# %matplotlib inline

# %%
import pandas as pd

df = pd.read_csv('/Users/Paul/Desktop/General_Assembly/DSI_SM_01/projects/01-projects-weekly/project-06/ALLMovieData.csv')

# %%
df = df[[1,2,3,4,5]]

# %%
df.tail(2)
# Out:
#                     title                                            reviews  \
# 53617  The Usual Suspects  Bryan Singer's The Usual Suspects is a clever ...
# 53618  The Usual Suspects  \n!!!! MAJOR SPOILER !!!!\n\nI remember watchi...
#
#        review_score  movie_score  genre
# 53617           1.0          8.6  Crime
# 53618           7.0          8.6  Crime

# %%
df.isnull().sum()
# Out:
# title           0
# reviews         0
# review_score    0
# movie_score     0
# genre           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53619 entries, 0 to 53618
# Data columns (total 5 columns):
# title           53619 non-null object
# reviews         53619 non-null object
# review_score    53619 non-null float64
# movie_score     53619 non-null float64
# genre           53619 non-null object
# dtypes: float64(2), object(3)
# memory usage: 2.0+ MB

# %%
df['reviews'] = df['reviews'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53619 entries, 0 to 53618
# Data columns (total 5 columns):
# title           53619 non-null object
# reviews         53619 non-null object
# review_score    53619 non-null float64
# movie_score     53619 non-null float64
# genre           53619 non-null object
# dtypes: float64(2), object(3)
# memory usage: 2.0+ MB

# %%
df.head(2)
# Out:
#           title                                            reviews  \
# 0  Raptor Ranch  I love movies and I also will check out most i...
# 1  Raptor Ranch  Even from the trailer, Raptor Ranch from the g...
#
#    review_score  movie_score   genre  \
# 0           2.0          3.0  Action
# 1           1.0          3.0  Action
#
#                                               review
# 0  The storyline is totally broken and built with...
# 1  The storyline is totally broken and built with...

# %%
df['reviews']

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer()
cv_fit=cv.fit_transform(df['reviews'])

# %%
print cv_fit
# Out:
#   (0, 39505)	1
#   (0, 43609)	1
#   (0, 3639)	3
#   (0, 3223)	1
#   (0, 72966)	2
#   (0, 11681)	1
#   (0, 46978)	1
#   (0, 43416)	1
#   (0, 33688)	1
#   (0, 51547)	1
#   (0, 49497)	1
#   (0, 4834)	1
#   (0, 72387)	1
#   (0, 72585)	1
#   (0, 57374)	1
#   (0, 66319)	3
#   (0, 29847)	1
#   (0, 60663)	1
#   (0, 9881)	1
#   (0, 26957)	1
#   (0, 9528)	1
#   (0, 27525)	1
#   (0, 35306)	1
#   (0, 11424)	1
#   (0, 3062)	1
#   :	:
#   (53618, 18239)	1
#   (53618, 46111)	1
#   (53618, 62082)	1
#   (53618, 12696)	1
#   (53618, 71817)	1
#   (53618, 43547)	1
#   (53618, 14697)	1
#   (53618, 59575)	1
#   (53618, 64185)	2
#   (53618, 3367)	1
#   (53618, 34719)	2
#   (53618, 38002)	1
#   (53618, 12142)	1
#   (53618, 64466)	2
#   (53618, 70908)	2
#   (53618, 669)	1
#   (53618, 38231)	1
#   (53618, 57220)	1
#   (53618, 9638)	1
#   (53618, 61599)	1
#   (53618, 47476)	1
#   (53618, 12903)	1
#   (53618, 36782)	1
#   (53618, 41314)	1
#   (53618, 15299)	1

# %%
print cv.get_feature_names()
165', u'1650', u'167', u'167million', u'1687', u'169', u'169m', u'16crore', u'16dec', u'16hour', u'16mm', u'16th', u'16x9', u'17', u'170', u'1700', u'17000', u'170min', u'171', u'1717', u'172', u'173', u'174', u'175', u'1757', u'1759', u'175min', u'176', u'176th', u'177', u'178', u'1789', u'178min', u'179', u'1791', u'179min', u'17s', u'17th', u'17year', u'17yr', u'17yrs', u'18', u'180', u'1800', u'1800s', u'180th', u'181', u'1810', u'182', u'1822', u'183', u'184', u'1844', u'185', u'1857', u'186', u'1860', u'1860s', u'1862', u'1863', u'1864', u'1868', u'187', u'1875', u'1881', u'1886', u'1887', u'1888', u'1888077', u'1890', u'1892', u'1897', u'18a', u'18m', u'18s', u'18th', u'18yo', u'18yr', u'19', u'190', u'1900', u'1900s', u'1901', u'1902', u'1903', u'1908', u'1909', u'1910', u'1910ish', u'1910s', u'1911', u'1912', u'19122', u'1914', u'1915', u'1916', u'1917', u'1918', u'1919', u'1920', u'1920s', u'1921', u'1922', u'1923', u'1924', u'1925', u'1926' ...

# %%
cv.get_stop_words
# Out:
# <bound method CountVectorizer.get_stop_words of CountVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)>

# %%
cv.analyzer
# Out:
# u'word'

# %%
print cv.ngram_range
# Out:
# (1, 1)

# %%
print cv.max_features
# Out:
# None

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
# tokenize the first review
count = word_tokenize(df['reviews'][0])
count
# Out:
# ['I',
#  'love',
#  'movies',
#  'and',
#  'I',
#  'also',
#  'will',
#  'check',
#  'out',
#  'most',
#  'independent',
#  'produced',
#  'pictures',
#  'as',
#  'well',
#  '.',
#  'When',
#  'I',
#  'saw',
#  'this',
#  'had',
#  'a',
#  'small',
#  'but',
#  'functional',
#  'budget',
#  ',',
#  'I',
#  'gave',
#  'it',
#  'a',
#  'chance',
#  '.',
#  'All',
#  'I',
#  'can',
#  'say',
#  'is',
#  'this',
#  '.',
#  'The',
#  'best',
#  'acting',
#  'in',
#  'this',
#  'movie',
#  'came',
#  'from',
#  'the',
#  'animated',
#  'creatures',
#  '.',
#  'The',
#  'script',
#  'is',
#  'weak',
#  'and',
#  'they',
#  'managed',
#  'to',
#  'include',
#  'almost',
#  'every',
#  'stereotype',
#  'that',
#  'has',
#  'ever',
#  'existed',
#  ',',
#  'yet',
#  'not',
#  'one',
#  'of',
#  'them',
#  'could',
#  'act',
#  '!',
#  'Seriously',
#  ',',
#  'you',
#  'will',
#  'spend',
#  'time',
#  'that',
#  'you',
#  'can',
#  'never',
#  'get',
#  'back',
#  'and',
#  'life',
#  'is',
#  'just',
#  'too',
#  'short',
#  'to',
#  'care',
#  '!',
#  'Do',
#  "n't",
#  'waste',
#  'your',
#  'time',
#  '.',
#  'Just',
#  'my',
#  'thoughts',
#  '!']

# %%
# make everything lower case
count = [w.lower() for w in count]

# %%
#remove special characters

# %%
from nltk.probability import FreqDist

mc = FreqDist(count) 


print 'frequency:' , FreqDist(count)
print 'most common:', mc.most_common(5)
# Out:
# frequency: <FreqDist with 80 samples and 108 outcomes>
# most common: [('.', 5), ('i', 5), ('and', 3), ('this', 3), ('is', 3)]

# %%
for i in df['reviews'][:5]:
    count = word_tokenize(df['reviews'][i])
    print count
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-95ed97f411c2> in <module>()
#       1 for i in df['reviews'][:5]:
# ----> 2     count = word_tokenize(df['reviews'][i])
#       3     print count
#
# /Users/Paul/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     558     def __getitem__(self, key):
#     559         try:
# --> 560             result = self.index.get_value(self, key)
#     561
#     562             if not lib.isscalar(result):
#
# /Users/Paul/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_value(self, series, key)
#    1909         try:
#    1910             return self._engine.get_value(s, k,
# -> 1911                                           tz=getattr(series.dtype, 'tz', None))
#    1912         except KeyError as e1:
#    1913             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_value (pandas/index.c:3234)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_value (pandas/index.c:2931)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3956)()
#
# KeyError: "I love movies and I also will check out most independent produced pictures as well. When I saw this had a small but functional budget, I gave it a chance.\n\nAll I can say is this. The best acting in this movie came from the animated creatures. \n\nThe script is weak and they managed to include almost every stereotype that has ever existed, yet not one of them could act!\n\nSeriously, you will spend time that you can never get back and life is just too short to care! Don't waste your time.\n\nJust my thoughts!"

# %% [markdown]
# # Clean the reviews!

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')
tokenizer.tokenize(str(i) for i in df['reviews'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-7345f6455e06> in <module>()
#       2
#       3 tokenizer = RegexpTokenizer(r'\w+')
# ----> 4 tokenizer.tokenize(str(i) for i in df['reviews'])
#
# /Users/Paul/anaconda/lib/python2.7/site-packages/nltk/tokenize/regexp.pyc in tokenize(self, text)
#     127         # If our regexp matches tokens, use re.findall:
#     128         else:
# --> 129             return self._regexp.findall(text)
#     130
#     131     def span_tokenize(self, text):
#
# TypeError: expected string or buffer

# %%
x = df['reviews'].astype(str)

# %%
FreqDist(MontyPython)

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

word_tokenize(i for i in x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-402d7a1733cd> in <module>()
#       1 from nltk.tokenize import sent_tokenize, word_tokenize
#       2
# ----> 3 word_tokenize(i for i in x)
#
# /Users/Paul/anaconda/lib/python2.7/site-packages/nltk/tokenize/__init__.pyc in word_tokenize(text, language)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     return [token for sent in sent_tokenize(text, language)
#     107             for token in _treebank_word_tokenize(sent)]
#     108
#
# /Users/Paul/anaconda/lib/python2.7/site-packages/nltk/tokenize/__init__.pyc in sent_tokenize(text, language)
#      89     """
#      90     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# ---> 91     return tokenizer.tokenize(text)
#      92
#      93 # Standard word tokenizer.
#
# /Users/Paul/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in tokenize(self, text, realign_boundaries)
#    1224         Given a text, returns a list of the sentences in that text.
#    1225         """
# -> 1226         return list(self.sentences_from_text(text, realign_boundaries))
#    1227
#    1228     def debug_decisions(self, text):
#
# /Users/Paul/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in sentences_from_text(self, text, realign_boundaries)
#    1272         follows the period.
#    1273         """
# -> 1274         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1275
#    1276     def _slices_from_text(self, text):
#
# /Users/Paul/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in span_tokenize(self, text, realign_boundaries)
#    1263         if realign_boundaries:
#    1264             slices = self._realign_boundaries(text, slices)
# -> 1265         return [(sl.start, sl.stop) for sl in slices]
#    1266
#    1267     def sentences_from_text(self, text, realign_boundaries=True):
#
# /Users/Paul/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in _realign_boundaries(self, text, slices)
#    1302         """
#    1303         realign = 0
# -> 1304         for sl1, sl2 in _pair_iter(slices):
#    1305             sl1 = slice(sl1.start + realign, sl1.stop)
#    1306             if not sl2:
#
# /Users/Paul/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in _pair_iter(it)
#     308     """
#     309     it = iter(it)
# --> 310     prev = next(it)
#     311     for el in it:
#     312         yield (prev, el)
#
# /Users/Paul/anaconda/lib/python2.7/site-packages/nltk/tokenize/punkt.pyc in _slices_from_text(self, text)
#    1276     def _slices_from_text(self, text):
#    1277         last_break = 0
# -> 1278         for match in self._lang_vars.period_context_re().finditer(text):
#    1279             context = match.group() + match.group('after_tok')
#    1280             if self.text_contains_sentbreak(context):
#
# TypeError: expected string or buffer
