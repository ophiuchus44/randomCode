# %%
from scipy import ndimage
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot([1,2,3,4,5])

# %%
img_ = plt.imread('/Users/jam3jam/Downloads/img_93907 copy2.jpg')
# img2 = np.asarray(img)[ np.asarray(img) < 255 ] 
np.asarray(img_)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-4b91b7374aaa> in <module>()
# ----> 1 img_ = plt.imread('/Users/jam3jam/Downloads/img_93907 copy2.jpg')
#       2 # img2 = np.asarray(img)[ np.asarray(img) < 255 ]
#       3 np.asarray(img_)
#
# /Users/Paul/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in imread(*args, **kwargs)
#    2288 @docstring.copy_dedent(_imread)
#    2289 def imread(*args, **kwargs):
# -> 2290     return _imread(*args, **kwargs)
#    2291
#    2292
#
# /Users/Paul/anaconda/lib/python2.7/site-packages/matplotlib/image.pyc in imread(fname, format)
#    1302
#    1303     if ext not in handlers:
# -> 1304         im = pilread(fname)
#    1305         if im is None:
#    1306             raise ValueError('Only know how to handle extensions: %s; '
#
# ...

# %%
from scipy import misc
f = misc.face()
misc.imsave('face.png', f)
plt.imshow(f)
plt.show()

# %%
from scipy import misc
face = misc.face()
misc.imsave('face.png', face)

# %%
face = misc.imread('face.png')
type(face)
face.shape,face.dtype
# Out:
# ((768, 1024, 3), dtype('uint8'))

# %%
f = misc.face(gray=True)
import matplotlib.pyplot as plt
plt.imshow(f, cmap=plt.cm.gray)

# %%
plt.imshow(f, cmap=plt.cm.gray, vmin=30, vmax=200)

# %%
plt.contour(f, [100, 150]) 
plt.gca().invert_yaxis()

# %%
plt.imshow(f[320:340, 510:530], cmap=plt.cm.gray)

# %%
plt.imshow(f[320:340, 510:530], cmap=plt.cm.gray, interpolation='nearest')

# %%
from IPython.display import Image
Image('http://www.scipy-lectures.org/_images/axis_convention.png')

# %%
import numpy as np
face = misc.face(gray=True)

# Slicing
face[10:13, 20:23]

face[100:120] = 255

lx, ly = face.shape
X, Y = np.ogrid[0:lx, 0:ly]
mask = (X - lx / 2) ** 2 + (Y - ly / 2) ** 2 > lx * ly / 4
# Masks
face[mask] = 0
# Fancy indexing
face[range(400), range(400)] = 255

# %%
plt.imshow(face, cmap=plt.cm.gray, vmin=30, vmax=200)

# %%
face.mean()
# Out:
# 87.375576019287109

# %%
face.max(), face.min()
# Out:
# (255, 0)

# %%
face = misc.face(gray=True)
lx, ly = face.shape
# Cropping
crop_face = face[lx / 4: - lx / 4, ly / 4: - ly / 4]
# up <-> down flip
flip_ud_face = np.flipud(face)
# rotation
rotate_face = ndimage.rotate(face, 45)
rotate_face_noreshape = ndimage.rotate(face, 45, reshape=False)

# %%
plt.imshow(crop_face)

# %%
plt.imshow(flip_ud_face)

# %%
plt.imshow(rotate_face_noreshape)

# %%
from scipy import misc
face = misc.face(gray=True)
blurred_face = ndimage.gaussian_filter(face, sigma=3)
very_blurred = ndimage.gaussian_filter(face, sigma=5)

# %%
plt.imshow(blurred_face)

# %%
plt.imshow(very_blurred)

# %%
filter_blurred_f = ndimage.gaussian_filter(very_blurred, 1)
alpha = 30
plt.imshow(filter_blurred_f)

# %%
sharpened = very_blurred + alpha * (very_blurred - filter_blurred_f)
plt.imshow(sharpened)

# %%
# YELP IMAGE PROCESSING

# %%
Aimg_ = plt.imread('/Users/Paul/Desktop/General_Assembly/DSI_SM_01/projects/Yelp4.jpg')
# img2 = np.asarray(img)[ np.asarray(img) < 255 ] 
tmp = np.asarray(Aimg_)
tmp
# Out:
# array([[[114, 108, 118],
#         [107, 102, 109],
#         [105,  98, 105],
#         ...,
#         [105,  99, 111],
#         [103,  98, 105],
#         [102,  97, 104]],
#
#        [[104,  99, 106],
#         [ 97,  90,  97],
#         [ 81,  75,  79],
#         ...,
#         [104,  98, 110],
#         [103,  98, 105],
#         [101,  96, 103]],
#
#        [[ 81,  75,  79],
#         [ 71,  65,  69],
#         [ 65,  59,  61],
#         ...,
#         [104,  98, 110],
#         [102,  97, 104],
#         [101,  96, 103]],
#
#        ...,
#        [[175, 170, 141],
#         [173, 168, 139],
#         [171, 166, 137],
#         ...,
#         [151, 151, 117],
#         [154, 148, 122],
#         [152, 146, 120]],
#
#        [[170, 165, 136],
#         [171, 166, 137],
#         [178, 173, 144],
#         ...,
#         [151, 144, 126],
#         [155, 149, 125],
#         [151, 145, 121]],
#
#        [[169, 164, 135],
#         [170, 165, 136],
#         [177, 172, 143],
# ...

# %%
tmp.argmax()
# Out:
# 28851

# %%
tmp.shape
# Out:
# (258, 258, 3)

# %%
tmp.max()
# Out:
# 255

# %%
tmp.min()
# Out:
# 0

# %%
tmp.mean()
# Out:
# 127.08944774953429

# %%
plt.imshow(Aimg_)
plt.show()

# %%
green = Aimg_[50:100, 150:200]

# %%
plt.imshow(green)

# %%
green.mean()
# Out:
# 81.057333333333332

# %%
green[20,40]
# Out:
# array([ 91, 122,  46], dtype=uint8)

# %%
green[35,35]
# Out:
# array([115, 143,  68], dtype=uint8)

# %%
green[25,25]
# Out:
# array([ 77, 114,  11], dtype=uint8)

# %%
plt.imshow(Aimg_[50:100, 150:200], cmap=plt.cm.gray)

# %%
import matplotlib.pyplot as plt
plt.imshow(Aimg_, cmap=plt.cm.gray)

# %%
plt.imshow(Aimg_, cmap=plt.cm.gray, vmin=30, vmax=200)

# %%
blurred_face = ndimage.gaussian_filter(Aimg_, sigma=3)
very_blurred = ndimage.gaussian_filter(Aimg_, sigma=5)

# %%
plt.imshow(blurred_face)

# %%
plt.imshow(very_blurred)

# %%
plt.contour(Aimg_, [100, 150]) 
plt.gca().invert_yaxis()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-540b4246fc83> in <module>()
# ----> 1 plt.contour(Aimg_, [100, 150])
#       2 plt.gca().invert_yaxis()
#
# /Users/Paul/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in contour(*args, **kwargs)
#    2764         ax.hold(hold)
#    2765     try:
# -> 2766         ret = ax.contour(*args, **kwargs)
#    2767     finally:
#    2768         ax.hold(washold)
#
# /Users/Paul/anaconda/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# ...

# %%
plt.contour(tmp, [100, 150]) 
plt.gca().invert_yaxis()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-a115c4011c4b> in <module>()
# ----> 1 plt.contour(tmp, [100, 150])
#       2 plt.gca().invert_yaxis()
#
# /Users/Paul/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in contour(*args, **kwargs)
#    2764         ax.hold(hold)
#    2765     try:
# -> 2766         ret = ax.contour(*args, **kwargs)
#    2767     finally:
#    2768         ax.hold(washold)
#
# /Users/Paul/anaconda/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# ...
