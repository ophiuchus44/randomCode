# %%
import pandas as pd

df = pd.read_csv('/Users/Paul/Desktop/General_Assembly/DSI_SM_01/projects/01-projects-weekly/project-06/summaryMovie.csv')

# %%
df.tail(2)
# Out:
#                     title       location  \
# 11036  The Usual Suspects  United States
# 11037  The Usual Suspects        UNKNOWN
#
#                                           summary_review  review_score  \
# 11036     a movie you need to watch twice to appreciate            9.0
# 11037  " the great trick the devil ever pull be convi...          10.0
#
#        movie_score  genre
# 11036          8.6  Crime
# 11037          8.6  Crime

# %%
print df.summary_review.unique()
# Out:
# ['really not good ' "you 're better off stay well clear from this ranch "
#  'so messy it should be raptor ranch dressing ... ' ...,
#  '" the usual suspect " simply fantastic '
#  'a film to watch over and over again for the first time '
#  'a movie you need to watch twice to appreciate ']

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
#tokenize the words of every summary
tmpList = []
for i in df.summary_review:
    tmp = word_tokenize(str(i))
    tmpList.append(tmp)

# %%
uhh = []
for i in tmpList:
    test = str(i)
    uhh.append(test)

# %%
uhh
# Out:
# ["['really', 'not', 'good']",
#  '[\'you\', "\'re", \'better\', \'off\', \'stay\', \'well\', \'clear\', \'from\', \'this\', \'ranch\']',
#  "['so', 'messy', 'it', 'should', 'be', 'raptor', 'ranch', 'dressing', '...']",
#  "['of', 'reptile', 'and', 'man']",
#  "['a', 'lot', 'better', 'then', 'people', 'say']",
#  "['what', 'a', 'f*ck', 'be', 'this']",
#  "['diversity', 'in', 'different', 'way']",
#  "['not', 'worth', 'watch']",
#  "['waste', 'of', 'time', 'and', 'money']",
#  '[\'it\', "\'", \'a\', \'real\', \'pain\', \'irrelevant\', \'story\', \'in\', \'the\', \'name\', \'of\', \'history\']',
#  '[\'manipulate\', \'bangladesh\', "\'s", \'liberation\', \'war\', \'history\']',
#  "['better', 'start', 'sell', 'pinup', 'magazine', 'on', 'the', 'street', '-', 'i', 'mean', 'it']",
#  "['to', 'yashraj', 'film', 'authority']",
#  "['worst', 'movie', 'and', 'historically', 'appropriate']",
#  "['a', 'big', 'protest', 'as', 'a', 'bangladeshi']",
#  "['wake', 'up', 'bollywood', 'plzzzzz']",
#  "['this', 'movie', 'change', 'the', 'main', 'history']",
#  "['this', 'film', 'have', 'start', 'disaster', 'in', 'bangladesh']",
#  '[\'it\', \'be\', \'bangladesh\', "\'s", \'liberation\', \'war\', \'against\', \'pakistan\']',
#  "['history', 'distortion']",
#  "['misrepresentation', 'of', 'the', 'history', 'of', '1971', 'liberation', 'war']",
#  "['bollywood', 'masala', 'action', 'film', 'its', 'not', 'base', 'on', 'fact']",
#  "['illiterate', 'and', 'uneducated', 'producer']",
#  "['poor', 'script', 'reflect', 'stupidity', 'of', 'ignorant', 'director', 'and', 'writer']",
#  "['worst', 'movie', 'in', 'the', 'world', 'history']",
#  '[\'manipulate\', \'bangladesh\', "\'s", \'liberation\', \'war\', \'history\']',
#  "['protest', ':', 'misinterpret', 'the', 'history', 'of', 'bangladesh', 'liberation', 'war', 'in', '1971']",
#  "['i', 'strongly', 'protest', 'this', 'movie']",
#  '[\'gunday\', \':\', \'manipulating\', \'bangladesh\', "\'s", \'liberation\', \'war\', \'history\']',
#  "['disappoint']",
#  "['be', 'we', 'sucker', 'for', 'entertainment', 'only']",
#  "['rubbish']",
#  "['wrong', 'history']",
#  "['nothing', 'but', 'a', 'bunch', 'of', 'lie', 'in', 'this', 'movie']",
#  "['humiliate', 'the', 'liberation', 'war', 'of', 'bangladesh', '1971']",
#  "['humilation', 'of', 'bangladesh', 'liberation', 'war']",
#  '[\'gunday\', \':\', \'an\', \'extreme\', \'manipulation\', \'of\', \'bangladesh\', "\'s", \'liberation\', \'war\', \'history\']',
#  "['a', 'famous', 'producer', 'like', 'aditya', 'chopra', 'should', 'not', 'have', 'make', 'this', 'type', 'of', 'movie', 'with', 'fake', 'history', 'this', 'be', 'lame', '...']",
#  "['false', 'statement', 'against', 'historical', 'truth']",
#  "['*', '*', '*', '*', '*', 'writer', 'need', 'to', 'do', 'more', 'research', 'before', 'make', 'a', 'film', '*', '*', '*', '*', '*']",
#  "['disgust', 'movie', ':', '/', 'yuck']",
#  "['most', 'disrespectful', 'offensive', 'and', 'humiliating', 'to', 'the', 'history', 'of', 'bangladesh']",
#  "['history', 'of', 'bangladesh', 'liberation', 'war', 'be', 'wrongly', 'plot']",
#  '[\'manipulate\', \'bangladesh\', "\'s", \'liberation\', \'war\', \'history\']',
#  "['a', 'fake', 'starting', 'and', 'history']",
#  "['shame', 'on', 'the', 'whole', 'team', 'of', 'this', 'movie']",
#  "['flase', 'information', 'and', 'an', 'awful', 'movie']",
#  "['critic']",
#  '[\'this\', \'movie\', "\'s", \'story\', \'line\', \'contempt\', \'our\', \'liberation\', \'war\']',
#  "['this', 'film', 'have', 'start', 'disaster', 'in', 'bangladesh']",
#  "['appal', 'plot', 'poor', 'fact', 'find', 'and', 'bad', 'possible', 'act']",
#  "['poor', 'screenplay', ':', 'writer', 'must', 'read', 'history', 'properly']",
#  "['historically', 'fraudulent', 'laughable', '...', '&', 'offensive']",
#  "['``', 'gunday', '``', 'humiliate', 'history', 'of', 'bangladesh']",
#  "['please', 'do', 'not', 'watch', 'the', 'movie', 'have', 'false', 'information', 'about', 'bangladesh', 'liberation', 'war']",
#  '[\'manipulate\', \'bangladesh\', "\'s", \'liberation\', \'war\', \'history\']',
#  "['bad', 'movie']",
#  '[\'abusive\', \'that\', "\'", \'all\', \'i\', \'can\', \'say\']',
#  "['this', 'movie', 'change', 'the', 'history', 'of', 'the', 'war', 'of', '1971']",
#  "['fake', 'information']",
#  "['bad', 'movie']",
#  "['the', 'very', 'best', 'lame', 'historical', 'movie', 'ever']",
#  "['shame', 'pity']",
#  "['what', 'the', 'hell']",
#  '[\'manipulate\', \'bangladesh\', "\'s", \'liberation\', \'war\', \'history\']',
#  '[\'manipulate\', \'bangladesh\', "\'s", \'liberation\', \'war\', \'history\']',
#  '[\'manipulate\', \'bangladesh\', "\'s", \'liberation\', \'war\', \'history\']',
#  "['protest']",
#  "['fatal', 'history', 'distortion']",
#  '[\'worst\', \'movie\', \'and\', \'manipulating\', \'bangladesh\', "\'s", \'liberation\', \'war\', \'history\']',
#  '[\'manipulation\', \'of\', \'bangladesh\', "\'s", \'history\', \'of\', \'liberation\', \'war\', \'against\', \'pakistan\']',
#  "['this', 'movie', 'contain', 'wrong', 'about', 'history', 'of', 'liberation', 'war', 'of', 'bangladesh']",
#  "['we', 'consider', 'the', 'mistake', 'in', 'your', 'film', 'to', 'be', 'unintended', 'therefore', 'apologize', 'to', 'u', 'and', 'correct', 'the', 'mistake', 'or', 'else', 'we', 'will', 'have', 'to', 'take', 'different', 'action', 'thank', 'you', '...']",
#  "['bollywood', 'movies-', 'shitty', 'as', 'always']",
#  '[\'a\', \'critic\', "\'s", \'comment\']',
#  '[\'misrepresentation\', \'of\', \'a\', \'country\', "\'s", \'libereation\', \'war\', \'history\']',
#  "['this', 'be', 'a', 'waste', 'of', 'my', 'time']",
#  "['gunday', '(', '2014', ')', ':', 'totally', 'a', 'quack', 'story']",
#  "['a', 'rubbish', 'with', 'no', 'background', 'study', 'and', 'research']",
#  "['history', 'misinterpret']",
#  "['no', 'idea', 'about', 'history']",
#  "['worst', 'movie', 'with', 'alteration', 'of', 'history']",
#  '[\'where\', "\'", \'the\', \'button\', \'to\', \'rate\', \'it\', \'in\', \'negative\']',
#  "['do', 'not', 'only', 'apologize', 'to', 'u', 'but', 'correct', 'the', 'mistake']",
#  "['be', 'film', 'maker', 'uneducated']",
#  "['history', 'be', 'not', 'fiction', 'dude', 'specially', 'when', 'you', 'be', 'deal', 'with', 'a', 'piece', 'of', 'it', 'where', '3', 'million', 'people', 'die']",
#  "['this', 'be', 'a', 'misrepresentation', 'of', 'the', 'history', '...']",
#  "['a', 'bad', 'try']",
#  "['a', 'time', 'pas', 'that', 'it']",
#  "['``', 'gunday', '``', '-', 'a', 'rabish', 'movie']",
#  "['protest', 'against', 'alteration', 'of', 'history', 'of', 'liberation', 'war', 'of', 'bangladesh']",
#  "['bad', 'script']",
#  "['a', 'deliberate', 'distortion', 'of', 'a', 'bloody', 'history']",
#  "['shame']",
#  "['strong', 'protest', 'against', 'the', 'humiliation', 'of', 'history']",
#  "['waste', 'of', 'time', 'and', 'money']",
#  "['very', 'very', 'good', 'film']",
#  "['false', 'historical', 'presentation']",
#  "['indian', 'need', 'only', 'entertain', 'movie', 'they', 'do', 'not', 'know', 'others', 'be', 'hearted', 'but', 'they', 'need', 'entertainment']",
#  "['strongly', 'protest']",
#  "['waste', 'of', 'time', 'and', 'energy']",
#  "['bangladesh', 'be', 'not', 'a', 'product', 'of', 'india', '-', 'pakistan', 'war']",
#  "['yash', 'raj', 'film', 'be', 'a', 'big', 'name', 'but', 'it', 'do', 'not', 'mean', 'that', 'u', 'can', 'change', 'our', 'history']",
#  '[\'the\', \'movie\', \'be\', \'send\', \'a\', \'wrong\', \'message\', \'regard\', \'the\', \'freedom\', \'war\', \'of\', \'bangladesh\', \'to\', \'it\', "\'", \'viewer\']',
#  "['shame', 'for', 'all', 'of', 'culprit', 'of', 'this', 'movie', 'maker']",
#  "['protest']",
#  "['manipulation', 'of', 'bangladesh', 'history']",
#  "['gunday', 'humiliated', 'history', 'of', 'bangladesh']",
#  "['about', 'the', 'worng', 'historical', 'background']",
#  "['``', 'gunday', '``', 'a', 'movie', 'which', 'be', 'the', 'face', 'of', 'indian', 'thought', 'against', 'liberation', 'war', 'of', 'bangladesh']",
#  "['manipulate', 'history']",
#  '[\'manipulation\', \'and\', \'misrepresentation\', \'of\', \'bangladesh\', "\'s", \'liberation\', \'war\', \'and\', \'it\', "\'", \'armed\', \'force\']',
#  "['at', 'beginning', 'of', 'this', 'movie', 'they', 'change', 'the', 'history', 'of', 'bangladesh']",
#  '[\'manipulate\', \'bangladesh\', "\'s", \'liberation\', \'war\', \'history\']',
#  "['historically', 'inaccurate', '&', 'offensive']",
#  "['a', 'movie', 'full', 'of', 'lie', 'and', 'manipulation']",
#  "['rubbish', 'fairy', '(', 'witch', ')', 'tale']",
#  "['i', 'strongly', 'protest', 'as', 'a', 'bangladeshi']",
#  '[\'it\', "\'", \'a\', \'mockery\', \'of\', \'pride\', \'and\', \'history\', \'of\', \'bangladesh\']',
#  "['this', 'movie', 'should', 'be', 'sued', 'and', 'yash', 'raj', 'film', 'should', 'be', 'take', 'to', 'the', 'court', 'of', 'justice']",
#  "['gunday-', 'grow', 'up', 'yrf', 'lame', 'script', 'and', 'awful', 'direction', 'may', 'help', 'you', 'financially', 'but', 'be', 'that', 'enough']",
#  "['i', 'strongly', 'protest', 'as', 'a', 'bangladeshi']",
#  "['corruption', 'of', 'history']",
#  "['a', 'film', 'which', 'tamper', 'a', 'country', 'honor', 'and', 'independent']",
#  "['the', 'big', 'lie']",
#  '[\'manipulate\', \'bangladesh\', "\'s", \'liberation\', \'war\', \'history\']',
#  "['gunday', '-', 'worst', 'story', 'ever', 'but', 'good', 'actor']",
#  "['completely', 'nonsense']",
#  "['play', 'video', 'game']",
#  "['contains', 'twisted', 'international', 'history']",
#  "['it', 'give', 'false', 'information', 'about', 'liberation', 'war', 'of', 'banglladesh']",
#  "['a', 'close', 'observation', 'from', 'a', 'bangladeshi', 'viewer']",
#  "['wrong', 'history']",
#  "['morality', 'of', 'the', 'movie']",
#  "['gunday', 'the', 'bad', 'film', 'ever', 'make', 'in', 'history']",
#  "['misrepresentation', 'of', 'the', 'history', '(', 'most', 'importantly', ')']",
#  "['wrong', 'history']",
#  "['only', 'hate', 'for', 'this', 'film', 'and', 'its', 'associate']",
#  "['manipulation', 'of', 'of', 'the', 'liberation', 'war', 'of', 'bangladesh', 'misleading', 'fact', 'overall', 'disrespectful']",
#  "['this', 'be', 'a', 'total', 'disgrace', '...', '.']",
#  "['insult', 'bangladesh', 'history', ',', 'tradition', 'by', 'put', 'fake', 'story']",
#  "['review']",
#  "['wrong', 'history', 'lawra']",
#  "['rat', '-1.00', '...', '.', '...', 'world', 'most', 'baddest', 'movie', 'ever', '...']",
#  "['this', 'film', 'be', 'pervert', 'our', 'liberation', 'war']",
#  '[\'manipulate\', \'bangladesh\', "\'s", \'liberation\', \'war\', \'history\', \'protest\', \'as\', \'a\', \'bangladeshi\']',
#  "['bad', 'movie']",
#  "['pseudo', '-', 'intellectualism']",
#  "['its', 'such', 'a', 'shame', 'for', 'yrf']",
#  "['yrf', 'insult', 'the', 'history']",
#  "['a', 'movie', 'be', 'a', 'work', 'of', 'fiction', 'but', 'when', 'it', 'use', 'historical', 'fact', 'that', 'should', 'be', 'accurate']",
#  '[\'false\', \'information\', \'about\', \'bangladesh\', "\'s", \'liberation\', \'war\']',
#  "['rubbish', 'storyline', 'and', 'base', 'on', 'false', 'information', 'about', 'liberation', 'war', 'of', 'bangladesh', '1971']",
#  "['i', 'protest', 'against', 'the', 'idiocy', 'of', 'the', 'movie']",
#  "['bullsit', 'movie']",
#  "['a', 'movie', 'base', 'on', 'fallacy', 'and', 'cheap', 'business']",
#  "['this', 'be', 'a', 'slap', 'on', 'the', 'face', 'of', 'all', 'the', 'people', 'of', 'bangladesh']",
#  "['manipulation', 'of', 'history']",
#  "['crap', 'that', 'crap', 'crap']",
#  '[\'it\', "\'", \'manupulated\', \'the\', \'history\']',
#  "['disgust']",
#  "['very', 'bad', 'story', 'a', 'good', 'try', 'to', 'temper', 'the', 'history']",
#  "['insane', 'title', 'by', 'manipulate', 'the', 'history']",
#  '[\'there\', "\'", \'nothing\', \'but\', \'distortion\', \'of\', \'great\', \'history\', \'...\', \'such\', \'a\', \'nasty\', \'film\']',
#  "['the', 'bad', 'movie', 'in', 'history', 'for', 'plot', 'bangladesh', 'history', 'wrongly']",
#  "['indian', 'people', 'should', 'know', 'how', 'to', 'respect', 'others']",
#  "['gunday', 'be', 'a', 'rubbish', 'and', 'foul', 'movie']",
#  "['dear', 'yashraj', 'film', 'authority', 'greeting']",
#  "['excellent', 'act', 'interesting', 'plot', 'stunning', 'locale', 'and', 'cinematography']",
#  "['comedy', 'film', 'excellent']",
#  "['gunday', 'be', 'daring', 'attempt', 'to', 'come', 'out', 'this', 'year']",
#  "['one', 'of', 'the', 'bad', 'hindi', 'movie', 'i', 'have', 'ever', 'see']",
#  "['rotten', 'tomatoo']",
#  "['misleading', ',', 'fraudulent', 'disrespectful', 'to', 'the', 'sovereignty', 'of', 'a', 'nation']",
#  "['protest']",
#  "['how', 'bollywood', 'release', 'this', 'kind', 'of', 'movie']",
#  "['bad', 'movie', 'plot', 'in', 'the', 'history', 'of', 'cinema']",
#  "['protest', 'on', 'present', 'wrong', 'history']",
#  "['historically', 'fraudulent', 'laughable', '...', '&', 'offensive', '(', 'most', 'importantly', ')']",
#  "['factually', 'inaccurate', 'and', 'a', 'total', 'killjoy']",
#  "['disturb', 'and', 'creepy', 'foolish', 'attempt', 'and', 'someone', 'kill', 'me', 'before', 'i', 'get', 'into', 'a', 'hate', '-', 'group', 'of', 'hindustan', 'cheesiness']",
#  "['what', 'if', 'a', 'movie', 'on', 'devyani', 'khobragade', 'would', 'contain', 'a', 'storyline', 'that', 'she', 'be', 'actually', 'a', 'prostitute', 'in', 'the', 'u']",
#  "['learn', 'to', 'respect']",
#  "['show', 'the', 'proper', 'respect', 'to', 'a', 'nation']",
#  "['i', 'be', 'against', 'you', 'as', 'a', 'bangladeshi']",
#  "['the', 'intro', 'be', 'fake']",
#  "['a', 'movie', 'base', 'on', 'false', 'history']",
#  '[\'manipulate\', \'bangladesh\', "\'s", \'liberation\', \'war\', \'history\']',
#  "['main', 'story', 'be', 'a', 'war', 'between', 'bangladesh', 'and', 'pakistan', 'that', 'be', 'happen', 'on', '1971', 'but', 'the', 'movie', 'director', 'change', 'the', 'story', 'and', 'tell', 'that', 'war', 'be', 'between', 'india', 'and', 'pakistan']",
#  "['fraud', 'with', 'history']",
#  "['total', 'masala', 'movie', 'which', 'you', 'just', 'love', 'to', 'watch']",
#  "['good', 'fare', 'though', 'historically', 'incorrect']",
#  "['rubbish', 'act', 'ranveer', 'singh', 'arjun', 'kapoor', 'priyanka', 'chopra', 'waste', 'of', 'time', 'poor']",
#  "['wrong', 'history', 'of', 'bangladesh', 'liberation', 'war']",
#  "['wrong', 'time', 'line']",
#  "['despicable']",
#  "['humiliating', 'bangladeshi', 'liberation', 'war']",
#  "['very', 'shameful', 'act', 'by', 'the', 'producer']",
#  "['distortion', 'of', 'the', 'history', 'of', 'our', 'liberation', 'war']",
#  "['apology', 'be', 'not', 'enough']",
#  '[\'india\', "\'s", \'worst\']',
#  "['should', 'bring', 'them', 'to', 'justice', 'for', 'gunday']",
#  "['a', 'pathetic', 'historical', 'movie', 'ever', 'see']",
#  "['the', 'most', 'ugly', 'and', 'lie', 'historical', 'movie', 'in', 'indian', 'industry']",
#  "['protest']",
#  "['rubbish', 'story', 'line', 'bad', 'acting', 'a', 'complete', 'waste', 'of', 'time']",
#  "['irrelevant', 'information', 'and', 'time', 'waste', 'event']",
#  "['say', 'no', 'to', 'gunday']",
#  "['we', 'know', 'how', 'this', 'one', 'will', 'go', 'without', 'even', 'watch', 'it', '...']",
#  "['true', 'rating', '-1']",
#  "['oh', 'good', 'grief']",
#  '[\'i\', \'enjoy\', \'this\', \'but\', \'i\', \'suggest\', \'wait\', \'until\', \'it\', "\'", \'in\', \'the\', \'$\', \'1\', \'bin\']',
#  "['do', 'not', 'bother']",
#  "['one', 'of', 'the', 'bad', 'movie', 'in', 'a', 'long', 'long', 'time']",
#  "['please', 'please', 'stay', 'away', 'from', 'this', 'movie']",
#  "['inane', 'bread', 'loaf', 'for', 'few']",
#  "['not', 'the', 'sequel', 'to', '``', 'independence', 'day', '``', '(', '1996', ')']",
#  "['sh*t', 'sandwich']",
#  "['bad', 'poorly', 'act']",
#  "['do', 'not', 'spend', 'a', 'dime', 'on', 'this', 'one']",
#  "['wow', 'that', 'bad', 'huh']",
#  "['this', 'movie', 'be', 'remarkable']",
#  "['independent', 'day', 'perfect', 'b', 'movie', 'scfi', 'action']",
#  "['bad', 'really', 'bad']",
#  "['do', 'not', 'even', 'waste', '2', 'minute', 'of', 'your', 'life', 'on', 'this']",
#  "['pathetic', 'movie', 'i', 'have', 'ever', 'see']",
#  "['the', 'bad', 'i', 'have', 'see', 'ever']",
#  '["c\'mon", \'people\', \'lighten\', \'up\', \'and\', \'lower\', \'your\', \'expectation\', \'a\', \'bit\', \'(\', \'mild\', \'spoiler\', \')\']',
#  "['sarah', 'pallin']",
#  "['the', 'worst', 'movie']",
#  '[\'may\', \'make\', \'sense\', \'if\', \'it\', \'be\', \'truly\', \'a\', "\'", \'spoof\', "\'"]',
#  "['can', 'sci', '-', 'fi', 'really', 'be', 'that', 'bad']",
#  "['good', 'movie', 'for', 'low', 'budget']",
#  "['people', 'be', 'confused', 'about', 'this', 'film']",
#  "['ok', 'movie', 'for', 'a', 'low', 'budget', 'film', 'but', 'not', 'good', 'enough', 'to', 'be', 'a', 'must', 'see', 'film']",
#  "['the', '3-d', 'thing', 'do', 'not', 'work', 'for', 'me', 'but', 'there', 'be', 'still', 'enough', 'style', 'and', 'silliness', 'to', 'amuse', 'both', 'kid', 'and', 'adult']",
#  "['irredeemably', 'stupid']",
#  "['fun', 'for', 'the', 'little', 'one', 'but', 'the', 'series', 'be', 'get', 'stale']",
#  "['fun', 'but', 'not', 'overwhelming']",
#  "['my', 'kid', 'like', 'it']",
#  "['would', 'have', 'be', 'average', 'at', 'best', 'without', 'the', '3-d', '...']",
#  "['latin', 'magic']",
#  "['it', 'may', 'be', '3-d', 'but', 'the', 'film', 'be', 'still', 'flat']",
#  "['the', 'spy', 'kid', 'franchise', 'end', 'on', 'a', 'bad', 'note']",
#  "['game', 'over', 'indeed']",
#  "['surpass', 'all', 'expectation']",
#  "['if', 'you', 'have', 'any', 'sense', 'do', 'not', 'watch', 'this', 'movie']",
#  "['an', 'exciting', 'adventure', 'for', 'mostly', 'little', 'kid', '-', 'see', 'it', 'in', 'your', '3-d', 'glass']",
#  "['virtual', 'fun', 'make', 'this', 'third', 'installment', 'virtually', 'the', 'best', 'one']",
#  "['cheesy', 'comic', 'fun']",
#  "['well', '-', 'put-together', 'film']",
#  "['while', 'rodriguez', 'be', 'clearly', 'a', 'gifted', 'filmmaker', 'he', 'let', 'the', '3-d', 'hamper', 'his', 'creative', 'imagination', '...', '.']",
#  "['cute', 'and', 'better', 'than', 'the', 'second']",
#  '[\'3d\', \'that\', "\'", \'good\']',
#  "['flippies', 'ridiculous']",
#  "['surpass', 'all', 'expectation']",
#  "['lose', 'in', 'computer', '-', 'land']",
#  "['very', 'cool', 'fun']",
#  "['horrid']",
#  "['come', 'on', 'people', 'give', 'it', 'a', 'break']",
#  "['a', 'disappointing', 'end', 'to', 'the', 'series']",
#  "['i', 'like', 'all', '3', 'spy', 'kid', 'movie', 'but', 'part', '3', 'be', 'the', 'best']",
#  "['it', 'be', 'the', 'cool', 'movie', 'i', 'have', 'ever', 'see']",
#  "['i', 'think', 'this', 'film', 'be', 'great']",
#  "['no']",
#  "['so', 'many', 'thing']",
#  "['please', 'let', 'the', 'game', 'be', 'over']",
#  "['the', '3d', 'effect', 'installment']",
#  "['devious', 'stallone', 'the', 'star', 'of', 'celebrity', 'fill', 'kid', 'flick']",
#  "['really', 'good']",
#  "['keep', 'in', 'mind', 'that', 'i', 'do', 'not', 'see', 'the', 'first', '2']",
#  "['the', 'game', 'just', 'may', 'be', 'over', '...']",
#  "['your', 'reward']",
#  "['creative', 'story', 'poor', 'vision']",
#  "['half', 'a', 'good', 'movie']",
#  "['not', 'to', 'good', 'the', 'third', 'time', 'around']",
#  "['cynicism', 'they', 'name', 'be', 'hollywood', '(', 'as', 'if', 'we', 'do', 'not', 'know', ')']",
#  "['one', 'helluva', 'surprise']",
#  "['a', 'fitting', 'coda', 'to', 'a', 'modestly', 'well', 'do', 'series', 'of', 'film']",
#  "['some', 'may', 'hate', 'some', 'may', 'love', 'worth', 'see', 'though']",
#  '["\'", \'great\', \'story\', \'mom\', \'but\', \'it\', \'need\', \'a\', \'new\', \'ending\', "\'", \'-\', \'carmen\', \'cortez\', \'spy\', \'kid\', \'1\', \'-\', \'spoiler\']',
#  "['the', 'spy', 'kid', 'movie', 'be', 'start', 'to', 'sag', '(', 'spoiler', ')']",
#  "['3-d', 'thing', 'be', 'a', 'waste', 'of', 'time']",
#  "['oh', 'my', 'eye']",
#  "['i', 'like', 'this', 'better', '...', 'when', 'it', 'be', 'call', 'tron', '.']",
#  "['improved', 'from', '2nd', 'one']",
#  "['oooo', 'my', 'eye', 'hurt', '...', 'what', 'be', 'this', 'about', 'anyway']",
#  "['3-d', 'as', 'in', 'three', 'time', 'dumb', 'than', 'its', 'predecessor']",
#  "['good', 'movie', 'star', 'movie', 'star']",
#  "['i', 'spy', 'with', 'my', 'little', 'eye', '-', 'crap']",
#  "['thin', 'story', 'save', 'by', 'great', 'special', 'fx']",
#  "['its', 'ok']",
#  '[\'it\', "\'", \'tron\', \'for\', \'kid\']',
#  "['one', 'big', 'commercial']",
#  "['great', 'but', 'somethings', 'be', 'not', 'so', 'great']",
#  "['i', 'think', 'it', 'need', 'more', 'effort']",
#  "['game', 'over', 'i', 'could', 'not', 'wait', 'for', 'this', 'movie', 'to', 'be', 'over']",
#  "['3-disappoint']",
#  "['not', 'the', 'great', '3-d', 'effect']",
#  "['what', 'a', 'way', 'to', 'go']",
#  "['an', 'abomination']",
#  '[\'it\', "\'", \'a\', \'kid\', "\'s", \'flick\', \'and\', \'my\', \'kid\', \'be\', \'satisfied\']',
#  "['positive', 'vibe', 'spin', 'on', 'the', 'matrix', 'with', 'scene', 'from', 'star', 'war']",
#  "['it', 'be', 'still', 'a', 'great', 'kid', 'movie']",
#  "['this', 'be', 'the', 'bad']",
#  '[\'i\', \'know\', \'this\', \'be\', \'a\', \'kid\', "\'s", \'movie\', \'but\', \'...\']',
#  "['its', 'a', 'kid', 'movie', 'fer', '-', 'christ-sake']",
#  "['despite', 'clever', 'use', 'of', '3-d', 'only', 'a', 'mediocre', 'effort']",
#  "['this', 'movie', 'be', 'goddamn', 'good', 'i', 'will', 'fight', 'anyone', 'who', 'say', 'otherwise']",
#  "['the', 'kid', 'love', 'it', 'the', 'parent', 'loathe', 'it']",
#  "['big', 'spy', 'kid', 'fan']",
#  '["\'", \'spy\', \'kid\', \'3-d\', \':\', \'game\', \'over\', "\'", \'be\', \'just\', \'a\', \'fun\', \'summer\', \'movie\']',
#  "['self', 'indulgent', 'waste', 'of', 'electricity']",
#  '[\'thank\', \'goodness\', \'it\', "\'", \'game\', \'over\']',
#  "['what', 'a', 'let', 'down']",
#  "['well', 'what', 'kind', 'of', 'script', 'can', 'you', 'really', 'expect']",
#  "['headache', 'cause', 'summer', 'film']",
#  "['great', 'movie', 'for', 'kid']",
#  "['better', 'than', 'the', 'first', '2-d']",
#  "['definitely', 'fun', 'for', 'the', 'kid']",
#  "['not', 'the', 'best', 'in', 'the', 'franchise', 'but', '...']",
#  "['spy', 'kid', '3-d', ':', 'a', 'pain', 'in', 'the', 'eye']",
#  "['nice', '3d', 'effect']",
#  "['game', 'over', '...', 'we', 'can', 'only', 'hope']",
#  "['rodriguez', 'do', 'it', 'again']",
#  "['the', 'critic', 'be', 'right', 'about', 'this', 'one']",
#  "['this', 'one', 'do', 'not', 'compare', 'to', 'the', 'other', 'two']",
#  "['worth', 'see']",
#  "['not', 'as', 'multi', '-', 'dimensional', 'as', 'the', 'title', 'would', 'suggest']",
#  "['should', 'this', 'be', 'a', 'weekly', 'saturday', 'morning', 'show']",
#  "['irritate', '3d', 'video', 'game', 'adventure', 'with', 'funny', 'ending']",
#  "['3d', 'be', 'too', 'hard', 'to', 'watch', 'would', 'have', 'be', 'better', 'in', '2d', '.']",
#  "['fun', 'with', 'third', '...']",
#  "['a', 'perfect', 'movie', 'except', 'for', 'the', 'eyestrain']",
#  "['spy', 'kid', '3-d', 'or', 'not']",
#  "['great', 'movie']",
#  "['a', 'dreary', 'disappointment']",
#  "['promise', 'but', 'uneven']",
#  "['thanks', 'god', 'be', 'over']",
#  "['do', 'not', 'think', 'they', 'could', 'make', 'anything', 'bad']",
#  '[\'good\', \'for\', \'kid\', \'parent\', "\'s", \'wo\', \'not\', \'be\', \'too\', \'bored\', \'...\']',
#  "['3d', 'not', 'even']",
#  "['the', '3-d', 'image', 'have', 'plenty', 'of', 'stuff', 'to', 'do', 'with', 'the', 'movie', 'because', 'after', 'all', 'they', 'be', 'not', 'go', 'to', 'make', 'a', 'fourth', 'i', 'bet']",
#  "['zeitgeist', 'baby']",
#  "['garbage']",
#  "['for', 'rodriguez', 'this', 'series', 'have', 'just', 'lose', 'its', 'third', 'life', 'game', 'over']",
#  "['the', '3-d', 'glass', 'will', 'give', 'you', 'a', 'headache']",
#  "['vision', 'vs.', 'presentation', '(', 'how', 'to', 'enjoy', 'a', '3d', 'movie', ')']",
#  "['story', 'negligible', 'eye', '-', 'candy', 'awesome']",
#  "['please', 'people', 'do', 'not', 'waste', 'your', 'money', 'on', 'this', 'film']",
#  "['charming', 'and', 'fresh', 'but', 'more', 'eye', 'candy', '(', 'hence', 'less', 'story', '...', ')']",
#  "['the', 'worst', 'movie', 'ever', 'make']",
#  "['graphic', 'steal', 'the', 'show']",
#  '["\'", \'game\', \'over\', "\'", \'never\', \'even\', \'start\']',
#  "['at', 'least', 'it', 'be', 'in', 'smell', '-', 'o-vision']",
#  "['imaginative', 'enjoyable', 'family', 'adventure']",
#  "['bad', 'glass', 'do', 'not', 'help', 'this', 'so', '-', 'so', '3-d', 'movie']",
#  "['a', 'dreadful', 'final', 'entry', 'for', 'the', 'spy', 'kid']",
#  "['the', 'bad', 'film', 'of', '2003', '...', 'in', 'painful', '3-d']",
#  "['muddled', 'muddy', 'mess']",
#  "['see', 'bit', 'and', 'piece']",
#  "['pure', 'trash']",
#  "['hello', 'the', 'film', 'be', 'much', 'exiting', 'and', '...', '.']",
#  "['four', 'tylenol', 'and', 'a', 'couple', 'of', 'dramamine', 'later']",
#  "['the', 'great', 'movie', 'i', 'have', 'see', 'this', 'year']",
#  "['this', 'movie', 'be', 'so', 'cool']",
#  "['3d', 'suck']",
#  "['well', 'put', 'together', 'piece', 'of', 'garbage']",
#  "['fun']",
#  "['fun', 'and', 'different', 'but', 'the', 'franchise', 'go', 'out', 'fall']",
#  "['insert', 'coin']",
#  "['horrible', 'movie']",
#  "['not', 'as', 'good', 'as', 'the', 'first', 'two']",
#  "['very', 'poorly', 'do', 'ashamed']",
#  "['disappoint']",
#  "['my', 'eye', 'hurt', 'horribly', 'when', 'i', 'saw', 'this', 'movie', 'oh', 'yeah', 'and', 'the', '3d', 'suck', 'too']",
#  "['eh', '...', '.']",
#  "['you', 'would', 'have', 'more', 'fun', 'look', 'at', 'a', 'glass', 'of', 'water']",
#  "['great', 'cast', 'with', 'a', 'horrible', 'script']",
#  "['good', 'concept', 'bad', 'story']",
#  "['a', 'big', 'unsatisfying', 'gimmick']",
#  "['bad', 'movie', 'ever', 'make', '...', '.']",
#  "['horrible', 'part', 'of', 'two', 'great', 'movie']",
#  "['much', 'better', 'on', 'video', 'than', 'in', 'the', 'theater']",
#  "['proof', 'that', 'sequel', 'be', 'not', 'necessary']",
#  "['mr.', 'rodriguez', 'what', 'happen']",
#  "['one', 'spy', 'kid', 'too', 'many']",
#  "['do', 'i', 'have', 'a', 'right', 'to', 'be', 'angry']",
#  "['ok', 'for', 'a', 'an', 'hour', '3d', 'movie']",
#  "['painfully', 'pathetic', 'movie']",
#  "['i', 'give', 'it', 'point', 'for', 'effort', '(', 'may', 'have', 'spoiler', ')']",
#  '[\'3d\', \'special\', \'effect\', \'...\', \'that\', "\'", \'all\']',
#  "['not', 'as', 'good', 'as', 'the', 'first', '...']",
#  "['this', '3d', 'be', 'doa']",
#  "['be', 'that', 'my', 'career', 'burn']",
#  "['part', 'of', 'sequel', 'burnout', 'summer']",
#  "['lord', 'almighty', 'what', 'an', 'awful', 'film']",
#  "['i', 'have', 'be', 'betray']",
#  "['spy', 'kid', '3-d', ':', 'game', 'over', ':', '4/10']",
#  "['the', 'movie', 'that', 'take', 'all', 'the', 'bad', 'out', 'of', 'the', 'others']",
#  "['very', 'well', 'done']",
#  "['about', 'as', 'exciting', 'as', 'watch', 'the', 'grass', 'grow']",
#  '[\'i\', \'can\', \'not\', \'believe\', \'i\', \'watch\', \'the\', \'whole\', \'thing\', \'it\', "\'", \'really\', \'bad\']',
#  "['i', 'want', 'my', 'hour', 'and', 'a', 'half', 'back']",
#  "['the', 'last', 'of', 'the', 'spy', 'kid', 'movie']",
#  "['if', 'mst3k', 'be', 'still', 'run', '...']",
#  "['bad', 'screenplay', '...', 'ever']",
#  "['gone', 'be', 'the', 'day', 'of', 'the', 'gadget', 'and', 'imaginative', 'idea']",
#  "['not', 'bad', 'not', 'good']",
#  "['give', 'the', 'name', 'in', 'front', 'of', 'the', 'camera', 'be', 'what', 'they', 'be', 'and', 'that', 'robert', 'rodriguez', 'be', 'the', 'one', 'propel', 'the', 'project', 'it', 'be', 'remarkable', 'just', 'how', 'awful', 'this', 'really', 'be']",
#  "['game', 'over']",
#  "['3-d', 'my', 'arse']",
#  "['spy', 'kid', '3-d', ':', 'game', 'over']",
#  "['it', 'stink', 'like', 'a', 'skunk']",
#  "['bad', 'movie', 'ever']",
#  "['how', 'horrible', 'can', 'a', 'movie', 'be']",
#  "['after', 'two', 'good', 'film', 'such', 'a', 'disappointment']",
#  "['do', 'not', 'waste', 'your', 'time', '...']",
#  "['baad']",
#  "['what', 'the', 'hell', 'be', 'that']",
#  "['not', 'awful', 'but', 'could', 'have', 'be', 'much', 'better']",
#  "['awful', 'awful', 'awful']",
#  "['why', 'robert', 'rodriguez', '...', '.', '..', 'why']",
#  "['really', 'enjoyed', 'the', 'first', 'thirty', 'minute', 'get', 'pretty', 'bland', 'after', 'that']",
#  "['what', 'indie', 'thriller', 'cinema', 'be', 'all', 'about']",
#  '[\'the\', \'ole\', "\'", \'college\', \'try\']',
#  "['better', 'once', 'it', 'stop', 'try', 'to', 'be', 'a', 'tarantino', 'film']",
#  "['keating', ';', 'cut', 'his', 'teeth', 'or', 'just', 'not', 'cut', 'out']",
#  "['good', 'flick', 'worth', 'a', 'watch']",
#  "['do', 'not', 'deserve', 'this', 'low', 'rating']",
#  "['chemtrails', 'and', 'bad', 'music']",
#  "['derivative']",
#  "['a', 'dumb', 'b', '-', 'horror', 'movie', ',', 'very', 'low', 'on', 'content']",
#  "['wow', 'what', 'a', 'great', 'movie', '!', '.']",
#  "['well', 'i', 'enjoy', 'it']",
#  "['better', 'than', 'the', 'previous', 'one']",
#  "['an', 'enjoyable', 'fantasy', 'film', 'with', 'a', 'positive', 'message']",
#  "['better', 'than', 'the', 'trailer', 'show', 'and', 'better', 'than', 'the', 'first', 'one']",
#  "['a', 'slick', 'and', 'enjoyable', 'fantasy', 'romp', 'let', 'down', 'by', 'a', 'muddle', 'plot', 'and', 'basic', 'dialogue']",
#  "['be', 'not', 'sure', 'i', 'would', 'enjoy', 'this', 'but', 'pleasantly', 'surprised']",
#  "['a', 'more', 'or', 'less', 'unnecessary', 'sequel']",
#  "['good', 'visual', 'effect', 'and', 'good', 'custom']",
#  "['emily', 'blunt', 'be', 'awesome', 'great', 'film', 'vast', 'improvement', 'over', 'the', 'first', 'film']",
#  "['great', 'feature']",
#  "['fair', 'at', 'best', 'prequel/sequel', 'to', 'snow', 'white', 'and', 'the', 'huntsman']",
#  "['fun', '&', 'fantasy']",
#  "['the', 'sequel', 'to', 'snow', 'white', '&', 'the', 'huntsman', '...']",
#  "['an', 'improvement', 'on', 'the', 'original', 'with', 'an', 'outstanding', 'cast']",
#  "['more', 'than', 'just', 'visual', 'effect']",
#  "['i', 'find', 'the', 'movie', 'quite', 'interesting']",
#  "['base', 'on', 'a', 'false', 'premise', 'and', 'still', 'a', 'decent', 'film']",
#  '[\'the\', \'huntsman\', \':\', \'winter\', "\'s", \'war\', \'(\', \'2016\', \')\']',
#  "['the', 'huntsman', 'be', 'decent']",
#  "['another', 'movie', 'not', 'as', 'bad', 'as', 'its', 'rating', 'would', 'suggest']",
#  "['a', 'perfectly', 'adequate', 'movie', 'that', 'be', 'well', '-', 'make', 'and', 'forgettable']",
#  "['adequate']",
#  "['mirror', 'mirror', 'on', 'the', 'wall', 'which', 'next', 'sequel', 'be', 'yet', 'to', 'fool']",
#  '[\'snow\', \'white\', "\'s", \'sequel\']',
#  "['great', 'popcorn', 'film', 'full', 'of', 'action', 'romance', 'and', 'fantasy']",
#  "['mesmerizing']",
#  "['love', 'action', 'comedy', 'and', 'special', 'fx']",
#  "['even', 'better', 'than', 'the', 'first', 'part']",
#  "['extremely', 'enjoyable', 'will', 'definitely', 'be', 'watch', 'it', 'again']",
#  "['totally', 'surprised', 'about', 'this', 'film']",
#  "['what', 'people', 'want', 'to', 'see', 'a+', 'actress']",
#  "['never', 'saw', 'the', 'previous', 'movie', 'but', 'actually', 'like', 'this', 'one']",
#  '[\'this\', \'flick\', \'expose\', \'disney\', "\'s", \'frozen\', \'for\', \'the\', \'fairy\', \'tale\', \'lie\', \'that\', \'it\', \'be\']',
#  "['surprisingly', 'good', 'fun', '...']",
#  "['a', 'dramatic', 'war', 'with', 'under', 'utilize', 'character', 'what', 'a', 'world', 'though']",
#  "['worth', 'a', 'try']",
#  "['the', 'movie', 'be', 'good']",
#  "['so', 'much', 'better', 'than', 'swath']",
#  "['better', 'than', 'i', 'expect']",
#  "['stunningly', 'beautiful', 'visuals']",
#  "['light', '-', 'hearted', 'fun', 'that', 'actually', 'work', 'a', 'lot', 'better', 'than', 'its', 'predecessor']",
#  "['a', 'bit', 'shambolic']",
#  "['a', 'very', 'capable', 'sequel']",
#  "['a', 'surprisingly', 'well', 'make', 'story']",
#  '[\'the\', \'hunts\', \'(\', \'wo\', \')\', \'man\', \':\', \'winter\', "\'s", \'war\', \'(\', \'ior\', \')\']',
#  "['fantastic', 'film', 'critic', 'need', 'to', 'chill']",
#  "['a', 'solid', 'fantasy', 'adventure', 'despite', 'not', 'bring', 'anything', 'new', 'to', 'the', 'genre']",
#  "['it', 'be', 'so', 'bad']",
#  "['get', 'to', 'know', 'the', 'raising', 'of', 'a', 'new', 'queen', 'the', 'story', 'before', 'and', 'after', 'snow', 'white', 'get', 'her', 'kingdom', 'back', 'and', 'of', 'course', 'the', 'creation', 'of', 'the', 'huntsman', 'and', 'the', 'story', 'with', 'his', 'wife']",
#  "['only', 'the', 'beginning', 'and', 'end', 'worth', 'see']",
#  "['i', 'really', 'enjoy', 'it', 'thought', 'chris', 'hemsworth', 'be', 'perfect']",
#  "['i', 'hope', 'the', 'next', 'spin', '-', 'off', 'be', 'all', 'about', 'queen', 'ravenna']",
#  "['not', 'bad']",
#  "['not', 'really', 'my', 'thing']",
#  "['hot', 'and', 'cold', 'wage', 'war']",
#  "['twizard', 'rating', ':', '79']",
#  "['boy', 'what', 'an', 'amazing', 'film', 'that', 'change', 'my', 'life']",
#  "['not', 'worth', 'of', 'movie', 'ticket']",
#  "['really', 'good']",
#  "['the', 'huntsman', 'fantasizes', 'about', 'the', 'lord', 'of', 'the', 'ring']",
#  "['love', 'can', 'conquer', 'ice']",
#  "['a', 'stellar', 'cast', 'make', 'this', 'prequel/sequel', 'better', 'than', 'the', 'original']",
#  "['mirror', 'mirror', '...']",
#  "['and', 'hour', 'and', 'a', 'half', 'of', 'how', 'unemployable', 'kristen', 'stewart', 'be']",
#  "['decent', 'fantasy', 'flick', 'with', 'some', 'beautiful', 'visuals']",
#  "['leftover']",
#  "['a', 'passable', 'snow', 'white', 'chronicle']",
#  '[\'it\', "\'", \'an\', \'okay\', \'movie\']',
#  "['love', 'the', 'gorgeous', 'visuals', 'and', 'the', 'sly', 'humour']",
#  "['a', 'worthy', 'sequel']",
#  "['whaaaaat', 'do', 'he', 'say']",
#  "['i', 'be', 'go', 'to', 'be', 'a', 'bit', 'harsh']",
#  '[\'a\', \'bitter\', \'disappointment\', \'|\', \'review\', \'of\', "\'", \'the\', \'huntsman\', \':\', \'winter\', "\'s", \'war\', "\'"]',
#  "['a', 'decent', 'film', 'if', 'you', 'stay', 'away', 'from', 'the', 'first', 'one']",
#  '[\'inconsistency\', \'&\', \'love\', \'story\', \'foil\', \'the\', \'wicked\', \'brilliance\', \'of\', \'``\', \'the\', \'huntsman\', \':\', \'winter\', "\'s", \'war\', \'``\']',
#  "['walk', 'out', 'of', 'the', 'cinema', 'with', 'the', 'temptation', 'to', 'write', 'something', 'cynical', ':']",
#  '[\'weak\', \'narrative\', \'make\', \'huntsman\', "\'", \'an\', \'unnecessary\', \'pre/sequel\']',
#  "['no', 'one', 'ask', 'for', 'this']",
#  "['bo', '-', 'o-o-oring']",
#  "['amira', 'adzwa', 'bmo', 'student', '23', 'year', 'old']",
#  "['so', 'much', 'potential', 'get', 'lose']",
#  "['nothing', 'original', 'here', 'move', 'on']",
#  '[\'the\', \'huntsman\', \':\', \'winter\', "\'s", \'war\', \'-\', \'movie\', \'review\']',
#  "['as', 'visually', 'sumptuous', 'as', 'it', 'be', 'this', 'prequel', '-', 'slash-sequel', 'be', 'no', 'more', 'than', 'a', 'half', '-', 'baked', 'mishmash', 'of', 'vastly', 'superior', 'fairy', '-', 'tales/', 'fantasy', 'adventuresis']",
#  "['very', 'intriguing', 'for', 'a', 'girly', 'movie']",
#  "['``', 'universal', 'picture', 'universal', 'picture', 'in', 'hollywood', 'what', 'have', 'you', 'do', '``']",
#  "['the', 'female', 'character', 'overshadow', 'the', 'huntsman']",
#  "['add', 'action', 'and', 'humor', 'can', 'not', 'save', 'the', 'muddled', 'plot']",
#  '[\'a\', \'decent\', \'refinement\', \'in\', \'action\', \'and\', \'visual\', \'but\', \'at\', \'the\', \'core\', \'it\', "\'", \'a\', \'predictably\', \'sappy\', \'fantasy\', \'drama\']',
#  "['not', 'to', 'be', 'confuse', 'with', 'the', 'war', 'wag', 'for', 'milady', 'de', 'winter']",
#  "['fails', 'to', 'improve', 'on', 'its', 'ordinary', 'predecessor']",
#  "['periodically', 'disappointing']",
#  "['as', 'bleak', 'as', 'its', 'predecessor']",
#  "['cynic', 'beware', 'this', 'movie', 'be', 'not', 'mean', 'to', 'be', 'take', 'seriously']",
#  "['not', 'so', 'happy', '(', 'ever', 'after', ')']",
#  "['better', 'than', 'expect']",
#  "['pathetic', 'tutty', 'fruit', 'movie']",
#  "['``', 'let', 'it', 'go', '``', 'universal', 'disney', 'already', 'have', 'dibs', 'on', 'the', 'snow', 'queen']",
#  '[\'the\', \'huntsman\', \':\', \'winter\', "\'s", \'war\']',
#  "['a', 'lighthearted', 'fare']",
#  "['not', 'much', 'to', 'see', 'here', 'really']",
#  "['unnecessary', 'sequel', 'and', 'unimpressive', 'fairy', 'tale']",
#  "['no', 'story']",
#  '[\'huntsman\', \':\', \'winter\', "\'s", \'war\', \'review\']',
#  "['expect', 'to', 'be', 'angry']",
#  "['sorry', 'to', 'say', 'i', 'do', 'not', 'like', 'it', 'but', 'some', 'nice', 'visuals']",
#  "['wasted', 'talent']",
#  "['i', 'can', 'not', 'believe', 'the', 'first', 'movie', 'be', 'better', '(', 'mild', '-', 'spoiler', ')']",
#  "['more', 'tall', '(', 'fairy', ')', 'tale', 'than', 'happily', 'ever', 'after']",
#  "['4/10']",
#  "['huntsman', ',', 'capital', '``', 'h', '``', 'should', 'be', 'capital', '``', 'c', '``']",
#  "['tedious', 'and', 'dull']",
#  "['banking', 'on', 'frozen']",
#  "['terrible', ',', 'terrible', 'and', 'just', 'plain', 'awful']",
#  "['huntsman', 'frozen', 'en', 'narnia']",
#  "['battle', 'with', 'allegiant', 'for', 'bad', 'of', 'the', 'year', 'so', 'far']",
#  '[\'if\', \'the\', \'huntsman\', \':\', \'winter\', "\'s", \'war\', \'want\', \'follow\', \'disney\', "\'s", \'frozen\', \'then\', \'it\', \'need\', \'to\', \'not\', \'be\', \'a\', \'copycat\', \'and\', \'``\', \'let\', \'it\', \'go\', \'``\']',
#  "['terrible', 'movie']",
#  '[\'``\', \'the\', \'huntsman\', \':\', \'winter\', "\'s", \'war\', \'``\', \'reflect\', \'poorly\', \'on\', \'the\', \'original\']',
#  "['their', 'be', 'no', 'need', 'for', 'this', 'sequel/prequel']",
#  "['prequel', 'sequel', 'or', 'spin', 'off']",
#  "['i', 'have', 'not', 'meet', 'anyone', 'that', 'like', 'this', 'movie', 'and', 'i', 'completely', 'get', 'why']",
#  "['my', 'review', 'on', 'this', 'movie', 'not', 'happy', 'not', 'good', 'do', 'not', 'like', 'it', 'terrible', 'and', 'violent', 'not', 'rat', 'for', 'kid', 'do', 'not', 'like', 'the', 'part', 'she', 'take', 'charlize', 'theron', 'wudnt', 'pay', 'to', 'see', 'it']",
#  "['your', 'typical', 'buffy', 'like', 'spunky', 'fighting', 'woman', 'we', 'be', 'all', 'so', 'tired', 'of', 'see']",
#  "['another', 'straight', 'white', 'male', 'hero', '...', '.', 'how', 'refreshing', '/sarcasm']",
#  '[\'it\', "\'", \'an\', \'ok\', \'movie\', \';\', \'do\', \'not\', \'go\', \'to\', \'the\', \'cinema\', \'with\', \'high\', \'expectation\']',
#  "['not', 'bvs', 'just', 'bs']",
#  "['a', 'much', 'great', 'improvement', 'on', 'mo', '5x', 'better']",
#  "['sloppy', 'misleading', 'and', 'disappointing', 'with', 'some', 'incredible', 'moment', 'mix', 'in']",
#  "['ben', 'affleck']",
#  "['ok', 'be', 'a', 'two', '-', 'letter', 'word', 'that', 'describe', 'the', 'most', 'anticipate', 'movie', 'of', '2016']",
#  "['i', 'be', 'a', 'fan', 'and', 'want', 'to', 'love', 'it', 'but', 'can', 'not']",
#  "['a', 'complete', 'package']",
#  "['an', 'overlong', 'awkwardly', 'pace', 'poorly', 'edit', 'mess', 'yet', 'bvs', 'improve', 'on', 'man', 'of', 'steel', 'in', 'almost', 'every', 'way', 'and', 'boast', 'some', 'of', 'the', 'great', 'superhero', 'moment', 'ever', 'put', 'to', 'screen']",
#  "['do', 'not', 'pay', 'for', 'this']",
#  "['argh']",
#  "['good', 'but', 'could', 'have', 'be', 'great']",
#  "['want', 'to', 'like', 'it']",
#  "['yawn', 'of', 'justice', 'yet', 'another', 'hollywood', 'hack', 'job']",
#  "['slow', 'and', 'boring', 'shut', 'it', 'off', 'after', 'a', 'hour']",
#  "['do', 'not', 'do', 'this', 'to', 'yourself', 'do', 'not', 'watch', 'good', 'user', 'review', 'be', 'fake']",
#  "['awful', 'worst', 'not', 'because', 'it', 'be', 'pretentious', 'and', 'totally', 'stupid', 'because', 'it', 'be', '150', 'min', 'of', 'utter', 'bore']",
#  "['at', 'least', 'worth', 'watch', '-', '``', 'wonder', 'woman', 'be', 'great', 'but', '``']",
#  "['bad', 'man', 'v', 'super', 'messed', 'up']",
#  "['zack', 'snyder', 'ruin', 'superman', 'twice', 'i', 'will', 'never', 'see', 'another', 'zack', 'snyder', 'movie', 'again']",
#  "['big', 'dramatic', 'and', 'action', 'packed', 'batman', 'v.', 'superman', 'be', 'unapologetically', 'off', '-', 'the-wall']",
#  "['snyder', 'miss', 'the', 'mark', 'yet', 'again']",
#  "['some', 'greatness', 'undermine', 'by', 'fatal', 'flaw']",
#  "['like', 'poetry', '(', 'first', '10/10', 'i', 'have', 'ever', 'give', ')']",
#  "['batman', 'v', 'superman', 'dawn', 'of', 'justice', 'review']",
#  "['overblown', 'in', 'every', 'conceivable', 'way', ';', 'definitely', 'one', 'of', 'the', 'big', 'disappointment', 'in', 'recent', 'memory']",
#  "['batman', 'vs.', 'superman', ':', 'dawn', 'of', 'justice', 'should', 'not', 'exist']",
#  "['love', 'it']",
#  "['an', 'epic', 'movie', 'for', 'fan']",
#  "['the', 'irony']",
#  "['the', 'dark', 'avenger']",
#  "['batman', 'v', 'superman', 'be', 'a', 'great', 'movie', 'just', 'maybe', 'not', 'yet']",
#  "['2nd', 'time', 'be', 'the', 'charm']",
#  "['do', 'not', 'listen', 'to', 'lame', 'critic']",
#  "['great', 'film', 'surprise', 'me', 'lot', 'after', 'such', 'terrible', 'review']",
#  "['a', 'dark', 'treat', 'must', 'watch', 'misinterpretion', 'of', 'critic']",
#  "['the', '2nd', 'best', 'comic', 'book', 'adaptation', 'after', 'dark', 'knight']",
#  "['amazed', 'favourite', 'superhero', 'film', 'of', 'this', 'year']",
#  "['the', 'critic', 'be', 'wrong']",
#  "['a', 'good', 'reason', 'on', 'why', 'you', 'should', 'not', 'trust', 'hype']",
#  "['move', 'over', '``', 'batman', '&', 'robin', '``']",
#  "['dreck', 'a', 'few', 'highlight', 'keep', 'this', 'from', 'a', 'zero', 'rating']",
#  "['not', 'good', 'at', 'all']",
#  "['snyder', 'hat', 'superman']",
#  "['would', 'love', 'to', 'love', 'it', 'but', 'i', 'can', 'not']",
#  "['batman', 'v', 'superman', 'may', 'not', 'be', 'the', 'superhero', 'film', 'that', 'we', 'want', 'but', 'its', 'sure', 'as', 'hell', 'the', 'one', 'we', 'need']",
#  "['the', 'most', 'epic', 'complex', 'visually', 'arrest', 'superhero', 'movie', 'since', '``', 'the', 'dark', 'knight', '``', 'trilogy']",
#  "['misunderstood']",
#  "['finally', 'the', 'dc', 'trinity', 'together', 'on', 'film']",
#  "['theatrical', 'version', 'v', 'ultimate', 'version']",
#  "['dawn', 'of', 'justice', 'be', 'not', 'that', 'great', 'but', 'it', 'be', 'not', 'that', 'bad', 'either']",
#  "['its', 'just', 'bad']",
#  "['absolutely', 'awful']",
#  "['set', 'a', 'record', 'in', 'plot', 'hole']",
#  "['150', 'minute', 'of', 'my', 'life', 'i', 'will', 'never', 'get', 'back']",
#  "['do', 'not', 'understand', 'critic', 'hate']",
#  "['may', 'contain', 'spoiler', 'this', 'film', 'be', 'one', 'giant', 'talentless', 'spoiler']",
#  "['really', 'disappointed']",
#  "['a', 'fundamentally', 'broken', 'movie', 'on', 'all', 'regard', 'spoiler']",
#  "['give', 'the', 'dark', 'knight', 'a', 'run', 'for', 'its', 'money']",
#  "['my', 'opinion', ':', 'the', 'bad', 'superhero', 'movie', 'of', 'all', 'time']",
#  "['unconditionally', 'fantastic']",
#  "['batman', 'v', 'superman', ':', 'dawn', 'of', 'justice', 'be', 'pretty', 'entertaining', 'much', 'of', 'the', 'time']",
#  "['a', 'sloppy', 'and', 'depressing', 'interpretation', 'of', 'the', 'hero']",
#  "['the', 'best', 'dc', 'movie', 'to', 'date', '20x', 'better', 'than', 'man', 'of', 'steel']",
#  "['people', 'fear', 'what', 'they', 'do', 'not', 'understand', '+', 'the', 'ultimate', 'cut']",
#  "['it', 'be', 'a', 'great', 'idea', 'for', 'a', 'dc', 'film', 'but', 'it', 'could', 'have', 'be', 'do', 'a', 'lot', 'better']",
#  "['do', 'not', 'disappoint', 'action', 'pack', 'dark', ',', 'gripp', 'and', 'highly', 'enjoyable']",
#  "['dawn', 'of', 'disappointment']",
#  "['no']",
#  "['the', 'movie', 'that', 'we', 'deserve', 'but', 'never', 'get']",
#  "['get', 'angry', 'we', 'deserve', 'better']",
#  "['this', 'be', 'a', 'great', 'movie']",
#  "['the', 'superhero', 'genre', 'get', 'the', 'psychological', 'treatment']",
#  "['really', 'enjoy', 'this', 'movie']",
#  "['clash', 'of', 'the', 'superhero']",
#  "['hack', 'snyder', 'finish', 'off', 'destroy', 'cultural', 'icon']",
#  "['disappointingly', 'overact', 'underacted', 'just', 'plain', 'not', 'acted', 'or', 'no', 'script', 'to', 'act', 'with']",
#  "['oh', 'boy', '...', 'i', 'just', '...', 'i', 'have', 'mediocre', 'expectation', 'and', 'those', 'be', 'far', 'too', 'high']",
#  "['where', 'be', 'the', 'logic']",
#  "['not', 'all', 'bad', 'but', 'like', 'seriously', 'snyder', 'and', 'company', 'really']",
#  "['this', 'be', 'not', 'really', 'a', 'batman', 'v', 'superman', 'film']",
#  "['a', 'movie', 'too', 'big', 'for', 'u', 'to', 'handle']",
#  "['too', 'long', 'and', 'make', 'no', 'sense']",
#  "['a', 'mediocre', 'film', 'with', 'a', 'few', 'good', 'part']",
#  "['mediocre']",
#  "['a', 'huge', 'mess']",
#  "['slugish', 'pacing', 'a', 'super', 'let', 'down']",
#  "['a', 'muddled', 'piece', 'of', 'garbage']",
#  "['no', 'just', 'no']",
#  "['one', 'of', 'the', 'most', 'incoherent', 'story', 'i', 'have', 'ever', 'see', 'on', 'a', 'movie', 'screen']",
#  "['the', 'most', 'pathetic', 'downtrodden', 'miserable', 'batman', 'you', 'will', 'ever', 'see']",
#  "['why', 'laugh', 'at', 'one', 'super', 'hero', 'when', 'you', 'can', 'laugh', 'at', 'two']",
#  "['way', 'too', 'many', 'plot', 'hole', 'weak', 'writing']",
#  "['possibly', 'the', 'most', 'boring', 'superhero', 'movie', 'i', 'have', 'ever', 'watch']",
#  "['a', 'jumbled', 'mess', 'that', 'have', 'so', 'much', 'potential', '...', 'you', 'know', 'like', 'most', 'zack', 'snyder', 'film']",
#  "['bad', 'superhero', 'movie', 'of', '2016']",
#  "['astoundingly', 'awful']",
#  "['this', 'movie', 'be', 'badly', 'edit', 'write', '&', 'destroy', 'an', 'iconic', 'story', '&', 'villain']",
#  "['terrible', '2', 'hour', 'trailer']",
#  "['psychologically', 'bad', 'processed', 'stereotype', 'superhero', 'movie']",
#  "['unacceptable']",
#  "['the', 'critic', 'be', 'right']",
#  "['implausible', 'and', 'boring']",
#  "['pathetic']",
#  "['bore', 'as', 'hell']",
#  "['very', 'good', 'movie']",
#  "['look', 'at', 'it', 'in', 'perspective']",
#  "['bad', 'than', 'i', 'expect']",
#  "['good', 'movie', 'stop', 'hat', 'it']",
#  "['the', 'thing', 'i', 'like', 'most', 'be', 'that', 'it', 'have', 'the', 'ball', 'to', 'do', 'what', 'i', 'have', 'be', 'criticize', 'the', 'marvel', 'movie', 'for', 'not', 'do']",
#  "['fell', 'asleep', 'in', 'cinema', 'enough', 'say']",
#  "['disappoint']",
#  "['the', 'best', 'comic', 'book', 'movie', 'yet']",
#  "['cool', 'movie', 'and', 'effect']",
#  "['be', 'a', 'doubter', 'now', 'a', 'fan']",
#  "['absolute', 'abomination']",
#  "['if', 'you', 'think', 'it', 'would', 'be', 'bad', '-', 'you', 'be', 'right']",
#  "['one', 'of', 'the', 'best', 'comic', 'book', 'film']",
#  "['fail', 'even', 'my', 'low', 'expectation']",
#  "['batman', 'v', 'superman', 'dawn', 'of', 'disappointment']",
#  "['a', 'visually', 'stunning', 'mess']",
#  "['i', 'be', 'not', 'angry', 'i', 'be', 'just', 'really', 'really', 'disappointed']",
#  '[\'contradictory\', \'filmmaking\', \'approach\', \'hold\', "\'", \'batman\', \'v\', \'superman\', "\'", \'back\']',
#  "['\\xe2\\x98\\x85\\xe2\\x98\\x85\\xe2\\x98\\x85', '-', 'over', 'the', 'top', 'but', 'underwhelming']",
#  "['death', 'of', 'justice']",
#  '[\'too\', \'long\', \'too\', \'much\', \'slow\', \'exposition\', \'but\', \'prop\', \'to\', \'affleck\', "\'s", \'batman\']',
#  "['dc', 'come', 'up', 'short', 'once', 'again']",
#  "['rush', 'to', 'the', 'justice', 'league']",
#  "['do', 'not', 'blame', 'ben', 'affleck']",
#  "['the', 'name', 'sound', 'familiar', 'but', 'not', 'the', 'character']",
#  "['awful']",
#  "['unworthy', 'of', 'your', 'worship']",
#  "['rush', 'messy', 'and', 'lack', 'any', 'real', 'fun']",
#  "['disappoint']",
#  "['``', 'the', 'dark', 'knight', 'vs.', 'the', 'man', 'of', 'steel', '``']",
#  "['this', 'be', 'a', 'no', 'brain', 'action', 'movie', 'good', 'for', 'something', 'but', 'not', 'much']",
#  "['disappoint']",
#  "['unbalanced', 'effort', 'at', 'combine', 'two', 'superhero', 'giant']",
#  "['terrible', 'movie']",
#  "['ruin', 'the', 'potential', 'of', 'bvs']",
#  "['garbage', 'movie']",
#  "['red', 'dawn']",
#  "['batman', 'v', 'superman', '-', 'really']",
#  "['disappoint']",
#  "['just', 'bad']",
#  "['great', 'material', '--', 'atrocious', 'editing']",
#  "['i', 'think', 'i', 'be', 'go', 'to', 'have', 'a', 'heart', 'attack', 'watch', 'this']",
#  "['i', 'give', 'it', 'a', '7']",
#  "['more', 'dusk', 'than', 'dawn', 'of', 'justice']",
#  "['why', 'do', 'warner', 'have', 'so', 'much', 'trouble', 'make', 'a', 'good', 'superhero', 'movie']",
#  "['meh']",
#  '[\'zack\', \'snyder\', \'do\', \'not\', \'get\', "\'", \'good\', "\'", \'hero\']',
#  "['a', 'true', 'yawn', 'of', 'justice']",
#  "['worst', 'of', 'any', 'of', 'the', 'movie', 'in', 'these', 'two', 'superhero', 'series']",
#  "['disappointing', 'film']",
#  '[\'can\', \'not\', \'be\', \'like\', \'marvel\', "\'s", \'but\', \'please\', \'just\', \'at\', \'least\', \'get\', \'close\', \'...\']',
#  "['an', 'insult', 'to', 'superhero', 'movie', '...']",
#  "['could', 'be', 'much', 'better']",
#  "['this', 'be', 'not', 'a', 'perfect', 'movie']",
#  "['a', 'clash', 'of', 'idea', 'and', 'moral']",
#  "['my', 'new', 'favorite', 'superhero', 'movie']",
#  "['people', 'be', 'way', 'too', 'critical', 'of', 'this..see', 'it']",
# ...
#  "['not', 'worth', 'go', 'to', 'cinema']",
#  "['while', 'visually', 'appeal', 'the', 'story', 'and', 'character', 'leave', 'much', 'to', 'be', 'desire']",
#  "['fails', 'to', 'live', 'up', 'to', 'the', 'hype']",
#  "['153', 'minute', 'too', 'long']",
#  "['bad', 'bad', 'bad']",
#  "['huge', 'huge', 'disappointment']",
#  "['sack', 'snyder', 'please']",
#  "['dawn', 'of', 'justice', '-', 'neither', 'batman', 'nor', 'superman']",
#  "['broken', 'record', 'review', '(', 'spoiler', ')']",
#  "['pretentious', 'schlock', 'poorly', 'craft', 'story', 'and', 'pacing', 'and', 'shallow', 'characterization', 'that', 'miss', 'the', 'point']",
#  "['dark', 'and', 'thought', 'provoke']",
#  "['enjoy', 'it']",
#  "['terrific', 'fun']",
#  "['a', 'dizzying', 'mess']",
#  "['dirty', 'funny', 'sexy', 'violent', 'and', 'unabashedly', 'romantic', ':', 'deadpool', 'have', 'arrive']",
#  "['this', 'be', 'what', 'it', 'look', 'like', 'when', 'filmmaker', 'take', 'risk']",
#  "['simply', 'excellent']",
#  "['best', 'movie', 'i', 'have', 'see', 'in', 'a', 'long', 'time']",
#  "['bad', 'marvel', 'movie', 'ever', 'make']",
#  "['boring', 'and', 'pointless']",
#  "['overrated', 'movie', 'write', 'by', 'a', '12', 'year', 'old']",
#  "['this', 'movie', 'be', 'a', 'cliche\\xcc\\x81']",
#  "['not', 'impressed']",
#  "['finally', 'an', 'r', '-', 'rat', 'comicbook', 'movie', 'and', 'they', 'make', 'it', 'this', 'lame']",
#  "['worst', 'marvel', 'movie', 'ever']",
#  "['film', 'should', 'have', 'a', 'maximum', 'age', 'limit', 'of', '10']",
#  "['sarcastic', 'beta', 'male', 'minus', 'morale', 'add', 'in', 'woman', 'worship']",
#  "['i', 'be', 'miss', 'it']",
#  "['terrible']",
#  '[\'banal\', \'puerile\', \'staid\', \'mostly\', \'awful\', \'and\', \'predictable\', \'humourless\', "\'", \'super\', "\'", \'hero\', \'movie\']',
#  "['quirky', 'and', 'funny', 'marvel', 'comic', 'parody', 'with', 'a', 'dirtbag', 'non', '-', 'superhero']",
#  '[\'good\', \'if\', \'you\', "\'re", \'have\', \'trouble\', \'sleep\']',
#  "['really', 'want', 'to', 'like', 'it', 'but', 'hat', 'it']",
#  "['utterly', 'base', 'entertainment']",
#  "['waste', 'of', 'time', 'and', 'money']",
#  "['if', 'it', 'be', 'not', 'for', 'ryan', 'reynolds', '...']",
#  "['epic', 'r', 'rat', 'marvel', 'movie']",
#  "['what', 'a', 'great', 'way', 'to', 'spend', 'a', 'couple', 'of', 'hour', 'well', 'play']",
#  "['deadpool', 'a', '90', 'minute', 'conversation', 'with', 'ryan', 'reynolds', 'about', 'deadpool']",
#  "['float', 'face', 'down', 'in', 'pool']",
#  "['rat', '8', 'plus', 'i', 'mean', 'seriously']",
#  "['one', 'of', 'the', 'bad', 'movie', 'i', 'have', 'ever', 'see']",
#  "['no', 'sir', 'i', 'do', 'not', 'like', 'it']",
#  "['terrible']",
#  "['genuinely', 'one', 'of', 'the', 'bad', 'film', 'ever', 'make']",
#  "['one', 'of', 'the', 'dumb', 'movie', 'i', 'have', 'see', 'in', 'a', 'long', 'time']",
#  "['disturbingly', 'awful']",
#  "['worst', 'of', '2016']",
#  "['bore', 'till', 'death']",
#  "['a', 'list', 'of', 'people', 'this', 'movie', 'be', 'for']",
#  "['i', 'laugh', 'twice', 'the', 'rest', 'be', 'rubbish']",
#  "['ash', 'taste', 'in', 'my', 'mouth']",
#  "['childish', 'immature', 'stupid', 'joke']",
#  "['a', 'bunch', 'of', 'joke', 'with', 'some', 'plot', 'not', 'a', 'movie', 'that', 'fill', 'with', 'joke']",
#  "['just', 'non', 'stop', 'joke', 'that', 'mainly', 'fall', 'flat', '(', 'no', 'spoiler', ')']",
#  "['playboy', 'meet', 'hollywood']",
#  "['rating', 'and', 'review', 'be', 'false', 'movie', 'be', 'terrible']",
#  "['fun', 'superhero', 'flick', 'with', 'an', 'extra', 'layer', 'of', 'm', '-', 'rat', 'sas']",
#  "['a', 'super', 'hero', 'without', 'hubris']",
#  "['comic', 'book', 'turn', 'movie', 'lot', 'of', 'inventive', 'action', 'and', 'a', 'great', 'sound', 'track']",
#  "['dead', 'funny']",
#  "['good', 'wholesome', 'fun', 'and', 'entertainment', '...']",
#  "['two', 'of', 'the', 'hot', 'actor', 'of', 'this', 'era', 'both', 'with', 'their', 'own', 'comic', 'flair', 'love', 'this']",
#  "['he', 'be', 'a', 'hero', 'by', 'pure', 'accident']",
#  "['not', 'quite', 'as', 'fun', 'as', 'it', 'want', 'to', 'be', 'but', 'still', 'fun']",
#  "['this', 'movie', 'surprise', 'me']",
#  "['awesomeness', 'dial', 'wade', 'pass', 'eleven']",
#  "['i', 'simply', 'love', 'it']",
#  "['a', 'bit', 'too', 'hype', 'but', 'a', 'solid', 'movie']",
#  "['love', 'this', 'movie']",
#  "['fan', 'of', 'the', 'comic', 'fan', 'of', 'the', 'movie']",
#  "['``', 'anti', '``', 'hero', 'still', 'end', 'with', '``', 'hero', '``']",
#  "['reynolds', 'play', 'it', 'well']",
#  "['disappoint']",
#  "['this', 'movie', 'be', 'actually', 'pretty', 'bad']",
#  "['impressive']",
#  "['one', 'of', 'the', 'bad', 'movie', 'i', 'have', 'ever', 'see', 'in', 'my', 'life']",
#  "['the', 'overpay', 'tool', 'who', 'direct', 'this', 'deserve', 'a', 'pat', 'on', 'the', 'back']",
#  "['nasty', 'fun', '&', 'invigorating', 'you', 'think', 'these', 'thing', 'be', 'all', 'the', 'same']",
#  "['it', 'be', 'what', 'it', 'say', 'on', 'the', 'tin']",
#  "['most', 'joke', 'fall', 'flat', 'for', 'me']",
#  "['ryan', 'reynolds', 'portray', 'deadpool', 'perfectly']",
#  "['ryan', 'reynolds', '``', 'get', 'it', '``']",
#  "['a', 'try', '-', 'hard', 'try', 'to', 'funny', 'but', 'end', 'up', 'be', 'just', 'lame']",
#  "['more', 'conservative', 'than', 'you', 'may', 'think']",
#  "['r', 'rat', 'comic', 'book', 'story']",
#  "['try', 'to', 'be', 'clever', 'forget', 'about', 'have', 'a', 'good', 'story', 'to', 'tell']",
#  "['the', 'sad', 'story', 'of', 'a', 'superhero', 'who', 'only', 'want', 'to', 'be', 'a', 'stand', 'up', 'comedian']",
#  "['major', 'disappointment']",
#  "['decent', 'action', 'flick', 'again', 'amazed', 'at', 'the', 'bi', '-', 'polar', 'review']",
#  "['unfunny', 'and', 'try', 'too', 'hard', 'to', 'be', 'funny']",
#  "['chop', 'chop']",
#  "['infantile', 'garbage']",
#  "['trash', 'tier', 'movie']",
#  "['not', 'much', 'of', 'a', 'movie', 'without', 'the', 'joke']",
#  "['deadpool', '=', 'how', 'can', 'people', 'really', 'hate', 'this', 'movie']",
#  "['3', 'word', 'to', 'describe', 'deadpool', ':', 'awesome', 'hilarious', 'and', 'ridiculous']",
#  "['its', 'good']",
#  "['maybe', 'too', 'much', 'hype']",
#  "['a', 'comic', 'carnage']",
#  "['it', 'be', 'about', 'f****g', 'time']",
#  "['want', 'to', 'have', 'fun', 'watch', 'it']",
#  "['good', 'movie', 'but', 'could', 'have', 'be', 'better']",
#  "['as', 'good', 'as', 'a', 'deadpool', 'movie', 'be', 'ever', 'go', 'to', 'be']",
#  '[\'black\', \'and\', \'vulgar\', \'comedy\', \'at\', \'it\', "\'", \'fine\']',
#  "['my', 'new', 'favorite', 'film']",
#  "['wow', 'can', 'not', 'believe', 'the', 'negativity']",
#  "['well', 'blow', 'me']",
#  "['deadpool', 'be', 'the', 'funny', 'and', 'most', 'enjoyable', 'to', 'watch', 'super', 'hero']",
#  "['pretty', 'good']",
#  '[\'it\', "\'", \'not\', \'easy\', \'to\', \'pull\', \'deadpool\', \'off\']',
#  "['campy', 'fun', 'flick', '-', 'if', 'you', 'can', 'take', 'the', 'blood', 'and', 'gore']",
#  '[\'ryan\', \'reunolds\', "\'", \'best\', \'yet\']',
#  "['funny', 'and', 'entertaining']",
#  "['deadpool', 'review']",
#  "['dead', 'on']",
#  "['great', 'comedy', 'good', 'action']",
#  "['full', 'of', 'shit', 'and', 'giggle']",
#  "['what', 'a', 'laugh']",
#  "['not', 'a', 'superhero', 'movie']",
#  "['this', 'film', 'have', 'its', 'audience']",
#  "['absolutely', 'hilarious', '-', 'deadpool', '(', '#', '1', ')']",
#  "['an', 'anti', '-', 'superhero', 'be', 'bear']",
#  "['bad', 'taste', 'extragavanca']",
#  "['desperately', 'want', 'to', 'be', 'funny', 'but', 'be', 'not']",
#  "['c', 'class', 'movie']",
#  "['bullshit', 'ever', 'see']",
#  "['a', 'simple', 'summary', '(', 'without', 'the', 'spoiler', ')', ';', 'what', 'you', 'need', 'to', 'know']",
#  "['not', 'funny']",
#  "['pretty', 'overrated']",
#  "['the', 'most', 'overrate', 'movie', 'of', '2016']",
#  "['my', 'review', 'for', 'deadpool', ':']",
#  "['mature', 'immaturity', 'at', 'its', 'best']",
#  "['awesome']",
#  "['marvel', 'hit', 'the', 'bullseye']",
#  '[\'deadpool\', \':\', "\'\'", \'x\', \'gon\', \'give\', \'it\', \'to\', \'ya\', \'``\']',
#  "['its', 'crude', 'but', 'i', 'like', 'it']",
#  "['a', 'spoiler', '-', 'free', 'review']",
#  "['the', 'mockumentary', 'style', 'of', 'the', 'merc', 'with', 'the', 'mouth', ':', 'kill', 'it']",
#  "['badassdom', '...', 'in', 'wade', 'we', 'trust']",
#  "['potential', 'spoiler', ':', 'argue', 'with', 'people', 'who', 'give', 'it', '1', 'star']",
#  "['the', 'character', 'work', 'but', 'the', 'rest', 'do', 'not']",
#  "['do', 'not', 'listen', 'to', 'the', 'one', 'star', 'review', 'this', 'movie', 'be', 'awesome']",
#  "['a', 'fun', 'movie', 'unless', 'you', 'hate', 'the', 'style', 'of', 'character', 'and', 'a', 'simple', 'story']",
#  "['it', 'know', 'what', 'it', 'be']",
#  "['great', 'movie', 'new', 'type', 'of', 'superhero', 'movie']",
#  "['death', 'serious', 'deadpool', 'be', 'absolutely', 'to', 'die', 'for', 'dead', 'on']",
#  "['surprisingly', 'i', 'love', 'it']",
#  "['the', 'best', 'movie', 'i', 'have', 'see', 'in', 'age', 'hilarious', 'this', 'be', 'all', 'ryan', 'renolds']",
#  "['okay', '...', 'but', 'not', 'enough']",
#  "['yes', 'its', 'stupid', 'but', 'its', 'enjoyable']",
#  "['lol', 'funny']",
#  "['a', 'movie', 'worth', 'watch', '67', 'time', 'and', 'i', 'have', '...', '.']",
#  "['a', 'truly', 'fun', 'flick']",
#  "['such', 'a', 'silly', 'movie', 'but', 'i', 'love', 'it']",
#  "['everyone', 'can', 'enjoy', 'this', 'one']",
#  "['a', 'different', 'and', 'better', 'kind', 'of', 'super', 'hero']",
#  "['dead', 'pool', 'dead', 'good']",
#  "['deadpool', '(', 'a', ')', 'english', '--', '--', '--', '--', 'my', 'rating', ':', '\\xe2\\x98\\x85\\xe2\\x98\\x85\\xe2\\x98\\x851\\xe2\\x81\\x842', 'new', 'venture']",
#  "['great', 'fun']",
#  '[\'probably\', \'the\', \'best\', \'of\', \'marvel\', "\'s", \'cinematic\', \'universe\']',
#  "['enjoyable']",
#  "['not', 'a', 'great', 'movie', 'but', 'great', 'fun']",
#  "['long', 'await', 'van', 'wilder', 'sequel', 'continue', 'the', 'tradition']",
#  "['deadpool', 'be', 'all', '...', 'heart']",
#  '["\'", \'look\', \'be\', \'everything\', \'ever\', \'hear\', \'dave\', \'beckham\', \'speak\', \'it\', "\'", \'like\', \'he\', \'mouth\', \'-\', \'sex\', \'a\', \'can\', \'of\', \'helium\', "\'"]',
#  '[\'best\', "\'", \'r\', \'rat\', "\'", \'movie\']',
#  "['deadpool', 'in', 'other', 'movie']",
#  "['exactly', 'what', 'it', 'say', 'it', 'would', 'be', 'spoiler', 'subject', 'to', 'interpretation']",
#  "['best', 'movie', 'i', 'have', 'see']",
#  '[\'``\', \'and\', \'that\', "\'", \'why\', \'regina\', \'rhyme\', \'with\', \'fun\', \'``\']',
#  "['the', 'deadpool', 'rise', '...']",
#  "['awesome', 'film']",
#  "['wow', '...']",
#  "['amazing', 'super', 'funny', 'and', 'hilarious', 'best', 'i', 'have', 'see', 'in', 'a', 'very', 'long', 'time']",
#  "['keep', 'make', 'movie', 'like', 'deadpool']",
#  "['a', 'marvel', 'masterpiece']",
#  "['love', 'it', 'put', 'the', 'other', 'boring', 'marvel', 'movie', 'to', 'shame']",
#  "['ryan', 'reynolds', 'and', 'the', 'quest', 'for', 'hotness']",
#  "['an', 'immature', 'unremarkable', 'romp']",
#  "['overrated', '(', 'mild', 'spoiler', ')']",
#  "['deadpool', 'be', 'an', 'unfunny', 'drudgery', 'that', 'bring', 'nothing', 'new', 'to', 'the', 'table']",
#  "['best', 'for', '15', 'year', '-', 'old', 'sneak', 'into', 'their', 'first', 'r', 'rat', 'film']",
#  "['as', 'brainless', 'and', 'boring', 'as', 'a', '14', 'y', 'o', 'attention', 'w**re']",
#  "['please', 'stop', 'the', 'violent', 'monkey', 'porn']",
#  "['we', 'walk', 'out', '...']",
#  "['a', 'slice', 'of', 'awesome']",
#  "['dumb', 'movie']",
#  "['would', 'have', 'be', 'better', 'if', 'they', 'do', 'not', 'do', 'a', 'hard', 'r', 'film']",
#  "['2016', 'begin', 'with', 'the', 'most', 'pathetic', 'movie', 'ever']",
#  "['a', 'beautiful', 'funny', 'love', 'story', 'of', 'a', 'super', 'hero']",
#  "['brilliant', 'superhero', 'comedy']",
#  "['harry', 'potter']",
#  "['good', 'job', ',', 'reynold', 'and', 'the', 'team']",
#  "['deadpool', 'be', 'about', 'a', 'mercenary', 'who', 'go', 'thru', 'hell', 'to', 'save', 'his', 'life', 'to', 'spend', 'the', 'rest', 'of', 'his', 'life', 'with', 'his', 'wife']",
#  "['tgchan', 'say', 'yes~', '/', 'tgchan.pl']",
#  "['every', 'bit', 'as', 'vile', 'profane', 'and', 'gratuitous', 'as', 'it', 'need', 'to', 'be']",
#  "['review', 'be', 'all', 'false', '..', 'do', 'not', 'deserve', 'a', 'rating', 'of', 'more', 'than', '2']",
#  "['on', 'the', 'verge', 'of', 'be', 'a', 'masterpiece', 'aside', 'from', 'a', 'couple', 'of', 'fault']",
#  "['outrageously', 'funny', 'original', 'and', 'entertaining']",
#  "['fantastic', 'film', 'but', 'daft', 'at', 'time']",
#  "['movie', 'for', 'kid', 'cheap', 'story']",
#  '[\'it\', "\'", \'an\', \'ok\', \'movie\', \'-\', \'a\', \'little\', \'original\', \'but\', \'not\', \'much\']',
#  "['the', 'movie', 'that', 'succeed', 'against', 'all', 'odds']",
#  "['work', 'like', 'a', 'charm']",
#  "['some', 'thing', 'to', 'remember']",
#  "['miss', 'opportunity']",
#  "['this', 'how', 'movie', 'should', 'be', 'make']",
#  "['love', 'it']",
#  "['one', 'of', 'the', 'best', 'x', 'man', 'movie', 'so', 'far']",
#  "['marvellous', 'mix', 'very', 'entertaining']",
#  "['refreshingly', 'filthy', 'superhero', 'movie', 'that', 'be', 'bind', 'by', 'its', 'origin', '-', 'story', 'trapping']",
#  "['let', 'jump', 'on', 'the', 'super', 'hero', 'make', 'bandwagon']",
#  "['what', 'i', 'expect']",
#  "['film', 'surpass', 'the', 'hype']",
#  "['surpasses', '``', 'begin', '``', 'in', 'every', 'aspect']",
#  "['best', 'movie', 'of', '2008', 'hand', 'down']",
#  "['the', 'sequel', 'we', 'deserve', 'to', 'the', 'batman', 'we', 'want']",
#  "['certainly', 'dark', '-', 'worth', 'the', 'wait']",
#  "['best', 'comic', 'movie', 'ever', '.']",
#  "['batman', 'at', 'his', 'best', 'and', 'beyond']",
#  "['the', 'dark', 'and', 'sinister', 'mood', 'of', 'the', 'film', 'really', 'set', 'the', 'theme', 'of', 'the', 'movie']",
#  "['the', 'batman', 'of', 'our', 'dream', 'so', 'much', 'more', 'than', 'a', 'comic', 'book', 'movie']",
#  "['the', 'dark', 'knight', 'be', 'as', 'good', 'as', 'everyone', 'say', 'and', 'easily', 'the', 'best', 'superhero', 'film', 'make']",
#  "['the', 'dark', 'knight', '--', '--', 'best', 'batman', 'movie', 'ever']",
#  '[\'heath\', \'ledger\', "\'s", \'dark\', \'and\', \'brilliant\', \'swan\', \'song\']',
#  "['a', 'batman', 'of', 'shakesperean', 'proportion']",
#  "['i', 'be', 'sorry', 'everyone', 'this', 'be', 'no', 'masterpiece']",
#  "['one', 'of', 'the', 'best', 'superhero', 'movie', 'ever']",
#  "['fantastic']",
#  "['batman', 'just', 'get', 'really', 'modern']",
#  "['the', 'dark', 'knight', 'delivers']",
#  '[\'very\', \'good\', \'but\', \'yikes\', \'let\', "\'", \'keep\', \'thing\', \'in\', \'perspective\']',
#  "['best', 'film', 'ever', 'you', 'must', 'be', 'batty']",
#  "['great', 'but', 'do', 'not', 'deserve', 'to', 'be', 'compare', 'with', 'masterpiece']",
#  '[\'let\', "\'", \'be\', \'realistic\']',
#  "['not', 'the', 'great', 'film', 'ever', 'make']",
#  "['heath', 'ledger', 'be', 'a', 'ledgend']",
#  "['tdk', 'a', 'solid', 'superhero', 'movie', 'nothing', 'more']",
#  "['the', 'film', 'that', 'seem', 'to', 'have', 'fool', 'everyone']",
#  "['too', 'many', 'fan', 'seem', 'to', 'be', 'blow', 'away']",
#  "['surprisingly', 'incoherent', 'and', 'boring']",
#  "['bold', 'without', 'ever', 'be', 'especially', 'great', 'and', 'which', 'progressively', 'get', 'less', '-', 'interesting', ';', 'the', 'film', 'be', 'a', 'wild', 'concoction', 'of', 'idea', 'that', 'just', 'about', 'tread', 'water']",
#  "['not', 'as', 'good', 'as', 'all', 'the', 'hype']",
#  "['be', 'it', 'really', 'one', 'of', 'the', 'top', '10']",
#  "['this', 'be', 'seriously', 'the', 'best', 'movie', 'ever', 'made.\\xef\\xbb\\xbf']",
#  "['perfect', 'movie']",
#  '[\'if\', \'not\', "\'", \'the\', \'dark\', \'knight\', "\'", \'...\', \'.then\', \'nothing\']',
#  "['an', 'action', 'movie', 'nothing', 'more']",
#  "['the', 'best', 'batman', 'film', 'yet']",
#  "['undescribable', 'perfection']",
#  "['christopher', 'nolan', 'masterpiece']",
#  "['i', 'be', 'disappoint', 'by', 'batman', 'begin', 'be', 'expect', 'the', 'bad', 'and', 'i', 'get', 'the', 'best']",
#  "['wonderful', 'how', 'superhero', 'movie', 'should', 'be', 'make']",
#  "['the', 'movie', 'be', 'over', 'rat', 'people', 'be', 'vote', 'emotionally']",
#  ...]

# %%
#put the list of lists back into the data frame
df.summary_review = [i for i in tmpList]

# %%
df.tail(2)
# Out:
#                     title       location  \
# 11036  The Usual Suspects  United States
# 11037  The Usual Suspects        UNKNOWN
#
#                                           summary_review  review_score  \
# 11036  [a, movie, you, need, to, watch, twice, to, ap...           9.0
# 11037  [``, the, great, trick, the, devil, ever, pull...          10.0
#
#        movie_score  genre
# 11036          8.6  Crime
# 11037          8.6  Crime

# %%
df['test'] = [i[:5] for i in df.summary_review]

# %%
df.tail(2)
# Out:
#                     title       location  \
# 11036  The Usual Suspects  United States
# 11037  The Usual Suspects        UNKNOWN
#
#                                           summary_review  review_score  \
# 11036  [a, movie, you, need, to, watch, twice, to, ap...           9.0
# 11037  [``, the, great, trick, the, devil, ever, pull...          10.0
#
#        movie_score  genre                          test
# 11036          8.6  Crime     [a, movie, you, need, to]
# 11037          8.6  Crime  [``, the, great, trick, the]

# %%
df2 = df[[2]]

# %%
df2.head()
# Out:
#                                       summary_review
# 0                                [really, not, good]
# 1  [you, 're, better, off, stay, well, clear, fro...
# 2  [so, messy, it, should, be, raptor, ranch, dre...
# 3                            [of, reptile, and, man]
# 4                [a, lot, better, then, people, say]

# %%
df
#    df2.summary_review[str(i)]
# Out:
# summary_review

# %%
df2.head(2)
# Out:
#    summary_review
# 0  summary_review
# 1  summary_review
